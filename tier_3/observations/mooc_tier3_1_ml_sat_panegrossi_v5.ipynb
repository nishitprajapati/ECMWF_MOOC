# %% [markdown]
#   <h1><center>ECMWF MOOC MACHINE LEARNING IN WEATHER AND CLIMATE</center></h1>
#
#    <h2><center>Tier 3: Practical ML application in weather and climate - OBSERVATIONS</center></h2>
#
#    <h2><center> Exercise on how to build a simple ANN model for satellite precipitation retrieval using passive microwave measurements </center></h2>
#
#  <h3><center>Created by: Daniele Casella, Paolo Sanò, Leo Pio D'Adderio, Riccardo D'Ercole </center></h3>
#   <h3><center> CNR-ISAC, Rome Italy</center></h3>

# %% [markdown]
# ## Introduction
# This Jupiter Notebook is on how to build a simple Artificialt Neural Network (ANN) (Multilayer Perceptrons) for surface precipitation rate estimation using the GPM Microwave Imager (GMI) measurements as input. The training dataset is a small-size osbervational dataset built from coincident measurements of the GMI and the Dual-frequency Precipitation Radar (DPR) on board the NASA/JAXA GPM-Core Observatory. The ANN architecture is pre-defined and an optimal set of parameters for the training phase is provided. The goal is to define the ANN (the weights) by minimising the prediction error (the loss function) avoiding overfitting during training. As you go through this Jupiter Notebook, you will learn about GMI characteristics, definition of ANN architecture, key parameters in the training phase, minimisation of the loss function, and overfitting. The ANN model obtained will be applied to one case study.
#
# As First Task it is recommended that you go through the code and the plots provided, understanding the meaning of each step. As a second Task you may run the code, play with the parameters, and analyse the results. Please, consider that the training for each set of parameters can take a few minutes.
#
# you can run this code on [colab](https://colab.research.google.com/github/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_3/observations/mooc_tier3_1_ml_sat_panegrossi_v5.ipynb)

# %% [markdown]
# ## Before starting: python and libraries installation
#
# ### Python
# Python 3 is required for running this code on your machine. The fastest way to have python is to install the [Anaconda Package](https://www.anaconda.com/products/individual).  By the way, python can be installed on all OS, there are versions of Anaconda for Linux Mac and Windows, however this code has been tested for Linux Ubuntu and windows 64 bit OS.
#
# Before starting you need to install some additional software and some python packages.
#
#
# ### Libraries installation
#
# If you are using Anaconda the easiest way to get everything installed is to use conda (from a terminal or Anaconda Prompt in Windows) to create a new virtual environment:
#
#
# <p style="background:black">
# <code style="background:black;color:white">
#   user@user:/home/user$ conda create -n tf tensorflow pandas scikit-learn matplotlib basemap xarray netCDF4 h5netcdf h5py wget
#   user@user:/home/user$ conda activate tf
# </code>
# </p>
#
# ### run in colab
#
# Otherwise if you are using colab you will need to install two libraries (wget and basemap), after the installation you will be asked to "restart runtime", you need to click on the "restart runtime" label.
# It is convenient to run this code with GPU enabled, you can do that from the edit menu.

# %%
# !pip install wget basemap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting basemap
#   Downloading basemap-1.3.6-cp310-cp310-manylinux1_x86_64.whl (859 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.2/859.2 kB 31.6 MB/s eta 0:00:00
# Collecting basemap-data<1.4,>=1.3.2
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 30.8 MB/s eta 0:00:00
# Collecting pyproj<3.5.0,>=1.9.3
#   Downloading pyproj-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 47.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.22.4)
# Collecting matplotlib<3.7,>=1.5
#   Downloading matplotlib-3.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 72.4 MB/s eta 0:00:00
# Collecting pyshp<2.4,>=1.2
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->basemap) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->basemap) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->basemap) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->basemap) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->basemap) (23.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->basemap) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->basemap) (1.4.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj<3.5.0,>=1.9.3->basemap) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.7,>=1.5->basemap) (1.16.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=7c5afeb32c5018b9aab252c7939388e74ba6867e2c254f482fe78780e3220013
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget, pyshp, pyproj, basemap-data, matplotlib, basemap
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed basemap-1.3.6 basemap-data-1.3.2 matplotlib-3.6.3 pyproj-3.4.1 pyshp-2.3.1 wget-3.2

# %% [markdown]
# ### Data download
#
#
# Before running the notebook you need to download some data:

# %%
import wget
url = 'https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_3/observations/1C-R.GPM.GMI.XCAL2016-C.20200916-S130832-E144106.037225.V07A.HDF5'
filename = wget.download(url)
url = 'https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_3/observations/2A.GPM.GMI.GPROF2021v1.20200916-S130832-E144106.037225.V07A.HDF5'
filename = wget.download(url)
url = 'https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_3/observations/dataset2_GMI_DPR_RR.nc'
filename = wget.download(url)

# %% [markdown]
# # GMI - GPM Microwave Imager
# The GMI is the most advanced spaceborne MW radiometer currently available, operating on the NASA/JAXA GPM Core Observatory (GPM-CO) launched in March 2014 (https://gpm.nasa.gov/). The GMI is a conical-scanning radiometer measuring vertically (V) and horizontally (H) polarised radiances in 13 channels between 10.65 and 183.31 GHz. Table 1 presents some details on GMI channels and their properties. In each channel the measured radiance, which is converted into brightness temperature (TB) for physical interpretation, results from the interaction of surface-emitted radiation with atmospheric water vapour and the liquid and solid hydrometeros within the cloud. Its 13 channels have different penetration ability in the cloud and are sensitive to different hydrometeor types and precipitation intensities. Complex retrieval algorithms convert the multichannel TBs in surface precipitation rate. There are several factors which makes the quantitative precipitation estimation from PMW radiometers (and from GMI) very challenging. Moreover, the relationhip between the multichannel TBs and surface rain rate is indirect and highly non linear, and machine learning techniques can be used to overcome some of these issues (e.g., Sanò et al., doi:10.3390/rs10071122) .
#
#
#  No. | Central frequency (GHz) | Polarisation | IFOV size
#  :-: | :-: | :-: | :-:
#  1 | 10.65 | V | 19x32 km
#  2 | 10.65 | H | 19x32 km
#  3 | 18.7 | V | 11x18 km
#  4 | 18.7 | H | 11x18 km
#  5 | 23.8 | V | 9.2x15 km
#  6 | 36.5 | V | 8.6x14 km
#  7 | 36.5 | H | 8.6x14 km
#  8 | 89.0 | V | 4.4x7.2 km
#  9 | 89.0 | H | 4.4x7.2 km
# 10 | 166.5 | V | 4.4x7.2 km
# 11 | 166.5 | H | 4.4x7.2 km
# 12 | 183.31 ± 3 | V | 4.4x7.2 km
# 13 | 183.31 ± 7 | V | 4.4x7.2 km
#
# <center><i>Table 1. GMI channels characteristics</i></center>

# %% [markdown]
# Now, we are ready to read the GMI files. The GMI files format is HDF5, and the "h5py" library has to be imported in order to be able to read the data. At the following link <a href="https://gpm.nasa.gov/resources/documents/file-specification-gpm-products/">GPM File Specification</a> you can find the document explaining the GMI file structure as well as the file structure of all Level 1 to Level 3 GPM products. The GPM products (including GMI) can be downloaded from <a href="https://storm.pps.eosdis.nasa.gov/storm/"> the NASA PPS Storm </a> website. In the following block we see how to open and read the content of a HDF5 file (i.e. the GMI file).

# %%
import h5py
gmi_file_path='./1C-R.GPM.GMI.XCAL2016-C.20200916-S130832-E144106.037225.V07A.HDF5'
hf=h5py.File(gmi_file_path,'r')
dataset1=hf['S1']
print(dataset1.keys())
# Out:
# <KeysViewHDF5 ['ScanTime', 'SCstatus', 'Latitude', 'Longitude', 'sunLocalTime', 'Quality', 'incidenceAngle', 'sunGlintAngle', 'incidenceAngleIndex', 'Tc']>

# %% [markdown]
# ### GMI TB Imagery
# In the following block, we are going to see how to create TB imagery for selected GMI channels.

# %%
# defining the funcion to plot
def plot_tb_map(TB,lat,lon,colorAxisMin,colorAxisMax):
    # set the lat/lon borders of the map
    latborders=[34,40]
    lonborders=[14,22]
    m = Basemap(projection='merc',
        resolution='l',
        lat_ts=20,
        llcrnrlat=latborders[0],urcrnrlat=latborders[1],\
        llcrnrlon=lonborders[0],urcrnrlon=lonborders[1])

    
#E set min/max values of the colorbar
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        im1 = m.pcolor(lon[:],lat[:],TB[:],shading='nearest',cmap='turbo',latlon=True,vmin=colorAxisMin,vmax=colorAxisMax)
    m.drawcoastlines()
    
# set parallels and meridians
    dparal=2 #separation in deg between drawn parallels
    parallels = np.arange(latborders[0],latborders[1],dparal)
    dmerid=2 #separation in deg between drawn meridians
    meridians = np.arange(lonborders[0],lonborders[1],dmerid)
    m.drawparallels(parallels,labels=[1,0,0,0],fontsize=15)
    m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=15) 
# add colorbar.
    cbar = m.colorbar(location='right',pad="5%")
    cbar.set_label('K')



#windows users may need to set an environmental variable before
#import os
#os.environ["PROJ_LIB"] = 'C:'+os.sep+'Users'+os.sep+'Leo'+os.sep+'anaconda3'+os.sep+'Library'+os.sep+'share'; #with your anaconda installation path

import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap 
from mpl_toolkits.basemap import Basemap
import numpy as np
import h5py
import warnings

gmi_file_path='./1C-R.GPM.GMI.XCAL2016-C.20200916-S130832-E144106.037225.V07A.HDF5'
hf=h5py.File(gmi_file_path,'r')

dataset1=hf['S1']
dataset2=hf['S2']
lat1=hf['S1/Latitude'][:]
lon1=hf['S1/Longitude'][:]
TB=hf['S1/Tc'][:]
TB10v=TB[:,:,0]
TB10h=TB[:,:,1]
TB19v=TB[:,:,2]
TB19h=TB[:,:,3]
TB23v=TB[:,:,4]
TB37v=TB[:,:,5]
TB37h=TB[:,:,6]
TB89v=TB[:,:,7]
TB89h=TB[:,:,8]

lat2=hf['S2/Latitude'][:]
lon2=hf['S2/Longitude'][:]


TB=hf['S2/Tc'][:]
TB166v=TB[:,:,0]
TB166v[TB166v<0]=np.NaN
TB166h=TB[:,:,1]
hf.close()

fig = plt.figure(figsize=(24,16))
ax = fig.add_subplot(231)
plot_tb_map(TB10v,lat1,lon1,colorAxisMin=160,colorAxisMax=280)
plt.title('TB 10v')

ax = fig.add_subplot(232)
plot_tb_map(TB19v,lat1,lon1,colorAxisMin=180,colorAxisMax=280)
plt.title('TB 19v')

ax = fig.add_subplot(233)
plot_tb_map(TB23v,lat1,lon1,colorAxisMin=200,colorAxisMax=300)
plt.title('TB 23v')

ax = fig.add_subplot(234)
plot_tb_map(TB37v,lat1,lon1,colorAxisMin=210,colorAxisMax=280)
plt.title('TB 37v')

ax = fig.add_subplot(235)
plot_tb_map(TB89v,lat1,lon1,colorAxisMin=130,colorAxisMax=280)
plt.title('TB 89v')

ax = fig.add_subplot(236)
plot_tb_map(TB166v,lat1,lon1,colorAxisMin=140,colorAxisMax=300)
plt.title('TB 166v')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-aeb114c84c63> in <cell line: 73>()
#      71 fig = plt.figure(figsize=(24,16))
#      72 ax = fig.add_subplot(231)
# ---> 73 plot_tb_map(TB10v,lat1,lon1,colorAxisMin=160,colorAxisMax=280)
#      74 plt.title('TB 10v')
#      75
#
# <ipython-input-4-aeb114c84c63> in plot_tb_map(TB, lat, lon, colorAxisMin, colorAxisMax)
#      25     m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=15)
#      26 # add colorbar.
# ---> 27     cbar = m.colorbar(location='right',pad="5%")
#      28     cbar.set_label('K')
#      29
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/basemap/__init__.py in colorbar(self, mappable, location, size, pad, fig, ax, **kwargs)
#    4640         else:
#    4641             raise ValueError('location must be top,bottom,left or right')
# -> 4642         cax = divider.append_axes(location, size=size, pad=pad)
#    4643         # create colorbar.
#    4644         cb = fig.colorbar(mappable,orientation=orientation,cax=cax,**kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     382             # Early return in the simple, non-deprecated case (much faster than
#     383             # calling bind()).
# --> 384             return func(*inner_args, **inner_kwargs)
#     385         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     386         if is_varargs and arguments.get(name):
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axes_grid1/axes_divider.py in append_axes(self, position, size, pad, add_to_figure, axes_class, **kwargs)
#     523             "top": (self.new_vertical, False),
#     524         }, position=position)
# --> 525         ax = create_axes(
#     526             size, pad, pack_start=pack_start, axes_class=axes_class, **kwargs)
#     527         if add_to_figure:
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axes_grid1/axes_divider.py in new_horizontal(self, size, pad, pack_start, **kwargs)
#     457             locator = self.new_locator(
#     458                 nx=len(self._horizontal) - 1, ny=self._yrefindex)
# --> 459         ax = self._get_new_axes(**kwargs)
#     460         ax.set_axes_locator(locator)
#     461         return ax
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axes_grid1/axes_divider.py in _get_new_axes(self, axes_class, **kwargs)
#     423         if axes_class is None:
#     424             if isinstance(axes, SubplotBase):
# --> 425                 axes_class = axes._axes_class
#     426             else:
#     427                 axes_class = type(axes)
#
# AttributeError: 'Axes' object has no attribute '_axes_class'

# %% [markdown]
# The panels show the GMI brightness temperatures (TBs) for the overpass which captured the Mediterranean Hurricane (Medicane) named Ianos on 16/09/2020 over the Ionian Sea between Southern Italy and Greece.
# The first row of panels shows the low frequency channels (< 30 GHz) affected mostly by the emission of radiation by the rain droplets, which results in higher TBs with respect to the radiatively cold sea surface background (warm areas in the imagery are associated to the precipitation in the rain bands around the cyclone center). The second row of panels shows the higher frequency channels, where the effect of the scattering by the ice on the observed TBs becomes visible as cold areas in the imagery. The scattering signal at 37 GHz and 89 GHz channel (low TBs) are due to the larger (and denser) frozen hydrometeors (hail/graupel) found in the convective cores, while at higher frequency the scattering is due to the smaller size/less dense ice in the upper cloud layers.  The following table summaries the properties of the six GMI frequencies (for further details please refer to D'Adderio et al.,10.1016/j.atmosres.2022.106174).
#
#  <table>
#
#   <tr>
#     <th style="text-align:center"> GMI channel</th>
#     <th style="text-align:center"> TB warmer than background</th>
#     <th style="text-align:center"> TB colder than background</th>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 10 GHz</td>
#     <td style="text-align:center"> emission from large raindrops (lower rain layers) </td>
#     <td style="text-align:center"> - </td>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 19 GHz</td>
#     <td style="text-align:center"> emission from large raindrops (rain)</td>
#     <td style="text-align:center"> - </td>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 22 GHz</td>
#     <td style="text-align:center"> emission from large raindrops (rain)<br>emission from  water vapour</td>
#     <td style="text-align:center"> - </td>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 37 GHz</td>
#     <td style="text-align:center"> emission from raindrops (rain)</td>
#     <td style="text-align:center"> Scattering by large and dense ice<br>(e.g. hail – deep convection)</td>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 89 GHz</td>
#     <td style="text-align:center"> emission from water vapour<br>and cloud liquid water</td>
#     <td style="text-align:center"> Scattering by precipitating heavily rimed ice<br>(e.g., graupel – convection/deep convection)</td>
#   </tr>
#     <tr>
#     <td style="text-align:center"> 166 GHz</td>
#     <td style="text-align:center"> emission from water vapour<br>and cloud liquid water</td>
#     <td style="text-align:center"> Scattering by less dense ice<br>(snowflakes and aggregates – stratiform/convective precip)</td>
#   </tr>
# </table>
# <center><i>Table 2. Properties of some GMI channels related to clouds and precipitation.</i></center>

# %% [markdown]
# # Exercise: training a simple artificial neural network model
#
# This section explains how to train a Multilayer Perceptrons (MLP) Neural Network which predicts the target variable or label (surface rain rate) given a set of 13 pre-defined inputs or features (TBs). The model represents a simple Neural Network (NN) with two hidden layers and a final layer which is used to predict the target label.
#
# The section is composed by the following parts:
#
# 1) Data loading and conversion
# <br>
# 2) Dataset description
# <br>
# 3) Training and test data split
# <br>
# 4) Model training
# <br>
# 5) Model evaluation
# <br>
# 6) Further training of the model and overfitting
# <br>
# 7) Testing the trained model on the initial case study
#
# <div class="alert alert-block alert-warning">
# <b>Warning </b> The neural network that will be trained during this exercise is not suitable for scientific/operational purposes, the main limitation comes from the training dataset, which is very small (10 orbits) with respect to the ones used in scientific/operational algorithms, which can include hundreds of thousands of orbits and millions of pixels. Using very large training dataset is of paramount importance for obtaining a model that is general, i.e. a model that performs with the same accuracy when applied to the training or to an independent dataset.
# </div>

# %% [markdown]
# ### 1) Data loading and conversion
# First, we will import all the libraries which are necessary to this exercise.
# <br>
# After loading the data in xarray format, which is one of the most common Python libraries to process netcdf files, the data is transformed into tensors which is the standard format for training Machine Learning or Deep Learning models.
# <br> For the purpose of this exercise, we will use the Tensorflow framework, which is built on top of Keras Python library in order to train a Neural Network.
# <br> We observe that the features dataset have 61906 different records and 13 features, whereas the label dataset consist of one variable and 61906 records.

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import optimizers
from tensorflow.keras import utils
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
import xarray as xr
import warnings
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings("ignore")

data_path = './dataset2_GMI_DPR_RR.nc'

ds = xr.open_dataset(data_path)

train_df = ds['tb'].to_dataframe().unstack()
target = ds['rr'].to_dataframe()

print('The shape of the features data is', train_df.shape)
print('The shape of the label data is', target.shape)

tensor_df = tf.convert_to_tensor(train_df, dtype=np.float)
label_df = tf.convert_to_tensor(target, dtype=np.float)
# Out:
# The shape of the features data is (61906, 13)
# The shape of the label data is (61906, 1)

# %% [markdown]
# ### 2) Dataset description
#
# The dataset used for training and test of the NN is built from 10 GMI orbits (from 9th March 2014). The 13 features correspond exactly to the 13 GMI channels taken in the same order as in Table 1. The rainfall rate represents the target variable and has been obtained from the NASA GMI/DPR Level 2 precipitation product (2B-CMB). This algorithm combines GMI measurements with the reflectivity profiles measured by the Dual-frequency Precipitation Radar (DPR) on board the GPM Core Observatory, the first spaceborne radar operating at Ka and Ku band (see figure below) and provides vertical profiles of liquid and solid precipitation microphysics, and precipitation rate near the surface. Some details on the 2B-CMB algorithm can be found in <a href="https://gpm.nasa.gov/resources/documents/gpmdpr-level-2-algorithm-theoretical-basis-document-atbd/">GMI/DPR Level 2 Algorithm Theoretical Basis Document (ATBD) </a>.
#
# The GMI TBs and the DPR rainfall rates (from 2B-CMB) have been matched to build the dataset using a nearest neighbour approach. Only pixels over ocean and sea where rainfall has been observed (2B-CMB rainfall rate > 0 mm/h) are selected to build the dataset (for a total of 61906 pixels).
# ![title](https://rmets.onlinelibrary.wiley.com/cms/asset/6e4beac5-ee9c-4de1-a780-0c34bd06987b/qj3313-fig-0001-m.jpg)
# _from: Skofronick-Jackson et al. 2018 doi:10.1002/qj.3313_

# %% [markdown]
# ### 3) Training and test data split
# The objective of Machine Learning is to create a model which is able to learn from training data and consequently make consistent predictions in the presence of unseen data. In order to achieve this, the objective is to minimize a loss function. This is done by identifying a vector of model weights which minimizes the loss function.
# <br>
# <br>
# In order to train a Machine Learning model which is able to make successful predictions and therefore generalize sufficiently well in the presence of indipendent data coming from the similar distribution, a standard practice is to divide the dataset into __training__ and __test sets__. Generally speaking, the Machine Learning best practice suggests to retain about 80% of the dataset for training and the rest 20% for test purpose. Another common practice is to divide the dataset into three sets, namely train, test and validation in order to tune the model hyperparameters (using the test) and then validate the model on an independent set (validation).
# <br>
# <br> In our case, considering that our training set is quite small, we decide to opt for a __50%__ split between training and test set, to allow for a model testing on a comparable size dataset.

# %%
def split_dataset(dataset, label_dataset):
    
    choice=np.mod(range(0,len(tensor_df)),2)==0 #this variable is true for even positions in the obseravtions sequence 
    X_train = dataset[choice==0]
    X_test = dataset[choice]
    y_train = label_dataset[choice==0]
    y_test = label_dataset[choice]   
    
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = split_dataset(tensor_df, label_df)

# Scaling: Standardize features by removing the mean and scaling to unit variance.
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train) #mean and variance are calculated on the training dataset and applied to the training dataset
X_test_scaled = scaler.transform(X_test)       #mean and variance (previously calculated) are applied to the test dataset


print( len(tensor_df))
print( X_train.shape)
print( X_test.shape)
# Out:
# 61906
# (30953, 13)
# (30953, 13)

# %% [markdown]
# Subsequently we define the __model hyperparameters__, which influence the model ability to learn.
# <br><br>
# - The __learning rate__ is the model speed of the learning process: a too high learning rate can save some training time at the expenses of letting the model converge (i.e., minimizing the loss function); a small learning rate can significantly increase the training time and still fail to achieve an efficient minimum. By default, NNs are trained with a decreasing linear schedule, allowing for a constant decrease in the learning rate which helps the model converge.
# <br>
# - The __batch size__ is the number of samples to include in a single training iteration. The total number of batches can be obtained from: size of the training data/batch_size
# <br>
# - The number of __epochs__ is the number times that the learning algorithm will work through the entire training dataset
# <br>
# - Finally, setting the __verbose__ option equal to 1 allow us to obtain information on the training while in progress

# %%
# model hyperparameters
learning_rate1= 0.001  #the learning rate is the step size at each iteration while moving toward a minimum of a loss function
epochs = 1600          #An epoch in machine learning means one complete pass of the training dataset through the algorithm. 
batch_size = 8000      #the batch size is the number of training examples utilized in one iteration. A large batch size should make the training faster but may lead to memory saturation


verbose = 1
# Set the input shape
input_shape = X_train.shape[1]
print(f'Feature shape: {input_shape}')
# Out:
# Feature shape: 13

# %% [markdown]
# ### 4) Model training
#
# We create a simple model architecture given the small training dataset. In this case we construct a MLP model with two hidden layers. The first layer contains 10 perceptrons, while the second is made of 20 perceptrons. We use a sigmoid activation function (transfer function used in both hidden layers). Finally, we use the mean squared error (MSE) as loss function to be minimised and display the mean average error (MAE) for each training iteration (epoch).
# <br> By printing the model it is possible to observe the shape of each layer and the total number of weights to be updated with the training.

# %%
# training phase with the training dataset
def train():
    # here the network achitecture is defined: it is a feed forward neural network with 2 hidden layers, 
    # 20 perceptrons in the fisrt hidden layer and 10 in the second. Sigmoids are used as transfer function in both hidden layers.
    model = Sequential()
    model.add(Dense(20, input_dim=input_shape, kernel_initializer='normal', activation='sigmoid'))
    model.add(Dense(10, kernel_initializer='normal', activation='sigmoid')) ###second hidden
    model.add(Dense(1, kernel_initializer='normal', activation='linear')) #output
    model.summary()
    #the optimizer is the algorithm used for the training. Adam is a standard choice, but Scale conjugate gradient (SGD), is also very efficient.
    optimizer = optimizers.Adam(lr=learning_rate1)
    #optimizer = optimizers.experimental.SGD( learning_rate=learning_rate1)
    
    # here the model optimzer and the loss function to be minimized during training (mean squared error, MSE) are defined
    # the mean absolute error (mae) is also computed as additional metrics
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae']) 
    
    # the training dataset, the batch size and the number of epochs to be used re defined
    history = model.fit(
        X_train_scaled,
        y_train,
        batch_size=batch_size,
        epochs=epochs,
    # validation is also carried out
    # monitoring loss and metrics on the test dataset
    # at the end of each epoch
        validation_data=(X_test_scaled, y_test),)
    model.save('./mlp_model.h5') #the model is saved at the end of the training phase in an HFD5 output file
    return model, history

# %%
# for trainig with CPU (Slower) uncomment next line.
# model, history = train() 

# for trainig with GPU (Faster) uncomment next 2 lines. works in colab with GPU enabled
with tf.device("/device:GPU:0"):
    model, history = train()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                280
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/1600
# 4/4 [==============================] - 5s 62ms/step - loss: 31.6153 - mae: 2.3636 - val_loss: 32.5935 - val_mae: 2.3472
# Epoch 2/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 31.4777 - mae: 2.3346 - val_loss: 32.4561 - val_mae: 2.3182
# Epoch 3/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 31.3386 - mae: 2.3057 - val_loss: 32.3184 - val_mae: 2.2898
# Epoch 4/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 31.2021 - mae: 2.2776 - val_loss: 32.1796 - val_mae: 2.2625
# Epoch 5/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 31.0633 - mae: 2.2505 - val_loss: 32.0396 - val_mae: 2.2361
# Epoch 6/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 30.9227 - mae: 2.2244 - val_loss: 31.8981 - val_mae: 2.2108
# Epoch 7/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 30.7797 - mae: 2.1994 - val_loss: 31.7546 - val_mae: 2.1864
# Epoch 8/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 30.6369 - mae: 2.1754 - val_loss: 31.6082 - val_mae: 2.1631
# Epoch 9/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 30.4890 - mae: 2.1524 - val_loss: 31.4595 - val_mae: 2.1410
# Epoch 10/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 30.3394 - mae: 2.1305 - val_loss: 31.3080 - val_mae: 2.1199
# Epoch 11/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 30.1874 - mae: 2.1098 - val_loss: 31.1536 - val_mae: 2.1000
# Epoch 12/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 30.0337 - mae: 2.0902 - val_loss: 30.9963 - val_mae: 2.0811
# Epoch 13/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 29.8745 - mae: 2.0717 - val_loss: 30.8371 - val_mae: 2.0634
# Epoch 14/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 29.7156 - mae: 2.0544 - val_loss: 30.6757 - val_mae: 2.0470
# Epoch 15/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 29.5532 - mae: 2.0381 - val_loss: 30.5130 - val_mae: 2.0318
# Epoch 16/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 29.3910 - mae: 2.0233 - val_loss: 30.3491 - val_mae: 2.0177
# Epoch 17/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 29.2253 - mae: 2.0097 - val_loss: 30.1853 - val_mae: 2.0049
# Epoch 18/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 29.0625 - mae: 1.9972 - val_loss: 30.0212 - val_mae: 1.9934
# Epoch 19/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 28.8995 - mae: 1.9861 - val_loss: 29.8578 - val_mae: 1.9831
# Epoch 20/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 28.7360 - mae: 1.9763 - val_loss: 29.6961 - val_mae: 1.9741
# Epoch 21/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 28.5761 - mae: 1.9675 - val_loss: 29.5362 - val_mae: 1.9664
# Epoch 22/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 28.4169 - mae: 1.9602 - val_loss: 29.3792 - val_mae: 1.9600
# Epoch 23/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 28.2616 - mae: 1.9540 - val_loss: 29.2253 - val_mae: 1.9549
# Epoch 24/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 28.1096 - mae: 1.9492 - val_loss: 29.0750 - val_mae: 1.9508
# Epoch 25/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 27.9607 - mae: 1.9455 - val_loss: 28.9289 - val_mae: 1.9480
# Epoch 26/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 27.8178 - mae: 1.9431 - val_loss: 28.7868 - val_mae: 1.9463
# Epoch 27/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 27.6762 - mae: 1.9417 - val_loss: 28.6501 - val_mae: 1.9457
# Epoch 28/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 27.5419 - mae: 1.9413 - val_loss: 28.5179 - val_mae: 1.9461
# Epoch 29/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 27.4129 - mae: 1.9421 - val_loss: 28.3905 - val_mae: 1.9474
# Epoch 30/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 27.2866 - mae: 1.9435 - val_loss: 28.2688 - val_mae: 1.9495
# Epoch 31/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 27.1658 - mae: 1.9459 - val_loss: 28.1525 - val_mae: 1.9524
# Epoch 32/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 27.0528 - mae: 1.9489 - val_loss: 28.0407 - val_mae: 1.9560
# Epoch 33/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 26.9437 - mae: 1.9528 - val_loss: 27.9339 - val_mae: 1.9603
# Epoch 34/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 26.8378 - mae: 1.9570 - val_loss: 27.8327 - val_mae: 1.9652
# Epoch 35/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 26.7383 - mae: 1.9618 - val_loss: 27.7364 - val_mae: 1.9705
# Epoch 36/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 26.6445 - mae: 1.9671 - val_loss: 27.6445 - val_mae: 1.9764
# Epoch 37/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 26.5547 - mae: 1.9727 - val_loss: 27.5572 - val_mae: 1.9825
# Epoch 38/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 26.4692 - mae: 1.9788 - val_loss: 27.4744 - val_mae: 1.9889
# Epoch 39/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 26.3887 - mae: 1.9850 - val_loss: 27.3956 - val_mae: 1.9955
# Epoch 40/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 26.3116 - mae: 1.9916 - val_loss: 27.3208 - val_mae: 2.0023
# Epoch 41/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 26.2375 - mae: 1.9982 - val_loss: 27.2502 - val_mae: 2.0092
# Epoch 42/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 26.1689 - mae: 2.0050 - val_loss: 27.1828 - val_mae: 2.0161
# Epoch 43/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 26.1030 - mae: 2.0119 - val_loss: 27.1188 - val_mae: 2.0231
# Epoch 44/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 26.0403 - mae: 2.0188 - val_loss: 27.0578 - val_mae: 2.0300
# Epoch 45/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 25.9806 - mae: 2.0256 - val_loss: 26.9998 - val_mae: 2.0369
# Epoch 46/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 25.9239 - mae: 2.0325 - val_loss: 26.9444 - val_mae: 2.0437
# Epoch 47/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 25.8686 - mae: 2.0391 - val_loss: 26.8919 - val_mae: 2.0503
# Epoch 48/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 25.8178 - mae: 2.0458 - val_loss: 26.8414 - val_mae: 2.0568
# Epoch 49/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 25.7682 - mae: 2.0524 - val_loss: 26.7930 - val_mae: 2.0632
# Epoch 50/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 25.7214 - mae: 2.0588 - val_loss: 26.7465 - val_mae: 2.0694
# Epoch 51/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 25.6755 - mae: 2.0651 - val_loss: 26.7021 - val_mae: 2.0754
# Epoch 52/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 25.6316 - mae: 2.0712 - val_loss: 26.6596 - val_mae: 2.0812
# Epoch 53/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 25.5907 - mae: 2.0772 - val_loss: 26.6182 - val_mae: 2.0869
# Epoch 54/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 25.5495 - mae: 2.0828 - val_loss: 26.5788 - val_mae: 2.0924
# Epoch 55/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 25.5114 - mae: 2.0884 - val_loss: 26.5405 - val_mae: 2.0977
# Epoch 56/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 25.4727 - mae: 2.0937 - val_loss: 26.5039 - val_mae: 2.1027
# Epoch 57/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 25.4373 - mae: 2.0987 - val_loss: 26.4681 - val_mae: 2.1076
# Epoch 58/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 25.4019 - mae: 2.1037 - val_loss: 26.4336 - val_mae: 2.1124
# Epoch 59/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 25.3684 - mae: 2.1085 - val_loss: 26.4000 - val_mae: 2.1170
# Epoch 60/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 25.3352 - mae: 2.1131 - val_loss: 26.3674 - val_mae: 2.1214
# Epoch 61/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 25.3036 - mae: 2.1175 - val_loss: 26.3356 - val_mae: 2.1257
# Epoch 62/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 25.2721 - mae: 2.1218 - val_loss: 26.3048 - val_mae: 2.1297
# Epoch 63/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 25.2415 - mae: 2.1258 - val_loss: 26.2750 - val_mae: 2.1336
# Epoch 64/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 25.2126 - mae: 2.1298 - val_loss: 26.2457 - val_mae: 2.1373
# Epoch 65/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.1836 - mae: 2.1335 - val_loss: 26.2172 - val_mae: 2.1409
# Epoch 66/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 25.1555 - mae: 2.1372 - val_loss: 26.1895 - val_mae: 2.1444
# Epoch 67/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 25.1284 - mae: 2.1406 - val_loss: 26.1623 - val_mae: 2.1477
# Epoch 68/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 25.1020 - mae: 2.1441 - val_loss: 26.1357 - val_mae: 2.1510
# Epoch 69/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.0760 - mae: 2.1474 - val_loss: 26.1096 - val_mae: 2.1542
# Epoch 70/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 25.0500 - mae: 2.1505 - val_loss: 26.0843 - val_mae: 2.1571
# Epoch 71/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 25.0252 - mae: 2.1535 - val_loss: 26.0595 - val_mae: 2.1599
# Epoch 72/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.0012 - mae: 2.1564 - val_loss: 26.0351 - val_mae: 2.1627
# Epoch 73/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 24.9769 - mae: 2.1592 - val_loss: 26.0113 - val_mae: 2.1654
# Epoch 74/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 24.9538 - mae: 2.1618 - val_loss: 25.9879 - val_mae: 2.1680
# Epoch 75/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.9308 - mae: 2.1645 - val_loss: 25.9650 - val_mae: 2.1704
# Epoch 76/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 24.9082 - mae: 2.1670 - val_loss: 25.9426 - val_mae: 2.1728
# Epoch 77/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 24.8866 - mae: 2.1695 - val_loss: 25.9204 - val_mae: 2.1752
# Epoch 78/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 24.8648 - mae: 2.1719 - val_loss: 25.8986 - val_mae: 2.1774
# Epoch 79/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 24.8436 - mae: 2.1742 - val_loss: 25.8773 - val_mae: 2.1796
# Epoch 80/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 24.8223 - mae: 2.1763 - val_loss: 25.8565 - val_mae: 2.1816
# Epoch 81/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 24.8018 - mae: 2.1783 - val_loss: 25.8360 - val_mae: 2.1835
# Epoch 82/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 24.7820 - mae: 2.1803 - val_loss: 25.8158 - val_mae: 2.1854
# Epoch 83/1600
# 4/4 [==============================] - 0s 36ms/step - loss: 24.7619 - mae: 2.1822 - val_loss: 25.7960 - val_mae: 2.1871
# Epoch 84/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 24.7427 - mae: 2.1841 - val_loss: 25.7764 - val_mae: 2.1889
# Epoch 85/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 24.7233 - mae: 2.1859 - val_loss: 25.7572 - val_mae: 2.1906
# Epoch 86/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 24.7046 - mae: 2.1877 - val_loss: 25.7381 - val_mae: 2.1923
# Epoch 87/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 24.6860 - mae: 2.1894 - val_loss: 25.7194 - val_mae: 2.1939
# Epoch 88/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 24.6676 - mae: 2.1911 - val_loss: 25.7010 - val_mae: 2.1954
# Epoch 89/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 24.6498 - mae: 2.1927 - val_loss: 25.6828 - val_mae: 2.1969
# Epoch 90/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 24.6317 - mae: 2.1942 - val_loss: 25.6650 - val_mae: 2.1983
# Epoch 91/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 24.6142 - mae: 2.1956 - val_loss: 25.6474 - val_mae: 2.1996
# Epoch 92/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 24.5970 - mae: 2.1970 - val_loss: 25.6299 - val_mae: 2.2010
# Epoch 93/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 24.5801 - mae: 2.1984 - val_loss: 25.6126 - val_mae: 2.2023
# Epoch 94/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 24.5632 - mae: 2.1997 - val_loss: 25.5956 - val_mae: 2.2035
# Epoch 95/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 24.5464 - mae: 2.2010 - val_loss: 25.5789 - val_mae: 2.2046
# Epoch 96/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 24.5301 - mae: 2.2022 - val_loss: 25.5624 - val_mae: 2.2057
# Epoch 97/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 24.5139 - mae: 2.2034 - val_loss: 25.5461 - val_mae: 2.2068
# Epoch 98/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 24.4978 - mae: 2.2045 - val_loss: 25.5300 - val_mae: 2.2078
# Epoch 99/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.4817 - mae: 2.2054 - val_loss: 25.5142 - val_mae: 2.2086
# Epoch 100/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.4667 - mae: 2.2065 - val_loss: 25.4983 - val_mae: 2.2097
# Epoch 101/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.4509 - mae: 2.2076 - val_loss: 25.4828 - val_mae: 2.2106
# Epoch 102/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 24.4356 - mae: 2.2085 - val_loss: 25.4673 - val_mae: 2.2115
# Epoch 103/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 24.4206 - mae: 2.2095 - val_loss: 25.4520 - val_mae: 2.2124
# Epoch 104/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.4055 - mae: 2.2104 - val_loss: 25.4369 - val_mae: 2.2133
# Epoch 105/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.3907 - mae: 2.2113 - val_loss: 25.4219 - val_mae: 2.2141
# Epoch 106/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 24.3759 - mae: 2.2121 - val_loss: 25.4071 - val_mae: 2.2148
# Epoch 107/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 24.3616 - mae: 2.2129 - val_loss: 25.3923 - val_mae: 2.2156
# Epoch 108/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 24.3474 - mae: 2.2137 - val_loss: 25.3777 - val_mae: 2.2164
# Epoch 109/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 24.3330 - mae: 2.2146 - val_loss: 25.3632 - val_mae: 2.2172
# Epoch 110/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 24.3188 - mae: 2.2153 - val_loss: 25.3489 - val_mae: 2.2179
# Epoch 111/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 24.3047 - mae: 2.2160 - val_loss: 25.3348 - val_mae: 2.2184
# Epoch 112/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 24.2907 - mae: 2.2165 - val_loss: 25.3208 - val_mae: 2.2189
# Epoch 113/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.2771 - mae: 2.2171 - val_loss: 25.3069 - val_mae: 2.2195
# Epoch 114/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.2634 - mae: 2.2177 - val_loss: 25.2931 - val_mae: 2.2200
# Epoch 115/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.2499 - mae: 2.2182 - val_loss: 25.2794 - val_mae: 2.2205
# Epoch 116/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 24.2366 - mae: 2.2187 - val_loss: 25.2657 - val_mae: 2.2210
# Epoch 117/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.2230 - mae: 2.2192 - val_loss: 25.2523 - val_mae: 2.2214
# Epoch 118/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.2100 - mae: 2.2197 - val_loss: 25.2388 - val_mae: 2.2219
# Epoch 119/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.1968 - mae: 2.2201 - val_loss: 25.2255 - val_mae: 2.2222
# Epoch 120/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.1839 - mae: 2.2205 - val_loss: 25.2122 - val_mae: 2.2226
# Epoch 121/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 24.1707 - mae: 2.2209 - val_loss: 25.1991 - val_mae: 2.2229
# Epoch 122/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.1583 - mae: 2.2213 - val_loss: 25.1859 - val_mae: 2.2234
# Epoch 123/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.1448 - mae: 2.2215 - val_loss: 25.1731 - val_mae: 2.2234
# Epoch 124/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.1325 - mae: 2.2217 - val_loss: 25.1601 - val_mae: 2.2236
# Epoch 125/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.1197 - mae: 2.2219 - val_loss: 25.1474 - val_mae: 2.2238
# Epoch 126/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.1073 - mae: 2.2221 - val_loss: 25.1346 - val_mae: 2.2240
# Epoch 127/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.0948 - mae: 2.2223 - val_loss: 25.1219 - val_mae: 2.2241
# Epoch 128/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.0821 - mae: 2.2224 - val_loss: 25.1093 - val_mae: 2.2242
# Epoch 129/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 24.0701 - mae: 2.2225 - val_loss: 25.0967 - val_mae: 2.2243
# Epoch 130/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 24.0573 - mae: 2.2226 - val_loss: 25.0843 - val_mae: 2.2243
# Epoch 131/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.0453 - mae: 2.2226 - val_loss: 25.0718 - val_mae: 2.2244
# Epoch 132/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 24.0335 - mae: 2.2229 - val_loss: 25.0592 - val_mae: 2.2247
# Epoch 133/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.0207 - mae: 2.2230 - val_loss: 25.0469 - val_mae: 2.2246
# Epoch 134/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 24.0087 - mae: 2.2229 - val_loss: 25.0346 - val_mae: 2.2245
# Epoch 135/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 23.9966 - mae: 2.2229 - val_loss: 25.0223 - val_mae: 2.2245
# Epoch 136/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.9844 - mae: 2.2228 - val_loss: 25.0101 - val_mae: 2.2243
# Epoch 137/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.9726 - mae: 2.2227 - val_loss: 24.9979 - val_mae: 2.2242
# Epoch 138/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.9607 - mae: 2.2227 - val_loss: 24.9856 - val_mae: 2.2242
# Epoch 139/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.9483 - mae: 2.2225 - val_loss: 24.9736 - val_mae: 2.2239
# Epoch 140/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 23.9368 - mae: 2.2223 - val_loss: 24.9614 - val_mae: 2.2239
# Epoch 141/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.9246 - mae: 2.2222 - val_loss: 24.9493 - val_mae: 2.2236
# Epoch 142/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.9127 - mae: 2.2220 - val_loss: 24.9372 - val_mae: 2.2234
# Epoch 143/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.9006 - mae: 2.2217 - val_loss: 24.9252 - val_mae: 2.2230
# Epoch 144/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.8892 - mae: 2.2215 - val_loss: 24.9130 - val_mae: 2.2230
# Epoch 145/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 23.8768 - mae: 2.2212 - val_loss: 24.9010 - val_mae: 2.2226
# Epoch 146/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.8653 - mae: 2.2210 - val_loss: 24.8889 - val_mae: 2.2224
# Epoch 147/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.8531 - mae: 2.2207 - val_loss: 24.8769 - val_mae: 2.2220
# Epoch 148/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 23.8415 - mae: 2.2204 - val_loss: 24.8648 - val_mae: 2.2218
# Epoch 149/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.8295 - mae: 2.2202 - val_loss: 24.8527 - val_mae: 2.2215
# Epoch 150/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.8176 - mae: 2.2198 - val_loss: 24.8407 - val_mae: 2.2211
# Epoch 151/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.8056 - mae: 2.2194 - val_loss: 24.8287 - val_mae: 2.2206
# Epoch 152/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.7938 - mae: 2.2191 - val_loss: 24.8165 - val_mae: 2.2203
# Epoch 153/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.7819 - mae: 2.2187 - val_loss: 24.8044 - val_mae: 2.2199
# Epoch 154/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 23.7700 - mae: 2.2183 - val_loss: 24.7923 - val_mae: 2.2195
# Epoch 155/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.7577 - mae: 2.2177 - val_loss: 24.7802 - val_mae: 2.2188
# Epoch 156/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.7459 - mae: 2.2172 - val_loss: 24.7680 - val_mae: 2.2184
# Epoch 157/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.7337 - mae: 2.2167 - val_loss: 24.7558 - val_mae: 2.2179
# Epoch 158/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.7218 - mae: 2.2163 - val_loss: 24.7435 - val_mae: 2.2175
# Epoch 159/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.7095 - mae: 2.2157 - val_loss: 24.7313 - val_mae: 2.2168
# Epoch 160/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.6975 - mae: 2.2152 - val_loss: 24.7189 - val_mae: 2.2162
# Epoch 161/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.6853 - mae: 2.2146 - val_loss: 24.7066 - val_mae: 2.2156
# Epoch 162/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.6732 - mae: 2.2140 - val_loss: 24.6941 - val_mae: 2.2151
# Epoch 163/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 23.6605 - mae: 2.2134 - val_loss: 24.6817 - val_mae: 2.2143
# Epoch 164/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.6483 - mae: 2.2126 - val_loss: 24.6692 - val_mae: 2.2137
# Epoch 165/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.6361 - mae: 2.2120 - val_loss: 24.6566 - val_mae: 2.2130
# Epoch 166/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.6235 - mae: 2.2113 - val_loss: 24.6439 - val_mae: 2.2123
# Epoch 167/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.6107 - mae: 2.2105 - val_loss: 24.6313 - val_mae: 2.2114
# Epoch 168/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.5983 - mae: 2.2097 - val_loss: 24.6186 - val_mae: 2.2107
# Epoch 169/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.5855 - mae: 2.2090 - val_loss: 24.6058 - val_mae: 2.2099
# Epoch 170/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.5728 - mae: 2.2082 - val_loss: 24.5929 - val_mae: 2.2091
# Epoch 171/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.5600 - mae: 2.2074 - val_loss: 24.5799 - val_mae: 2.2083
# Epoch 172/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 23.5472 - mae: 2.2066 - val_loss: 24.5668 - val_mae: 2.2075
# Epoch 173/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 23.5341 - mae: 2.2058 - val_loss: 24.5536 - val_mae: 2.2067
# Epoch 174/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.5207 - mae: 2.2049 - val_loss: 24.5404 - val_mae: 2.2057
# Epoch 175/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.5077 - mae: 2.2039 - val_loss: 24.5271 - val_mae: 2.2048
# Epoch 176/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 23.4943 - mae: 2.2030 - val_loss: 24.5136 - val_mae: 2.2038
# Epoch 177/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.4811 - mae: 2.2020 - val_loss: 24.5001 - val_mae: 2.2029
# Epoch 178/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.4675 - mae: 2.2011 - val_loss: 24.4864 - val_mae: 2.2020
# Epoch 179/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.4538 - mae: 2.2002 - val_loss: 24.4727 - val_mae: 2.2010
# Epoch 180/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 23.4400 - mae: 2.1991 - val_loss: 24.4589 - val_mae: 2.1999
# Epoch 181/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.4262 - mae: 2.1981 - val_loss: 24.4449 - val_mae: 2.1989
# Epoch 182/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.4124 - mae: 2.1971 - val_loss: 24.4308 - val_mae: 2.1980
# Epoch 183/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.3980 - mae: 2.1960 - val_loss: 24.4166 - val_mae: 2.1968
# Epoch 184/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.3840 - mae: 2.1949 - val_loss: 24.4023 - val_mae: 2.1958
# Epoch 185/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.3696 - mae: 2.1938 - val_loss: 24.3879 - val_mae: 2.1946
# Epoch 186/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.3551 - mae: 2.1926 - val_loss: 24.3734 - val_mae: 2.1935
# Epoch 187/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.3407 - mae: 2.1916 - val_loss: 24.3587 - val_mae: 2.1925
# Epoch 188/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.3257 - mae: 2.1904 - val_loss: 24.3440 - val_mae: 2.1912
# Epoch 189/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.3108 - mae: 2.1891 - val_loss: 24.3291 - val_mae: 2.1900
# Epoch 190/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.2958 - mae: 2.1878 - val_loss: 24.3141 - val_mae: 2.1887
# Epoch 191/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 23.2808 - mae: 2.1867 - val_loss: 24.2989 - val_mae: 2.1877
# Epoch 192/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.2654 - mae: 2.1856 - val_loss: 24.2837 - val_mae: 2.1867
# Epoch 193/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.2503 - mae: 2.1846 - val_loss: 24.2682 - val_mae: 2.1857
# Epoch 194/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.2347 - mae: 2.1836 - val_loss: 24.2526 - val_mae: 2.1846
# Epoch 195/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.2189 - mae: 2.1824 - val_loss: 24.2371 - val_mae: 2.1833
# Epoch 196/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 23.2033 - mae: 2.1810 - val_loss: 24.2213 - val_mae: 2.1820
# Epoch 197/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.1870 - mae: 2.1796 - val_loss: 24.2055 - val_mae: 2.1806
# Epoch 198/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 23.1714 - mae: 2.1783 - val_loss: 24.1895 - val_mae: 2.1794
# Epoch 199/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.1550 - mae: 2.1770 - val_loss: 24.1734 - val_mae: 2.1780
# Epoch 200/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.1389 - mae: 2.1756 - val_loss: 24.1571 - val_mae: 2.1767
# Epoch 201/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.1225 - mae: 2.1744 - val_loss: 24.1408 - val_mae: 2.1756
# Epoch 202/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.1062 - mae: 2.1732 - val_loss: 24.1243 - val_mae: 2.1744
# Epoch 203/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.0893 - mae: 2.1718 - val_loss: 24.1079 - val_mae: 2.1729
# Epoch 204/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.0729 - mae: 2.1704 - val_loss: 24.0912 - val_mae: 2.1716
# Epoch 205/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.0560 - mae: 2.1691 - val_loss: 24.0745 - val_mae: 2.1703
# Epoch 206/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.0390 - mae: 2.1677 - val_loss: 24.0578 - val_mae: 2.1689
# Epoch 207/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.0220 - mae: 2.1663 - val_loss: 24.0409 - val_mae: 2.1675
# Epoch 208/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.0050 - mae: 2.1647 - val_loss: 24.0240 - val_mae: 2.1661
# Epoch 209/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.9880 - mae: 2.1634 - val_loss: 24.0069 - val_mae: 2.1648
# Epoch 210/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.9709 - mae: 2.1621 - val_loss: 23.9898 - val_mae: 2.1635
# Epoch 211/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.9533 - mae: 2.1606 - val_loss: 23.9727 - val_mae: 2.1620
# Epoch 212/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 22.9360 - mae: 2.1591 - val_loss: 23.9556 - val_mae: 2.1605
# Epoch 213/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.9189 - mae: 2.1578 - val_loss: 23.9382 - val_mae: 2.1593
# Epoch 214/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.9015 - mae: 2.1565 - val_loss: 23.9209 - val_mae: 2.1582
# Epoch 215/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.8837 - mae: 2.1552 - val_loss: 23.9036 - val_mae: 2.1567
# Epoch 216/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.8663 - mae: 2.1537 - val_loss: 23.8862 - val_mae: 2.1552
# Epoch 217/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.8487 - mae: 2.1522 - val_loss: 23.8688 - val_mae: 2.1539
# Epoch 218/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.8309 - mae: 2.1508 - val_loss: 23.8514 - val_mae: 2.1525
# Epoch 219/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.8141 - mae: 2.1497 - val_loss: 23.8337 - val_mae: 2.1517
# Epoch 220/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.7962 - mae: 2.1488 - val_loss: 23.8161 - val_mae: 2.1507
# Epoch 221/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.7783 - mae: 2.1475 - val_loss: 23.7986 - val_mae: 2.1493
# Epoch 222/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.7603 - mae: 2.1459 - val_loss: 23.7812 - val_mae: 2.1476
# Epoch 223/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.7432 - mae: 2.1444 - val_loss: 23.7636 - val_mae: 2.1463
# Epoch 224/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 22.7253 - mae: 2.1429 - val_loss: 23.7461 - val_mae: 2.1448
# Epoch 225/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 22.7073 - mae: 2.1412 - val_loss: 23.7287 - val_mae: 2.1431
# Epoch 226/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.6900 - mae: 2.1397 - val_loss: 23.7112 - val_mae: 2.1418
# Epoch 227/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.6723 - mae: 2.1384 - val_loss: 23.6937 - val_mae: 2.1406
# Epoch 228/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.6549 - mae: 2.1372 - val_loss: 23.6761 - val_mae: 2.1395
# Epoch 229/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.6372 - mae: 2.1360 - val_loss: 23.6587 - val_mae: 2.1384
# Epoch 230/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.6193 - mae: 2.1347 - val_loss: 23.6413 - val_mae: 2.1369
# Epoch 231/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.6018 - mae: 2.1331 - val_loss: 23.6238 - val_mae: 2.1354
# Epoch 232/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.5842 - mae: 2.1316 - val_loss: 23.6064 - val_mae: 2.1340
# Epoch 233/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.5666 - mae: 2.1300 - val_loss: 23.5891 - val_mae: 2.1325
# Epoch 234/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.5490 - mae: 2.1285 - val_loss: 23.5717 - val_mae: 2.1311
# Epoch 235/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.5315 - mae: 2.1271 - val_loss: 23.5543 - val_mae: 2.1298
# Epoch 236/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.5142 - mae: 2.1258 - val_loss: 23.5369 - val_mae: 2.1286
# Epoch 237/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.4965 - mae: 2.1244 - val_loss: 23.5195 - val_mae: 2.1272
# Epoch 238/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 22.4792 - mae: 2.1229 - val_loss: 23.5021 - val_mae: 2.1259
# Epoch 239/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 22.4618 - mae: 2.1216 - val_loss: 23.4848 - val_mae: 2.1247
# Epoch 240/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.4441 - mae: 2.1202 - val_loss: 23.4675 - val_mae: 2.1232
# Epoch 241/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.4269 - mae: 2.1186 - val_loss: 23.4501 - val_mae: 2.1218
# Epoch 242/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 22.4093 - mae: 2.1171 - val_loss: 23.4328 - val_mae: 2.1203
# Epoch 243/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.3918 - mae: 2.1155 - val_loss: 23.4155 - val_mae: 2.1187
# Epoch 244/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 22.3745 - mae: 2.1141 - val_loss: 23.3981 - val_mae: 2.1175
# Epoch 245/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.3573 - mae: 2.1129 - val_loss: 23.3806 - val_mae: 2.1165
# Epoch 246/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.3396 - mae: 2.1115 - val_loss: 23.3631 - val_mae: 2.1151
# Epoch 247/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 22.3221 - mae: 2.1101 - val_loss: 23.3457 - val_mae: 2.1136
# Epoch 248/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 22.3049 - mae: 2.1086 - val_loss: 23.3283 - val_mae: 2.1123
# Epoch 249/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 22.2874 - mae: 2.1073 - val_loss: 23.3108 - val_mae: 2.1109
# Epoch 250/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 22.2697 - mae: 2.1056 - val_loss: 23.2935 - val_mae: 2.1091
# Epoch 251/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.2526 - mae: 2.1039 - val_loss: 23.2759 - val_mae: 2.1077
# Epoch 252/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.2349 - mae: 2.1021 - val_loss: 23.2585 - val_mae: 2.1058
# Epoch 253/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.2178 - mae: 2.1006 - val_loss: 23.2409 - val_mae: 2.1048
# Epoch 254/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.2001 - mae: 2.0992 - val_loss: 23.2234 - val_mae: 2.1031
# Epoch 255/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.1827 - mae: 2.0977 - val_loss: 23.2058 - val_mae: 2.1018
# Epoch 256/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 22.1652 - mae: 2.0962 - val_loss: 23.1882 - val_mae: 2.1003
# Epoch 257/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 22.1476 - mae: 2.0947 - val_loss: 23.1706 - val_mae: 2.0988
# Epoch 258/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.1299 - mae: 2.0928 - val_loss: 23.1532 - val_mae: 2.0969
# Epoch 259/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 22.1125 - mae: 2.0911 - val_loss: 23.1356 - val_mae: 2.0953
# Epoch 260/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 22.0949 - mae: 2.0893 - val_loss: 23.1180 - val_mae: 2.0936
# Epoch 261/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 22.0773 - mae: 2.0876 - val_loss: 23.1004 - val_mae: 2.0922
# Epoch 262/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 22.0600 - mae: 2.0862 - val_loss: 23.0826 - val_mae: 2.0909
# Epoch 263/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 22.0423 - mae: 2.0848 - val_loss: 23.0649 - val_mae: 2.0894
# Epoch 264/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.0243 - mae: 2.0832 - val_loss: 23.0472 - val_mae: 2.0877
# Epoch 265/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.0069 - mae: 2.0816 - val_loss: 23.0294 - val_mae: 2.0864
# Epoch 266/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.9892 - mae: 2.0802 - val_loss: 23.0115 - val_mae: 2.0850
# Epoch 267/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 21.9714 - mae: 2.0787 - val_loss: 22.9937 - val_mae: 2.0835
# Epoch 268/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 21.9537 - mae: 2.0771 - val_loss: 22.9758 - val_mae: 2.0821
# Epoch 269/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 21.9357 - mae: 2.0756 - val_loss: 22.9579 - val_mae: 2.0805
# Epoch 270/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 21.9177 - mae: 2.0739 - val_loss: 22.9400 - val_mae: 2.0788
# Epoch 271/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 21.9000 - mae: 2.0723 - val_loss: 22.9220 - val_mae: 2.0774
# Epoch 272/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 21.8821 - mae: 2.0708 - val_loss: 22.9039 - val_mae: 2.0761
# Epoch 273/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 21.8640 - mae: 2.0692 - val_loss: 22.8859 - val_mae: 2.0745
# Epoch 274/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 21.8462 - mae: 2.0677 - val_loss: 22.8678 - val_mae: 2.0730
# Epoch 275/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 21.8282 - mae: 2.0660 - val_loss: 22.8497 - val_mae: 2.0713
# Epoch 276/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 21.8099 - mae: 2.0641 - val_loss: 22.8316 - val_mae: 2.0695
# Epoch 277/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 21.7921 - mae: 2.0625 - val_loss: 22.8134 - val_mae: 2.0681
# Epoch 278/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 21.7735 - mae: 2.0606 - val_loss: 22.7954 - val_mae: 2.0662
# Epoch 279/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 21.7558 - mae: 2.0589 - val_loss: 22.7771 - val_mae: 2.0648
# Epoch 280/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.7375 - mae: 2.0573 - val_loss: 22.7589 - val_mae: 2.0631
# Epoch 281/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.7191 - mae: 2.0555 - val_loss: 22.7407 - val_mae: 2.0613
# Epoch 282/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 21.7008 - mae: 2.0536 - val_loss: 22.7224 - val_mae: 2.0596
# Epoch 283/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 21.6827 - mae: 2.0520 - val_loss: 22.7038 - val_mae: 2.0584
# Epoch 284/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 21.6642 - mae: 2.0507 - val_loss: 22.6853 - val_mae: 2.0572
# Epoch 285/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 21.6457 - mae: 2.0494 - val_loss: 22.6667 - val_mae: 2.0558
# Epoch 286/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 21.6270 - mae: 2.0479 - val_loss: 22.6482 - val_mae: 2.0544
# Epoch 287/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.6092 - mae: 2.0467 - val_loss: 22.6295 - val_mae: 2.0535
# Epoch 288/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 21.5899 - mae: 2.0452 - val_loss: 22.6108 - val_mae: 2.0516
# Epoch 289/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 21.5712 - mae: 2.0432 - val_loss: 22.5921 - val_mae: 2.0497
# Epoch 290/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 21.5530 - mae: 2.0416 - val_loss: 22.5733 - val_mae: 2.0485
# Epoch 291/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.5338 - mae: 2.0399 - val_loss: 22.5545 - val_mae: 2.0466
# Epoch 292/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.5151 - mae: 2.0379 - val_loss: 22.5358 - val_mae: 2.0448
# Epoch 293/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.4966 - mae: 2.0362 - val_loss: 22.5167 - val_mae: 2.0433
# Epoch 294/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.4775 - mae: 2.0343 - val_loss: 22.4978 - val_mae: 2.0413
# Epoch 295/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 21.4590 - mae: 2.0327 - val_loss: 22.4785 - val_mae: 2.0402
# Epoch 296/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.4392 - mae: 2.0311 - val_loss: 22.4597 - val_mae: 2.0381
# Epoch 297/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.4208 - mae: 2.0294 - val_loss: 22.4405 - val_mae: 2.0370
# Epoch 298/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.4015 - mae: 2.0279 - val_loss: 22.4214 - val_mae: 2.0353
# Epoch 299/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.3823 - mae: 2.0263 - val_loss: 22.4022 - val_mae: 2.0338
# Epoch 300/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.3633 - mae: 2.0247 - val_loss: 22.3829 - val_mae: 2.0324
# Epoch 301/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.3438 - mae: 2.0229 - val_loss: 22.3637 - val_mae: 2.0304
# Epoch 302/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 21.3249 - mae: 2.0212 - val_loss: 22.3442 - val_mae: 2.0292
# Epoch 303/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 21.3055 - mae: 2.0198 - val_loss: 22.3247 - val_mae: 2.0276
# Epoch 304/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.2859 - mae: 2.0181 - val_loss: 22.3052 - val_mae: 2.0261
# Epoch 305/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.2666 - mae: 2.0166 - val_loss: 22.2857 - val_mae: 2.0246
# Epoch 306/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.2467 - mae: 2.0147 - val_loss: 22.2662 - val_mae: 2.0226
# Epoch 307/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.2273 - mae: 2.0128 - val_loss: 22.2466 - val_mae: 2.0210
# Epoch 308/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.2080 - mae: 2.0112 - val_loss: 22.2268 - val_mae: 2.0196
# Epoch 309/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.1882 - mae: 2.0097 - val_loss: 22.2070 - val_mae: 2.0180
# Epoch 310/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.1689 - mae: 2.0084 - val_loss: 22.1870 - val_mae: 2.0170
# Epoch 311/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.1486 - mae: 2.0070 - val_loss: 22.1673 - val_mae: 2.0154
# Epoch 312/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.1287 - mae: 2.0052 - val_loss: 22.1474 - val_mae: 2.0136
# Epoch 313/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.1090 - mae: 2.0034 - val_loss: 22.1274 - val_mae: 2.0119
# Epoch 314/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 21.0890 - mae: 2.0013 - val_loss: 22.1074 - val_mae: 2.0098
# Epoch 315/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 21.0693 - mae: 1.9996 - val_loss: 22.0871 - val_mae: 2.0086
# Epoch 316/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.0488 - mae: 1.9981 - val_loss: 22.0670 - val_mae: 2.0068
# Epoch 317/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.0287 - mae: 1.9962 - val_loss: 22.0468 - val_mae: 2.0050
# Epoch 318/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 21.0085 - mae: 1.9943 - val_loss: 22.0265 - val_mae: 2.0033
# Epoch 319/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.9886 - mae: 1.9927 - val_loss: 22.0061 - val_mae: 2.0019
# Epoch 320/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.9681 - mae: 1.9913 - val_loss: 21.9857 - val_mae: 2.0004
# Epoch 321/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.9478 - mae: 1.9896 - val_loss: 21.9654 - val_mae: 1.9989
# Epoch 322/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.9274 - mae: 1.9880 - val_loss: 21.9448 - val_mae: 1.9972
# Epoch 323/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.9071 - mae: 1.9864 - val_loss: 21.9241 - val_mae: 1.9960
# Epoch 324/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.8864 - mae: 1.9849 - val_loss: 21.9034 - val_mae: 1.9943
# Epoch 325/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.8660 - mae: 1.9832 - val_loss: 21.8827 - val_mae: 1.9926
# Epoch 326/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.8454 - mae: 1.9812 - val_loss: 21.8618 - val_mae: 1.9907
# Epoch 327/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.8243 - mae: 1.9793 - val_loss: 21.8413 - val_mae: 1.9889
# Epoch 328/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.8038 - mae: 1.9773 - val_loss: 21.8205 - val_mae: 1.9869
# Epoch 329/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.7833 - mae: 1.9753 - val_loss: 21.7996 - val_mae: 1.9852
# Epoch 330/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.7619 - mae: 1.9735 - val_loss: 21.7789 - val_mae: 1.9834
# Epoch 331/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.7418 - mae: 1.9720 - val_loss: 21.7577 - val_mae: 1.9822
# Epoch 332/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.7207 - mae: 1.9706 - val_loss: 21.7366 - val_mae: 1.9810
# Epoch 333/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.7000 - mae: 1.9694 - val_loss: 21.7154 - val_mae: 1.9798
# Epoch 334/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 20.6784 - mae: 1.9677 - val_loss: 21.6944 - val_mae: 1.9780
# Epoch 335/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.6576 - mae: 1.9659 - val_loss: 21.6730 - val_mae: 1.9762
# Epoch 336/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.6363 - mae: 1.9642 - val_loss: 21.6517 - val_mae: 1.9745
# Epoch 337/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.6150 - mae: 1.9621 - val_loss: 21.6305 - val_mae: 1.9724
# Epoch 338/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.5937 - mae: 1.9604 - val_loss: 21.6093 - val_mae: 1.9711
# Epoch 339/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 20.5729 - mae: 1.9589 - val_loss: 21.5877 - val_mae: 1.9696
# Epoch 340/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 20.5514 - mae: 1.9570 - val_loss: 21.5662 - val_mae: 1.9675
# Epoch 341/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 20.5299 - mae: 1.9549 - val_loss: 21.5448 - val_mae: 1.9656
# Epoch 342/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 20.5083 - mae: 1.9530 - val_loss: 21.5232 - val_mae: 1.9638
# Epoch 343/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 20.4874 - mae: 1.9515 - val_loss: 21.5014 - val_mae: 1.9627
# Epoch 344/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 20.4659 - mae: 1.9502 - val_loss: 21.4796 - val_mae: 1.9614
# Epoch 345/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.4437 - mae: 1.9486 - val_loss: 21.4579 - val_mae: 1.9596
# Epoch 346/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 20.4223 - mae: 1.9466 - val_loss: 21.4361 - val_mae: 1.9577
# Epoch 347/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.4012 - mae: 1.9448 - val_loss: 21.4142 - val_mae: 1.9560
# Epoch 348/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.3789 - mae: 1.9428 - val_loss: 21.3924 - val_mae: 1.9541
# Epoch 349/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 20.3572 - mae: 1.9410 - val_loss: 21.3705 - val_mae: 1.9524
# Epoch 350/1600
# ...
# Epoch 1484/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 13.0477 - mae: 1.4610 - val_loss: 13.3997 - val_mae: 1.4599
# Epoch 1485/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 13.0461 - mae: 1.4554 - val_loss: 13.4023 - val_mae: 1.4559
# Epoch 1486/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 13.0447 - mae: 1.4541 - val_loss: 13.3993 - val_mae: 1.4580
# Epoch 1487/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0411 - mae: 1.4566 - val_loss: 13.3963 - val_mae: 1.4616
# Epoch 1488/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 13.0434 - mae: 1.4616 - val_loss: 13.3962 - val_mae: 1.4660
# Epoch 1489/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0418 - mae: 1.4632 - val_loss: 13.3923 - val_mae: 1.4629
# Epoch 1490/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 13.0447 - mae: 1.4576 - val_loss: 13.3964 - val_mae: 1.4560
# Epoch 1491/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 13.0419 - mae: 1.4532 - val_loss: 13.3931 - val_mae: 1.4564
# Epoch 1492/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0354 - mae: 1.4554 - val_loss: 13.3880 - val_mae: 1.4626
# Epoch 1493/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 13.0445 - mae: 1.4637 - val_loss: 13.3875 - val_mae: 1.4679
# Epoch 1494/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 13.0387 - mae: 1.4621 - val_loss: 13.3835 - val_mae: 1.4593
# Epoch 1495/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0329 - mae: 1.4555 - val_loss: 13.3869 - val_mae: 1.4550
# Epoch 1496/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 13.0325 - mae: 1.4550 - val_loss: 13.3794 - val_mae: 1.4598
# Epoch 1497/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 13.0280 - mae: 1.4576 - val_loss: 13.3789 - val_mae: 1.4607
# Epoch 1498/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 13.0296 - mae: 1.4601 - val_loss: 13.3769 - val_mae: 1.4626
# Epoch 1499/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 13.0319 - mae: 1.4579 - val_loss: 13.3792 - val_mae: 1.4589
# Epoch 1500/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0278 - mae: 1.4567 - val_loss: 13.3752 - val_mae: 1.4607
# Epoch 1501/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0233 - mae: 1.4587 - val_loss: 13.3752 - val_mae: 1.4610
# Epoch 1502/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 13.0227 - mae: 1.4595 - val_loss: 13.3715 - val_mae: 1.4611
# Epoch 1503/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 13.0244 - mae: 1.4601 - val_loss: 13.3685 - val_mae: 1.4609
# Epoch 1504/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 13.0191 - mae: 1.4569 - val_loss: 13.3709 - val_mae: 1.4560
# Epoch 1505/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 13.0254 - mae: 1.4524 - val_loss: 13.3749 - val_mae: 1.4542
# Epoch 1506/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 13.0168 - mae: 1.4540 - val_loss: 13.3670 - val_mae: 1.4609
# Epoch 1507/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 13.0228 - mae: 1.4624 - val_loss: 13.3685 - val_mae: 1.4679
# Epoch 1508/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 13.0168 - mae: 1.4641 - val_loss: 13.3616 - val_mae: 1.4625
# Epoch 1509/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 13.0170 - mae: 1.4570 - val_loss: 13.3650 - val_mae: 1.4551
# Epoch 1510/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 13.0151 - mae: 1.4548 - val_loss: 13.3574 - val_mae: 1.4576
# Epoch 1511/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 13.0100 - mae: 1.4564 - val_loss: 13.3554 - val_mae: 1.4596
# Epoch 1512/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 13.0088 - mae: 1.4582 - val_loss: 13.3540 - val_mae: 1.4602
# Epoch 1513/1600
# 4/4 [==============================] - 0s 41ms/step - loss: 13.0082 - mae: 1.4585 - val_loss: 13.3532 - val_mae: 1.4594
# Epoch 1514/1600
# 4/4 [==============================] - 0s 31ms/step - loss: 13.0101 - mae: 1.4559 - val_loss: 13.3567 - val_mae: 1.4566
# Epoch 1515/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 13.0065 - mae: 1.4551 - val_loss: 13.3527 - val_mae: 1.4576
# Epoch 1516/1600
# 4/4 [==============================] - 0s 32ms/step - loss: 13.0028 - mae: 1.4556 - val_loss: 13.3491 - val_mae: 1.4587
# Epoch 1517/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0030 - mae: 1.4579 - val_loss: 13.3453 - val_mae: 1.4616
# Epoch 1518/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 13.0021 - mae: 1.4594 - val_loss: 13.3431 - val_mae: 1.4598
# Epoch 1519/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 13.0006 - mae: 1.4586 - val_loss: 13.3405 - val_mae: 1.4600
# Epoch 1520/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9996 - mae: 1.4563 - val_loss: 13.3438 - val_mae: 1.4564
# Epoch 1521/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.9971 - mae: 1.4546 - val_loss: 13.3401 - val_mae: 1.4573
# Epoch 1522/1600
# 4/4 [==============================] - 0s 30ms/step - loss: 12.9978 - mae: 1.4568 - val_loss: 13.3396 - val_mae: 1.4593
# Epoch 1523/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9949 - mae: 1.4583 - val_loss: 13.3372 - val_mae: 1.4601
# Epoch 1524/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 12.9970 - mae: 1.4593 - val_loss: 13.3347 - val_mae: 1.4602
# Epoch 1525/1600
# 4/4 [==============================] - 0s 31ms/step - loss: 12.9939 - mae: 1.4556 - val_loss: 13.3388 - val_mae: 1.4544
# Epoch 1526/1600
# 4/4 [==============================] - 0s 33ms/step - loss: 12.9935 - mae: 1.4533 - val_loss: 13.3368 - val_mae: 1.4554
# Epoch 1527/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 12.9904 - mae: 1.4544 - val_loss: 13.3334 - val_mae: 1.4575
# Epoch 1528/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9994 - mae: 1.4595 - val_loss: 13.3308 - val_mae: 1.4651
# Epoch 1529/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 12.9890 - mae: 1.4618 - val_loss: 13.3287 - val_mae: 1.4599
# Epoch 1530/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.9864 - mae: 1.4560 - val_loss: 13.3305 - val_mae: 1.4543
# Epoch 1531/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 12.9881 - mae: 1.4518 - val_loss: 13.3292 - val_mae: 1.4535
# Epoch 1532/1600
# 4/4 [==============================] - 0s 30ms/step - loss: 12.9854 - mae: 1.4554 - val_loss: 13.3208 - val_mae: 1.4615
# Epoch 1533/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9837 - mae: 1.4590 - val_loss: 13.3199 - val_mae: 1.4609
# Epoch 1534/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9904 - mae: 1.4610 - val_loss: 13.3183 - val_mae: 1.4614
# Epoch 1535/1600
# 4/4 [==============================] - 0s 31ms/step - loss: 12.9884 - mae: 1.4554 - val_loss: 13.3253 - val_mae: 1.4524
# Epoch 1536/1600
# 4/4 [==============================] - 0s 30ms/step - loss: 12.9795 - mae: 1.4514 - val_loss: 13.3211 - val_mae: 1.4544
# Epoch 1537/1600
# 4/4 [==============================] - 0s 33ms/step - loss: 12.9766 - mae: 1.4551 - val_loss: 13.3153 - val_mae: 1.4603
# Epoch 1538/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9776 - mae: 1.4607 - val_loss: 13.3125 - val_mae: 1.4631
# Epoch 1539/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9747 - mae: 1.4600 - val_loss: 13.3105 - val_mae: 1.4595
# Epoch 1540/1600
# 4/4 [==============================] - 0s 31ms/step - loss: 12.9733 - mae: 1.4566 - val_loss: 13.3130 - val_mae: 1.4551
# Epoch 1541/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 12.9720 - mae: 1.4538 - val_loss: 13.3093 - val_mae: 1.4557
# Epoch 1542/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9712 - mae: 1.4540 - val_loss: 13.3091 - val_mae: 1.4557
# Epoch 1543/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9687 - mae: 1.4558 - val_loss: 13.3057 - val_mae: 1.4592
# Epoch 1544/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 12.9701 - mae: 1.4585 - val_loss: 13.3026 - val_mae: 1.4595
# Epoch 1545/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 12.9656 - mae: 1.4571 - val_loss: 13.3019 - val_mae: 1.4563
# Epoch 1546/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 12.9648 - mae: 1.4541 - val_loss: 13.3040 - val_mae: 1.4540
# Epoch 1547/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9651 - mae: 1.4528 - val_loss: 13.3022 - val_mae: 1.4550
# Epoch 1548/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9691 - mae: 1.4571 - val_loss: 13.2955 - val_mae: 1.4611
# Epoch 1549/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.9613 - mae: 1.4588 - val_loss: 13.2954 - val_mae: 1.4586
# Epoch 1550/1600
# 4/4 [==============================] - 0s 33ms/step - loss: 12.9608 - mae: 1.4557 - val_loss: 13.2962 - val_mae: 1.4549
# Epoch 1551/1600
# 4/4 [==============================] - 0s 31ms/step - loss: 12.9590 - mae: 1.4546 - val_loss: 13.2937 - val_mae: 1.4564
# Epoch 1552/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.9607 - mae: 1.4569 - val_loss: 13.2906 - val_mae: 1.4597
# Epoch 1553/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 12.9609 - mae: 1.4566 - val_loss: 13.2929 - val_mae: 1.4556
# Epoch 1554/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.9548 - mae: 1.4546 - val_loss: 13.2911 - val_mae: 1.4571
# Epoch 1555/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 12.9537 - mae: 1.4571 - val_loss: 13.2873 - val_mae: 1.4598
# Epoch 1556/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 12.9524 - mae: 1.4581 - val_loss: 13.2862 - val_mae: 1.4583
# Epoch 1557/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 12.9550 - mae: 1.4552 - val_loss: 13.2867 - val_mae: 1.4543
# Epoch 1558/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9513 - mae: 1.4554 - val_loss: 13.2814 - val_mae: 1.4586
# Epoch 1559/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.9547 - mae: 1.4593 - val_loss: 13.2814 - val_mae: 1.4605
# Epoch 1560/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.9474 - mae: 1.4583 - val_loss: 13.2796 - val_mae: 1.4559
# Epoch 1561/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 12.9479 - mae: 1.4523 - val_loss: 13.2892 - val_mae: 1.4505
# Epoch 1562/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 12.9523 - mae: 1.4499 - val_loss: 13.2816 - val_mae: 1.4542
# Epoch 1563/1600
# 4/4 [==============================] - 0s 30ms/step - loss: 12.9423 - mae: 1.4541 - val_loss: 13.2747 - val_mae: 1.4586
# Epoch 1564/1600
# 4/4 [==============================] - 0s 30ms/step - loss: 12.9446 - mae: 1.4589 - val_loss: 13.2745 - val_mae: 1.4614
# Epoch 1565/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.9451 - mae: 1.4594 - val_loss: 13.2731 - val_mae: 1.4592
# Epoch 1566/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.9392 - mae: 1.4561 - val_loss: 13.2730 - val_mae: 1.4535
# Epoch 1567/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 12.9415 - mae: 1.4512 - val_loss: 13.2725 - val_mae: 1.4518
# Epoch 1568/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.9433 - mae: 1.4534 - val_loss: 13.2656 - val_mae: 1.4568
# Epoch 1569/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9406 - mae: 1.4583 - val_loss: 13.2638 - val_mae: 1.4593
# Epoch 1570/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.9388 - mae: 1.4556 - val_loss: 13.2679 - val_mae: 1.4537
# Epoch 1571/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 12.9357 - mae: 1.4532 - val_loss: 13.2644 - val_mae: 1.4557
# Epoch 1572/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.9319 - mae: 1.4554 - val_loss: 13.2635 - val_mae: 1.4574
# Epoch 1573/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9330 - mae: 1.4572 - val_loss: 13.2609 - val_mae: 1.4586
# Epoch 1574/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9312 - mae: 1.4558 - val_loss: 13.2627 - val_mae: 1.4544
# Epoch 1575/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9297 - mae: 1.4531 - val_loss: 13.2609 - val_mae: 1.4536
# Epoch 1576/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.9284 - mae: 1.4528 - val_loss: 13.2567 - val_mae: 1.4556
# Epoch 1577/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9275 - mae: 1.4565 - val_loss: 13.2529 - val_mae: 1.4593
# Epoch 1578/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9265 - mae: 1.4587 - val_loss: 13.2514 - val_mae: 1.4587
# Epoch 1579/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9244 - mae: 1.4567 - val_loss: 13.2514 - val_mae: 1.4550
# Epoch 1580/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9318 - mae: 1.4519 - val_loss: 13.2602 - val_mae: 1.4499
# Epoch 1581/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9270 - mae: 1.4518 - val_loss: 13.2482 - val_mae: 1.4559
# Epoch 1582/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.9235 - mae: 1.4569 - val_loss: 13.2455 - val_mae: 1.4588
# Epoch 1583/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9228 - mae: 1.4553 - val_loss: 13.2455 - val_mae: 1.4532
# Epoch 1584/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9211 - mae: 1.4511 - val_loss: 13.2475 - val_mae: 1.4516
# Epoch 1585/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9178 - mae: 1.4517 - val_loss: 13.2421 - val_mae: 1.4560
# Epoch 1586/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9195 - mae: 1.4581 - val_loss: 13.2408 - val_mae: 1.4618
# Epoch 1587/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9172 - mae: 1.4591 - val_loss: 13.2401 - val_mae: 1.4575
# Epoch 1588/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9193 - mae: 1.4535 - val_loss: 13.2448 - val_mae: 1.4512
# Epoch 1589/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9192 - mae: 1.4529 - val_loss: 13.2360 - val_mae: 1.4561
# Epoch 1590/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.9125 - mae: 1.4545 - val_loss: 13.2351 - val_mae: 1.4550
# Epoch 1591/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9099 - mae: 1.4542 - val_loss: 13.2335 - val_mae: 1.4551
# Epoch 1592/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9100 - mae: 1.4550 - val_loss: 13.2325 - val_mae: 1.4555
# Epoch 1593/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9080 - mae: 1.4549 - val_loss: 13.2311 - val_mae: 1.4560
# Epoch 1594/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9082 - mae: 1.4565 - val_loss: 13.2278 - val_mae: 1.4570
# Epoch 1595/1600
# 4/4 [==============================] - 0s 36ms/step - loss: 12.9097 - mae: 1.4544 - val_loss: 13.2300 - val_mae: 1.4533
# Epoch 1596/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9049 - mae: 1.4535 - val_loss: 13.2273 - val_mae: 1.4552
# Epoch 1597/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9024 - mae: 1.4550 - val_loss: 13.2235 - val_mae: 1.4571
# Epoch 1598/1600
# 4/4 [==============================] - 0s 34ms/step - loss: 12.9080 - mae: 1.4582 - val_loss: 13.2227 - val_mae: 1.4590
# Epoch 1599/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9009 - mae: 1.4561 - val_loss: 13.2262 - val_mae: 1.4523
# Epoch 1600/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9037 - mae: 1.4506 - val_loss: 13.2283 - val_mae: 1.4512

# %% [markdown]
# ### 5) Model evaluation
#
# Here we plot the learning curves, i.e., the MAE obtained ad each iteration (epoch) as a function of the epoch number. By observing the learning curves, we clearly see that the training and test values of the loss function decrease with the number of epochs. However, the decreasing rate of the two curves slows down, and the two curves become almost flat somewhat near the 1400th epoch, which means that the training of the model is almost completed. Moreover, the two (train and test) loss curves are very similar to each other, this is a clear sign of the generalizability of the model. In other terms, if we train on a dataset and we get the same result on an indipendent test dataset (with different observations) we expect that the application of the model to any other dataset will still give the same accuracy (i.e., validation dataset which is not considered in this exercise).
# <br> Overall, it is possible to observe that the two curves do not fully reach and asymptotic value, and it may be possible that a further training of the model brigns to slightly better results.

# %%
import matplotlib.pyplot as plt
# plot learning curves
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('MSE loss')
plt.plot((history.history['loss']), label='train')
plt.plot((history.history['val_loss']), label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### 6) Further training of the model and overfitting
#
# The model can be further trained for even more Epochs, but it will be subject to overfitting. An overfitting model reproduces too closely the target variable in a specific training dataset, and may therefore fail to fit additional data or predict future observations reliably.  In other words, the model memorizes the training dataset too well, learning also the noise included, and it is not able to generalise any more. <br>The following code loads the model that has been trained in section 6 and trains it further for additional 1000 epochs, using the same training hyperparameters (learning rate, batch size, etc.).

# %%
# training phase with the training dataset
fine_tune_epochs = 1000
total_epochs =  epochs + fine_tune_epochs
def train_fine(model):

    optimizer = optimizers.Adam(lr=learning_rate1)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    history_fine = model.fit(
        X_train_scaled,
        y_train,
        batch_size=batch_size,
        epochs=total_epochs,
        initial_epoch=history.epoch[-1],
    # We also carry out some validation to
    # monitor loss and metrics on the test dataset
    # at the end of each epoch
        validation_data=(X_test_scaled, y_test),)
        #validation_data=(X_test, np.log10(y_test)),)
    model.save('./mlp_model_1.h5')
    return model, history_fine
new_model = tf.keras.models.load_model('./mlp_model.h5')

# for trainig with CPU (Slower) uncomment next line.
# model_fine, history_fine = train_fine(new_model)

# for trainig with GPU (Faster) uncomment next 2 lines. works in colab with GPU enabled
with tf.device("/device:GPU:0"):
    model_fine, history_fine = train_fine(new_model)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1600/2600
# 4/4 [==============================] - 1s 51ms/step - loss: 12.9099 - mae: 1.4545 - val_loss: 13.2327 - val_mae: 1.4610
# Epoch 1601/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.9024 - mae: 1.4574 - val_loss: 13.2231 - val_mae: 1.4570
# Epoch 1602/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8948 - mae: 1.4557 - val_loss: 13.2184 - val_mae: 1.4563
# Epoch 1603/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.8947 - mae: 1.4540 - val_loss: 13.2165 - val_mae: 1.4536
# Epoch 1604/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8913 - mae: 1.4543 - val_loss: 13.2109 - val_mae: 1.4564
# Epoch 1605/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8911 - mae: 1.4543 - val_loss: 13.2103 - val_mae: 1.4540
# Epoch 1606/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.8875 - mae: 1.4542 - val_loss: 13.2059 - val_mae: 1.4555
# Epoch 1607/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8883 - mae: 1.4545 - val_loss: 13.2044 - val_mae: 1.4557
# Epoch 1608/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.8880 - mae: 1.4560 - val_loss: 13.2006 - val_mae: 1.4565
# Epoch 1609/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.8813 - mae: 1.4544 - val_loss: 13.2011 - val_mae: 1.4520
# Epoch 1610/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.8818 - mae: 1.4502 - val_loss: 13.2042 - val_mae: 1.4492
# Epoch 1611/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.8802 - mae: 1.4497 - val_loss: 13.2005 - val_mae: 1.4517
# Epoch 1612/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.8770 - mae: 1.4526 - val_loss: 13.1944 - val_mae: 1.4563
# Epoch 1613/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.8779 - mae: 1.4575 - val_loss: 13.1922 - val_mae: 1.4582
# Epoch 1614/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.8750 - mae: 1.4562 - val_loss: 13.1910 - val_mae: 1.4543
# Epoch 1615/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8712 - mae: 1.4534 - val_loss: 13.1904 - val_mae: 1.4526
# Epoch 1616/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8756 - mae: 1.4506 - val_loss: 13.1892 - val_mae: 1.4506
# Epoch 1617/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8675 - mae: 1.4524 - val_loss: 13.1806 - val_mae: 1.4569
# Epoch 1618/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8837 - mae: 1.4600 - val_loss: 13.1802 - val_mae: 1.4603
# Epoch 1619/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8670 - mae: 1.4576 - val_loss: 13.1790 - val_mae: 1.4527
# Epoch 1620/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.8617 - mae: 1.4506 - val_loss: 13.1844 - val_mae: 1.4480
# Epoch 1621/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8661 - mae: 1.4486 - val_loss: 13.1789 - val_mae: 1.4497
# Epoch 1622/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8628 - mae: 1.4494 - val_loss: 13.1786 - val_mae: 1.4509
# Epoch 1623/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.8618 - mae: 1.4540 - val_loss: 13.1712 - val_mae: 1.4579
# Epoch 1624/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.8606 - mae: 1.4581 - val_loss: 13.1694 - val_mae: 1.4574
# Epoch 1625/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.8560 - mae: 1.4572 - val_loss: 13.1670 - val_mae: 1.4558
# Epoch 1626/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.8543 - mae: 1.4542 - val_loss: 13.1698 - val_mae: 1.4518
# Epoch 1627/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8538 - mae: 1.4516 - val_loss: 13.1665 - val_mae: 1.4518
# Epoch 1628/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.8518 - mae: 1.4511 - val_loss: 13.1638 - val_mae: 1.4513
# Epoch 1629/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.8516 - mae: 1.4528 - val_loss: 13.1573 - val_mae: 1.4551
# Epoch 1630/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8504 - mae: 1.4535 - val_loss: 13.1551 - val_mae: 1.4519
# Epoch 1631/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8463 - mae: 1.4524 - val_loss: 13.1545 - val_mae: 1.4521
# Epoch 1632/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.8465 - mae: 1.4526 - val_loss: 13.1536 - val_mae: 1.4525
# Epoch 1633/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8433 - mae: 1.4532 - val_loss: 13.1516 - val_mae: 1.4528
# Epoch 1634/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.8471 - mae: 1.4511 - val_loss: 13.1557 - val_mae: 1.4491
# Epoch 1635/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8400 - mae: 1.4498 - val_loss: 13.1490 - val_mae: 1.4515
# Epoch 1636/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8386 - mae: 1.4528 - val_loss: 13.1421 - val_mae: 1.4549
# Epoch 1637/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.8379 - mae: 1.4543 - val_loss: 13.1416 - val_mae: 1.4537
# Epoch 1638/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.8361 - mae: 1.4531 - val_loss: 13.1403 - val_mae: 1.4522
# Epoch 1639/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8340 - mae: 1.4527 - val_loss: 13.1384 - val_mae: 1.4532
# Epoch 1640/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.8331 - mae: 1.4523 - val_loss: 13.1382 - val_mae: 1.4517
# Epoch 1641/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8381 - mae: 1.4543 - val_loss: 13.1321 - val_mae: 1.4556
# Epoch 1642/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8305 - mae: 1.4538 - val_loss: 13.1364 - val_mae: 1.4510
# Epoch 1643/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8309 - mae: 1.4511 - val_loss: 13.1353 - val_mae: 1.4509
# Epoch 1644/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.8381 - mae: 1.4488 - val_loss: 13.1430 - val_mae: 1.4480
# Epoch 1645/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8264 - mae: 1.4509 - val_loss: 13.1299 - val_mae: 1.4544
# Epoch 1646/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8253 - mae: 1.4560 - val_loss: 13.1261 - val_mae: 1.4572
# Epoch 1647/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8249 - mae: 1.4572 - val_loss: 13.1237 - val_mae: 1.4545
# Epoch 1648/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.8256 - mae: 1.4514 - val_loss: 13.1317 - val_mae: 1.4471
# Epoch 1649/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8245 - mae: 1.4496 - val_loss: 13.1242 - val_mae: 1.4511
# Epoch 1650/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8197 - mae: 1.4514 - val_loss: 13.1192 - val_mae: 1.4519
# Epoch 1651/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8178 - mae: 1.4519 - val_loss: 13.1192 - val_mae: 1.4519
# Epoch 1652/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8147 - mae: 1.4529 - val_loss: 13.1176 - val_mae: 1.4530
# Epoch 1653/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8210 - mae: 1.4517 - val_loss: 13.1203 - val_mae: 1.4507
# Epoch 1654/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8133 - mae: 1.4529 - val_loss: 13.1127 - val_mae: 1.4547
# Epoch 1655/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8192 - mae: 1.4570 - val_loss: 13.1099 - val_mae: 1.4551
# Epoch 1656/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8104 - mae: 1.4527 - val_loss: 13.1147 - val_mae: 1.4481
# Epoch 1657/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8124 - mae: 1.4475 - val_loss: 13.1199 - val_mae: 1.4457
# Epoch 1658/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8080 - mae: 1.4471 - val_loss: 13.1119 - val_mae: 1.4494
# Epoch 1659/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8047 - mae: 1.4517 - val_loss: 13.1040 - val_mae: 1.4544
# Epoch 1660/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.8057 - mae: 1.4555 - val_loss: 13.1025 - val_mae: 1.4553
# Epoch 1661/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.8064 - mae: 1.4537 - val_loss: 13.1046 - val_mae: 1.4508
# Epoch 1662/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.8019 - mae: 1.4514 - val_loss: 13.1032 - val_mae: 1.4507
# Epoch 1663/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.8008 - mae: 1.4501 - val_loss: 13.1015 - val_mae: 1.4496
# Epoch 1664/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7998 - mae: 1.4518 - val_loss: 13.0961 - val_mae: 1.4527
# Epoch 1665/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7970 - mae: 1.4529 - val_loss: 13.0954 - val_mae: 1.4518
# Epoch 1666/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.7986 - mae: 1.4510 - val_loss: 13.0959 - val_mae: 1.4491
# Epoch 1667/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7945 - mae: 1.4504 - val_loss: 13.0916 - val_mae: 1.4510
# Epoch 1668/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7930 - mae: 1.4522 - val_loss: 13.0887 - val_mae: 1.4526
# Epoch 1669/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7956 - mae: 1.4545 - val_loss: 13.0847 - val_mae: 1.4534
# Epoch 1670/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.7944 - mae: 1.4533 - val_loss: 13.0830 - val_mae: 1.4511
# Epoch 1671/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7986 - mae: 1.4485 - val_loss: 13.0974 - val_mae: 1.4443
# Epoch 1672/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7899 - mae: 1.4464 - val_loss: 13.0879 - val_mae: 1.4483
# Epoch 1673/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7873 - mae: 1.4522 - val_loss: 13.0808 - val_mae: 1.4550
# Epoch 1674/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7863 - mae: 1.4556 - val_loss: 13.0796 - val_mae: 1.4549
# Epoch 1675/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7868 - mae: 1.4557 - val_loss: 13.0792 - val_mae: 1.4530
# Epoch 1676/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7837 - mae: 1.4515 - val_loss: 13.0818 - val_mae: 1.4477
# Epoch 1677/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7815 - mae: 1.4484 - val_loss: 13.0783 - val_mae: 1.4480
# Epoch 1678/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7841 - mae: 1.4503 - val_loss: 13.0729 - val_mae: 1.4498
# Epoch 1679/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7803 - mae: 1.4521 - val_loss: 13.0694 - val_mae: 1.4514
# Epoch 1680/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7772 - mae: 1.4524 - val_loss: 13.0696 - val_mae: 1.4503
# Epoch 1681/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7756 - mae: 1.4511 - val_loss: 13.0706 - val_mae: 1.4489
# Epoch 1682/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.7766 - mae: 1.4498 - val_loss: 13.0734 - val_mae: 1.4476
# Epoch 1683/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7798 - mae: 1.4480 - val_loss: 13.0732 - val_mae: 1.4479
# Epoch 1684/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7881 - mae: 1.4540 - val_loss: 13.0604 - val_mae: 1.4574
# Epoch 1685/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7803 - mae: 1.4590 - val_loss: 13.0616 - val_mae: 1.4555
# Epoch 1686/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7686 - mae: 1.4533 - val_loss: 13.0680 - val_mae: 1.4469
# Epoch 1687/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7758 - mae: 1.4458 - val_loss: 13.0817 - val_mae: 1.4429
# Epoch 1688/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7718 - mae: 1.4452 - val_loss: 13.0667 - val_mae: 1.4478
# Epoch 1689/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7675 - mae: 1.4520 - val_loss: 13.0576 - val_mae: 1.4551
# Epoch 1690/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7692 - mae: 1.4554 - val_loss: 13.0542 - val_mae: 1.4529
# Epoch 1691/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7650 - mae: 1.4541 - val_loss: 13.0528 - val_mae: 1.4514
# Epoch 1692/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7663 - mae: 1.4508 - val_loss: 13.0566 - val_mae: 1.4467
# Epoch 1693/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.7635 - mae: 1.4496 - val_loss: 13.0501 - val_mae: 1.4496
# Epoch 1694/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.7600 - mae: 1.4509 - val_loss: 13.0491 - val_mae: 1.4495
# Epoch 1695/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7601 - mae: 1.4495 - val_loss: 13.0494 - val_mae: 1.4479
# Epoch 1696/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7589 - mae: 1.4498 - val_loss: 13.0464 - val_mae: 1.4500
# Epoch 1697/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7566 - mae: 1.4514 - val_loss: 13.0461 - val_mae: 1.4502
# Epoch 1698/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.7575 - mae: 1.4503 - val_loss: 13.0478 - val_mae: 1.4480
# Epoch 1699/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7559 - mae: 1.4492 - val_loss: 13.0492 - val_mae: 1.4475
# Epoch 1700/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7553 - mae: 1.4503 - val_loss: 13.0438 - val_mae: 1.4505
# Epoch 1701/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7515 - mae: 1.4523 - val_loss: 13.0392 - val_mae: 1.4518
# Epoch 1702/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7527 - mae: 1.4536 - val_loss: 13.0374 - val_mae: 1.4512
# Epoch 1703/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7511 - mae: 1.4514 - val_loss: 13.0400 - val_mae: 1.4481
# Epoch 1704/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7538 - mae: 1.4509 - val_loss: 13.0333 - val_mae: 1.4498
# Epoch 1705/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.7551 - mae: 1.4525 - val_loss: 13.0311 - val_mae: 1.4495
# Epoch 1706/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7483 - mae: 1.4478 - val_loss: 13.0425 - val_mae: 1.4430
# Epoch 1707/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7476 - mae: 1.4455 - val_loss: 13.0371 - val_mae: 1.4452
# Epoch 1708/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7462 - mae: 1.4469 - val_loss: 13.0358 - val_mae: 1.4474
# Epoch 1709/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7428 - mae: 1.4503 - val_loss: 13.0321 - val_mae: 1.4511
# Epoch 1710/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7430 - mae: 1.4520 - val_loss: 13.0314 - val_mae: 1.4511
# Epoch 1711/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7439 - mae: 1.4519 - val_loss: 13.0272 - val_mae: 1.4517
# Epoch 1712/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7399 - mae: 1.4537 - val_loss: 13.0234 - val_mae: 1.4528
# Epoch 1713/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7394 - mae: 1.4541 - val_loss: 13.0232 - val_mae: 1.4509
# Epoch 1714/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7380 - mae: 1.4513 - val_loss: 13.0229 - val_mae: 1.4468
# Epoch 1715/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.7384 - mae: 1.4464 - val_loss: 13.0297 - val_mae: 1.4436
# Epoch 1716/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7436 - mae: 1.4441 - val_loss: 13.0339 - val_mae: 1.4435
# Epoch 1717/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7338 - mae: 1.4477 - val_loss: 13.0183 - val_mae: 1.4515
# Epoch 1718/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7369 - mae: 1.4555 - val_loss: 13.0140 - val_mae: 1.4564
# Epoch 1719/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7416 - mae: 1.4545 - val_loss: 13.0168 - val_mae: 1.4491
# Epoch 1720/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7310 - mae: 1.4505 - val_loss: 13.0144 - val_mae: 1.4485
# Epoch 1721/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7315 - mae: 1.4513 - val_loss: 13.0100 - val_mae: 1.4493
# Epoch 1722/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.7302 - mae: 1.4490 - val_loss: 13.0153 - val_mae: 1.4453
# Epoch 1723/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7403 - mae: 1.4495 - val_loss: 13.0073 - val_mae: 1.4493
# Epoch 1724/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7266 - mae: 1.4494 - val_loss: 13.0125 - val_mae: 1.4458
# Epoch 1725/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7326 - mae: 1.4459 - val_loss: 13.0192 - val_mae: 1.4435
# Epoch 1726/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7243 - mae: 1.4472 - val_loss: 13.0091 - val_mae: 1.4489
# Epoch 1727/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.7226 - mae: 1.4523 - val_loss: 13.0040 - val_mae: 1.4531
# Epoch 1728/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7248 - mae: 1.4541 - val_loss: 13.0049 - val_mae: 1.4507
# Epoch 1729/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.7228 - mae: 1.4517 - val_loss: 13.0022 - val_mae: 1.4488
# Epoch 1730/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7230 - mae: 1.4517 - val_loss: 13.0010 - val_mae: 1.4490
# Epoch 1731/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7206 - mae: 1.4486 - val_loss: 13.0040 - val_mae: 1.4449
# Epoch 1732/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.7222 - mae: 1.4461 - val_loss: 13.0045 - val_mae: 1.4453
# Epoch 1733/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7221 - mae: 1.4502 - val_loss: 12.9955 - val_mae: 1.4519
# Epoch 1734/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.7167 - mae: 1.4535 - val_loss: 12.9937 - val_mae: 1.4509
# Epoch 1735/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.7139 - mae: 1.4513 - val_loss: 12.9973 - val_mae: 1.4465
# Epoch 1736/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7171 - mae: 1.4465 - val_loss: 13.0047 - val_mae: 1.4428
# Epoch 1737/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7176 - mae: 1.4474 - val_loss: 12.9905 - val_mae: 1.4486
# Epoch 1738/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.7143 - mae: 1.4522 - val_loss: 12.9883 - val_mae: 1.4506
# Epoch 1739/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.7174 - mae: 1.4493 - val_loss: 12.9982 - val_mae: 1.4450
# Epoch 1740/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.7095 - mae: 1.4478 - val_loss: 12.9926 - val_mae: 1.4471
# Epoch 1741/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.7094 - mae: 1.4495 - val_loss: 12.9877 - val_mae: 1.4489
# Epoch 1742/2600
# 4/4 [==============================] - 0s 35ms/step - loss: 12.7076 - mae: 1.4508 - val_loss: 12.9875 - val_mae: 1.4486
# Epoch 1743/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.7085 - mae: 1.4510 - val_loss: 12.9842 - val_mae: 1.4493
# Epoch 1744/2600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.7166 - mae: 1.4485 - val_loss: 12.9958 - val_mae: 1.4437
# Epoch 1745/2600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.7056 - mae: 1.4461 - val_loss: 12.9877 - val_mae: 1.4465
# Epoch 1746/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.7004 - mae: 1.4502 - val_loss: 12.9793 - val_mae: 1.4514
# Epoch 1747/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.7045 - mae: 1.4528 - val_loss: 12.9784 - val_mae: 1.4509
# Epoch 1748/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.7030 - mae: 1.4525 - val_loss: 12.9754 - val_mae: 1.4499
# Epoch 1749/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.7028 - mae: 1.4498 - val_loss: 12.9799 - val_mae: 1.4455
# Epoch 1750/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.7032 - mae: 1.4464 - val_loss: 12.9817 - val_mae: 1.4450
# Epoch 1751/2600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.6980 - mae: 1.4476 - val_loss: 12.9769 - val_mae: 1.4473
# Epoch 1752/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.7011 - mae: 1.4489 - val_loss: 12.9765 - val_mae: 1.4479
# Epoch 1753/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.6966 - mae: 1.4514 - val_loss: 12.9692 - val_mae: 1.4524
# Epoch 1754/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.7032 - mae: 1.4564 - val_loss: 12.9675 - val_mae: 1.4536
# Epoch 1755/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.6987 - mae: 1.4535 - val_loss: 12.9730 - val_mae: 1.4453
# Epoch 1756/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.6980 - mae: 1.4477 - val_loss: 12.9729 - val_mae: 1.4442
# Epoch 1757/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.7074 - mae: 1.4440 - val_loss: 12.9878 - val_mae: 1.4407
# Epoch 1758/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.6918 - mae: 1.4450 - val_loss: 12.9687 - val_mae: 1.4476
# Epoch 1759/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.6911 - mae: 1.4520 - val_loss: 12.9659 - val_mae: 1.4528
# Epoch 1760/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.6941 - mae: 1.4547 - val_loss: 12.9626 - val_mae: 1.4515
# Epoch 1761/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.6908 - mae: 1.4520 - val_loss: 12.9660 - val_mae: 1.4460
# Epoch 1762/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.6910 - mae: 1.4456 - val_loss: 12.9760 - val_mae: 1.4411
# Epoch 1763/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.6894 - mae: 1.4448 - val_loss: 12.9645 - val_mae: 1.4449
# Epoch 1764/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.6878 - mae: 1.4479 - val_loss: 12.9621 - val_mae: 1.4468
# Epoch 1765/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.6868 - mae: 1.4510 - val_loss: 12.9601 - val_mae: 1.4508
# Epoch 1766/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.6868 - mae: 1.4530 - val_loss: 12.9579 - val_mae: 1.4495
# Epoch 1767/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.6846 - mae: 1.4518 - val_loss: 12.9584 - val_mae: 1.4471
# Epoch 1768/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.6886 - mae: 1.4466 - val_loss: 12.9704 - val_mae: 1.4419
# Epoch 1769/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.6837 - mae: 1.4447 - val_loss: 12.9645 - val_mae: 1.4439
# Epoch 1770/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.6845 - mae: 1.4497 - val_loss: 12.9515 - val_mae: 1.4510
# Epoch 1771/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.6808 - mae: 1.4539 - val_loss: 12.9517 - val_mae: 1.4512
# Epoch 1772/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.6820 - mae: 1.4505 - val_loss: 12.9578 - val_mae: 1.4453
# Epoch 1773/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.6810 - mae: 1.4462 - val_loss: 12.9614 - val_mae: 1.4433
# Epoch 1774/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6773 - mae: 1.4463 - val_loss: 12.9525 - val_mae: 1.4469
# Epoch 1775/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6841 - mae: 1.4524 - val_loss: 12.9474 - val_mae: 1.4523
# Epoch 1776/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6785 - mae: 1.4521 - val_loss: 12.9516 - val_mae: 1.4465
# Epoch 1777/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6767 - mae: 1.4466 - val_loss: 12.9602 - val_mae: 1.4422
# Epoch 1778/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6756 - mae: 1.4461 - val_loss: 12.9497 - val_mae: 1.4464
# Epoch 1779/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.6721 - mae: 1.4500 - val_loss: 12.9440 - val_mae: 1.4489
# Epoch 1780/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6717 - mae: 1.4506 - val_loss: 12.9431 - val_mae: 1.4476
# Epoch 1781/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6734 - mae: 1.4484 - val_loss: 12.9443 - val_mae: 1.4457
# Epoch 1782/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6689 - mae: 1.4480 - val_loss: 12.9423 - val_mae: 1.4460
# Epoch 1783/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6681 - mae: 1.4480 - val_loss: 12.9424 - val_mae: 1.4453
# Epoch 1784/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6673 - mae: 1.4474 - val_loss: 12.9426 - val_mae: 1.4454
# Epoch 1785/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.6669 - mae: 1.4480 - val_loss: 12.9405 - val_mae: 1.4463
# Epoch 1786/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6648 - mae: 1.4492 - val_loss: 12.9383 - val_mae: 1.4477
# Epoch 1787/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6654 - mae: 1.4507 - val_loss: 12.9358 - val_mae: 1.4480
# Epoch 1788/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.6639 - mae: 1.4499 - val_loss: 12.9344 - val_mae: 1.4463
# Epoch 1789/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6631 - mae: 1.4492 - val_loss: 12.9329 - val_mae: 1.4463
# Epoch 1790/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6671 - mae: 1.4468 - val_loss: 12.9395 - val_mae: 1.4433
# Epoch 1791/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6630 - mae: 1.4466 - val_loss: 12.9320 - val_mae: 1.4466
# Epoch 1792/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6697 - mae: 1.4522 - val_loss: 12.9280 - val_mae: 1.4497
# Epoch 1793/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6596 - mae: 1.4502 - val_loss: 12.9325 - val_mae: 1.4444
# Epoch 1794/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6574 - mae: 1.4468 - val_loss: 12.9352 - val_mae: 1.4434
# Epoch 1795/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6636 - mae: 1.4447 - val_loss: 12.9413 - val_mae: 1.4409
# Epoch 1796/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6561 - mae: 1.4455 - val_loss: 12.9291 - val_mae: 1.4464
# Epoch 1797/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.6615 - mae: 1.4523 - val_loss: 12.9233 - val_mae: 1.4518
# Epoch 1798/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.6579 - mae: 1.4533 - val_loss: 12.9236 - val_mae: 1.4482
# Epoch 1799/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6530 - mae: 1.4497 - val_loss: 12.9283 - val_mae: 1.4443
# Epoch 1800/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6550 - mae: 1.4453 - val_loss: 12.9355 - val_mae: 1.4411
# Epoch 1801/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.6545 - mae: 1.4448 - val_loss: 12.9256 - val_mae: 1.4438
# Epoch 1802/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6540 - mae: 1.4486 - val_loss: 12.9204 - val_mae: 1.4480
# Epoch 1803/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6501 - mae: 1.4499 - val_loss: 12.9221 - val_mae: 1.4459
# Epoch 1804/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.6498 - mae: 1.4477 - val_loss: 12.9246 - val_mae: 1.4445
# Epoch 1805/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6493 - mae: 1.4476 - val_loss: 12.9232 - val_mae: 1.4451
# Epoch 1806/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6576 - mae: 1.4506 - val_loss: 12.9155 - val_mae: 1.4491
# Epoch 1807/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.6460 - mae: 1.4509 - val_loss: 12.9192 - val_mae: 1.4459
# Epoch 1808/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6474 - mae: 1.4466 - val_loss: 12.9289 - val_mae: 1.4421
# Epoch 1809/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.6509 - mae: 1.4452 - val_loss: 12.9221 - val_mae: 1.4445
# Epoch 1810/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.6471 - mae: 1.4493 - val_loss: 12.9155 - val_mae: 1.4480
# Epoch 1811/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6438 - mae: 1.4493 - val_loss: 12.9192 - val_mae: 1.4447
# Epoch 1812/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.6431 - mae: 1.4482 - val_loss: 12.9157 - val_mae: 1.4462
# Epoch 1813/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6434 - mae: 1.4483 - val_loss: 12.9167 - val_mae: 1.4438
# Epoch 1814/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6431 - mae: 1.4461 - val_loss: 12.9132 - val_mae: 1.4442
# Epoch 1815/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.6440 - mae: 1.4489 - val_loss: 12.9060 - val_mae: 1.4472
# Epoch 1816/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.6401 - mae: 1.4491 - val_loss: 12.9096 - val_mae: 1.4446
# Epoch 1817/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.6427 - mae: 1.4480 - val_loss: 12.9078 - val_mae: 1.4455
# Epoch 1818/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.6376 - mae: 1.4476 - val_loss: 12.9120 - val_mae: 1.4430
# Epoch 1819/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6408 - mae: 1.4445 - val_loss: 12.9183 - val_mae: 1.4414
# Epoch 1820/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.6370 - mae: 1.4454 - val_loss: 12.9098 - val_mae: 1.4456
# Epoch 1821/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6373 - mae: 1.4500 - val_loss: 12.9022 - val_mae: 1.4493
# Epoch 1822/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6393 - mae: 1.4516 - val_loss: 12.9009 - val_mae: 1.4488
# Epoch 1823/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6386 - mae: 1.4496 - val_loss: 12.9112 - val_mae: 1.4434
# Epoch 1824/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6387 - mae: 1.4472 - val_loss: 12.9027 - val_mae: 1.4453
# Epoch 1825/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6331 - mae: 1.4473 - val_loss: 12.9055 - val_mae: 1.4438
# Epoch 1826/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6353 - mae: 1.4451 - val_loss: 12.9093 - val_mae: 1.4418
# Epoch 1827/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6306 - mae: 1.4451 - val_loss: 12.9029 - val_mae: 1.4444
# Epoch 1828/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6290 - mae: 1.4482 - val_loss: 12.8978 - val_mae: 1.4470
# Epoch 1829/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6321 - mae: 1.4490 - val_loss: 12.8988 - val_mae: 1.4464
# Epoch 1830/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.6286 - mae: 1.4487 - val_loss: 12.8993 - val_mae: 1.4455
# Epoch 1831/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6304 - mae: 1.4492 - val_loss: 12.8945 - val_mae: 1.4469
# Epoch 1832/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.6283 - mae: 1.4491 - val_loss: 12.8969 - val_mae: 1.4442
# Epoch 1833/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.6259 - mae: 1.4474 - val_loss: 12.8962 - val_mae: 1.4439
# Epoch 1834/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6279 - mae: 1.4446 - val_loss: 12.9021 - val_mae: 1.4403
# Epoch 1835/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.6271 - mae: 1.4433 - val_loss: 12.8995 - val_mae: 1.4424
# Epoch 1836/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6256 - mae: 1.4491 - val_loss: 12.8877 - val_mae: 1.4501
# Epoch 1837/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6306 - mae: 1.4505 - val_loss: 12.8919 - val_mae: 1.4457
# Epoch 1838/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6322 - mae: 1.4516 - val_loss: 12.8852 - val_mae: 1.4497
# Epoch 1839/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6207 - mae: 1.4513 - val_loss: 12.8878 - val_mae: 1.4448
# Epoch 1840/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6220 - mae: 1.4454 - val_loss: 12.9028 - val_mae: 1.4391
# Epoch 1841/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6237 - mae: 1.4426 - val_loss: 12.8940 - val_mae: 1.4418
# Epoch 1842/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.6211 - mae: 1.4449 - val_loss: 12.8930 - val_mae: 1.4440
# Epoch 1843/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6188 - mae: 1.4494 - val_loss: 12.8828 - val_mae: 1.4490
# Epoch 1844/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.6201 - mae: 1.4526 - val_loss: 12.8812 - val_mae: 1.4494
# Epoch 1845/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6167 - mae: 1.4508 - val_loss: 12.8852 - val_mae: 1.4436
# Epoch 1846/2600
# 4/4 [==============================] - 0s 13ms/step - loss: 12.6204 - mae: 1.4442 - val_loss: 12.8943 - val_mae: 1.4397
# Epoch 1847/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6183 - mae: 1.4430 - val_loss: 12.8898 - val_mae: 1.4410
# Epoch 1848/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.6144 - mae: 1.4458 - val_loss: 12.8819 - val_mae: 1.4463
# Epoch 1849/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.6162 - mae: 1.4512 - val_loss: 12.8789 - val_mae: 1.4496
# Epoch 1850/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6161 - mae: 1.4511 - val_loss: 12.8830 - val_mae: 1.4456
# Epoch 1851/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6126 - mae: 1.4486 - val_loss: 12.8805 - val_mae: 1.4448
# Epoch 1852/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6128 - mae: 1.4465 - val_loss: 12.8843 - val_mae: 1.4419
# Epoch 1853/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6110 - mae: 1.4459 - val_loss: 12.8799 - val_mae: 1.4441
# Epoch 1854/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6095 - mae: 1.4486 - val_loss: 12.8754 - val_mae: 1.4464
# Epoch 1855/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.6090 - mae: 1.4488 - val_loss: 12.8764 - val_mae: 1.4448
# Epoch 1856/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6091 - mae: 1.4466 - val_loss: 12.8810 - val_mae: 1.4420
# Epoch 1857/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6070 - mae: 1.4454 - val_loss: 12.8783 - val_mae: 1.4436
# Epoch 1858/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6097 - mae: 1.4490 - val_loss: 12.8715 - val_mae: 1.4469
# Epoch 1859/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6062 - mae: 1.4491 - val_loss: 12.8751 - val_mae: 1.4440
# Epoch 1860/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6046 - mae: 1.4469 - val_loss: 12.8744 - val_mae: 1.4429
# Epoch 1861/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6048 - mae: 1.4453 - val_loss: 12.8760 - val_mae: 1.4418
# Epoch 1862/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.6063 - mae: 1.4447 - val_loss: 12.8756 - val_mae: 1.4420
# Epoch 1863/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6033 - mae: 1.4480 - val_loss: 12.8650 - val_mae: 1.4479
# Epoch 1864/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6076 - mae: 1.4518 - val_loss: 12.8662 - val_mae: 1.4473
# Epoch 1865/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6022 - mae: 1.4485 - val_loss: 12.8721 - val_mae: 1.4429
# Epoch 1866/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6018 - mae: 1.4466 - val_loss: 12.8705 - val_mae: 1.4434
# Epoch 1867/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.6007 - mae: 1.4469 - val_loss: 12.8677 - val_mae: 1.4439
# Epoch 1868/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5993 - mae: 1.4473 - val_loss: 12.8688 - val_mae: 1.4432
# Epoch 1869/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.5990 - mae: 1.4459 - val_loss: 12.8698 - val_mae: 1.4427
# Epoch 1870/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.6016 - mae: 1.4454 - val_loss: 12.8699 - val_mae: 1.4418
# Epoch 1871/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.6074 - mae: 1.4482 - val_loss: 12.8588 - val_mae: 1.4481
# Epoch 1872/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5972 - mae: 1.4501 - val_loss: 12.8638 - val_mae: 1.4443
# Epoch 1873/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5941 - mae: 1.4466 - val_loss: 12.8677 - val_mae: 1.4414
# Epoch 1874/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5974 - mae: 1.4452 - val_loss: 12.8636 - val_mae: 1.4423
# Epoch 1875/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5936 - mae: 1.4459 - val_loss: 12.8623 - val_mae: 1.4427
# Epoch 1876/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5942 - mae: 1.4460 - val_loss: 12.8651 - val_mae: 1.4427
# Epoch 1877/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5926 - mae: 1.4468 - val_loss: 12.8601 - val_mae: 1.4453
# Epoch 1878/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.5953 - mae: 1.4504 - val_loss: 12.8558 - val_mae: 1.4479
# Epoch 1879/2600
# 4/4 [==============================] - 0s 35ms/step - loss: 12.5929 - mae: 1.4507 - val_loss: 12.8555 - val_mae: 1.4447
# Epoch 1880/2600
# 4/4 [==============================] - 0s 28ms/step - loss: 12.5925 - mae: 1.4449 - val_loss: 12.8684 - val_mae: 1.4385
# Epoch 1881/2600
# 4/4 [==============================] - 0s 31ms/step - loss: 12.6016 - mae: 1.4407 - val_loss: 12.8768 - val_mae: 1.4375
# Epoch 1882/2600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.5970 - mae: 1.4450 - val_loss: 12.8525 - val_mae: 1.4477
# Epoch 1883/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5950 - mae: 1.4531 - val_loss: 12.8500 - val_mae: 1.4500
# Epoch 1884/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.5925 - mae: 1.4517 - val_loss: 12.8564 - val_mae: 1.4437
# Epoch 1885/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5860 - mae: 1.4454 - val_loss: 12.8627 - val_mae: 1.4397
# Epoch 1886/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5882 - mae: 1.4434 - val_loss: 12.8591 - val_mae: 1.4408
# Epoch 1887/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5885 - mae: 1.4458 - val_loss: 12.8483 - val_mae: 1.4445
# Epoch 1888/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5904 - mae: 1.4461 - val_loss: 12.8551 - val_mae: 1.4425
# Epoch 1889/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.5832 - mae: 1.4465 - val_loss: 12.8494 - val_mae: 1.4448
# Epoch 1890/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5838 - mae: 1.4488 - val_loss: 12.8478 - val_mae: 1.4458
# Epoch 1891/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5849 - mae: 1.4475 - val_loss: 12.8531 - val_mae: 1.4429
# Epoch 1892/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5815 - mae: 1.4470 - val_loss: 12.8505 - val_mae: 1.4443
# Epoch 1893/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5813 - mae: 1.4476 - val_loss: 12.8459 - val_mae: 1.4444
# Epoch 1894/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5820 - mae: 1.4471 - val_loss: 12.8495 - val_mae: 1.4427
# Epoch 1895/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5805 - mae: 1.4454 - val_loss: 12.8498 - val_mae: 1.4421
# Epoch 1896/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5794 - mae: 1.4464 - val_loss: 12.8447 - val_mae: 1.4436
# Epoch 1897/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5787 - mae: 1.4482 - val_loss: 12.8399 - val_mae: 1.4458
# Epoch 1898/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5826 - mae: 1.4479 - val_loss: 12.8442 - val_mae: 1.4421
# Epoch 1899/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5779 - mae: 1.4466 - val_loss: 12.8396 - val_mae: 1.4440
# Epoch 1900/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5764 - mae: 1.4474 - val_loss: 12.8415 - val_mae: 1.4430
# Epoch 1901/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5746 - mae: 1.4463 - val_loss: 12.8443 - val_mae: 1.4426
# Epoch 1902/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5743 - mae: 1.4463 - val_loss: 12.8451 - val_mae: 1.4431
# Epoch 1903/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5751 - mae: 1.4464 - val_loss: 12.8420 - val_mae: 1.4440
# Epoch 1904/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5731 - mae: 1.4473 - val_loss: 12.8425 - val_mae: 1.4441
# Epoch 1905/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5770 - mae: 1.4473 - val_loss: 12.8463 - val_mae: 1.4431
# Epoch 1906/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.5734 - mae: 1.4482 - val_loss: 12.8356 - val_mae: 1.4462
# Epoch 1907/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5721 - mae: 1.4493 - val_loss: 12.8381 - val_mae: 1.4445
# Epoch 1908/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5795 - mae: 1.4461 - val_loss: 12.8467 - val_mae: 1.4400
# Epoch 1909/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5721 - mae: 1.4448 - val_loss: 12.8340 - val_mae: 1.4435
# Epoch 1910/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5700 - mae: 1.4476 - val_loss: 12.8313 - val_mae: 1.4445
# Epoch 1911/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5727 - mae: 1.4479 - val_loss: 12.8356 - val_mae: 1.4418
# Epoch 1912/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5698 - mae: 1.4440 - val_loss: 12.8400 - val_mae: 1.4402
# Epoch 1913/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5679 - mae: 1.4446 - val_loss: 12.8385 - val_mae: 1.4428
# Epoch 1914/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.5678 - mae: 1.4477 - val_loss: 12.8354 - val_mae: 1.4459
# Epoch 1915/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5672 - mae: 1.4486 - val_loss: 12.8372 - val_mae: 1.4447
# Epoch 1916/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.5662 - mae: 1.4478 - val_loss: 12.8336 - val_mae: 1.4436
# Epoch 1917/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5686 - mae: 1.4487 - val_loss: 12.8297 - val_mae: 1.4445
# Epoch 1918/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5657 - mae: 1.4484 - val_loss: 12.8279 - val_mae: 1.4433
# Epoch 1919/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5690 - mae: 1.4443 - val_loss: 12.8392 - val_mae: 1.4386
# Epoch 1920/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5643 - mae: 1.4424 - val_loss: 12.8356 - val_mae: 1.4407
# Epoch 1921/2600
# 4/4 [==============================] - 0s 14ms/step - loss: 12.5615 - mae: 1.4461 - val_loss: 12.8287 - val_mae: 1.4452
# Epoch 1922/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5694 - mae: 1.4509 - val_loss: 12.8267 - val_mae: 1.4468
# Epoch 1923/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5632 - mae: 1.4480 - val_loss: 12.8314 - val_mae: 1.4418
# Epoch 1924/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5613 - mae: 1.4458 - val_loss: 12.8324 - val_mae: 1.4412
# Epoch 1925/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.5601 - mae: 1.4451 - val_loss: 12.8276 - val_mae: 1.4417
# Epoch 1926/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.5619 - mae: 1.4463 - val_loss: 12.8257 - val_mae: 1.4421
# Epoch 1927/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5589 - mae: 1.4446 - val_loss: 12.8283 - val_mae: 1.4407
# Epoch 1928/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.5621 - mae: 1.4444 - val_loss: 12.8328 - val_mae: 1.4415
# Epoch 1929/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.5603 - mae: 1.4469 - val_loss: 12.8197 - val_mae: 1.4458
# Epoch 1930/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.5578 - mae: 1.4501 - val_loss: 12.8196 - val_mae: 1.4458
# Epoch 1931/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.5592 - mae: 1.4474 - val_loss: 12.8286 - val_mae: 1.4417
# Epoch 1932/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.5551 - mae: 1.4455 - val_loss: 12.8243 - val_mae: 1.4422
# Epoch 1933/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.5593 - mae: 1.4472 - val_loss: 12.8173 - val_mae: 1.4435
# Epoch 1934/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.5542 - mae: 1.4472 - val_loss: 12.8208 - val_mae: 1.4423
# Epoch 1935/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.5552 - mae: 1.4437 - val_loss: 12.8323 - val_mae: 1.4385
# Epoch 1936/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.5548 - mae: 1.4433 - val_loss: 12.8289 - val_mae: 1.4418
# Epoch 1937/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.5550 - mae: 1.4458 - val_loss: 12.8278 - val_mae: 1.4427
# Epoch 1938/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.5570 - mae: 1.4493 - val_loss: 12.8154 - val_mae: 1.4485
# Epoch 1939/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.5526 - mae: 1.4502 - val_loss: 12.8179 - val_mae: 1.4443
# Epoch 1940/2600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.5503 - mae: 1.4469 - val_loss: 12.8196 - val_mae: 1.4409
# Epoch 1941/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.5497 - mae: 1.4434 - val_loss: 12.8218 - val_mae: 1.4392
# Epoch 1942/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.5507 - mae: 1.4434 - val_loss: 12.8235 - val_mae: 1.4408
# Epoch 1943/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.5531 - mae: 1.4471 - val_loss: 12.8121 - val_mae: 1.4459
# Epoch 1944/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5492 - mae: 1.4500 - val_loss: 12.8133 - val_mae: 1.4458
# Epoch 1945/2600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.5483 - mae: 1.4480 - val_loss: 12.8188 - val_mae: 1.4415
# Epoch 1946/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.5476 - mae: 1.4436 - val_loss: 12.8225 - val_mae: 1.4389
# Epoch 1947/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.5468 - mae: 1.4434 - val_loss: 12.8167 - val_mae: 1.4412
# Epoch 1948/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.5498 - mae: 1.4437 - val_loss: 12.8203 - val_mae: 1.4403
# Epoch 1949/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.5500 - mae: 1.4465 - val_loss: 12.8124 - val_mae: 1.4452
# Epoch 1950/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.5457 - mae: 1.4484 - val_loss: 12.8123 - val_mae: 1.4439
# Epoch 1951/2600
# ...
# Epoch 2484/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3321 - mae: 1.4367 - val_loss: 12.6547 - val_mae: 1.4328
# Epoch 2485/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3405 - mae: 1.4423 - val_loss: 12.6345 - val_mae: 1.4425
# Epoch 2486/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3303 - mae: 1.4459 - val_loss: 12.6437 - val_mae: 1.4392
# Epoch 2487/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3303 - mae: 1.4439 - val_loss: 12.6425 - val_mae: 1.4377
# Epoch 2488/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.3280 - mae: 1.4409 - val_loss: 12.6498 - val_mae: 1.4357
# Epoch 2489/2600
# 4/4 [==============================] - 0s 27ms/step - loss: 12.3293 - mae: 1.4410 - val_loss: 12.6452 - val_mae: 1.4374
# Epoch 2490/2600
# 4/4 [==============================] - 0s 27ms/step - loss: 12.3271 - mae: 1.4414 - val_loss: 12.6514 - val_mae: 1.4368
# Epoch 2491/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3252 - mae: 1.4416 - val_loss: 12.6483 - val_mae: 1.4383
# Epoch 2492/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.3264 - mae: 1.4442 - val_loss: 12.6417 - val_mae: 1.4405
# Epoch 2493/2600
# 4/4 [==============================] - 0s 39ms/step - loss: 12.3338 - mae: 1.4429 - val_loss: 12.6582 - val_mae: 1.4357
# Epoch 2494/2600
# 4/4 [==============================] - 0s 34ms/step - loss: 12.3244 - mae: 1.4405 - val_loss: 12.6467 - val_mae: 1.4372
# Epoch 2495/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.3251 - mae: 1.4411 - val_loss: 12.6428 - val_mae: 1.4374
# Epoch 2496/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.3281 - mae: 1.4437 - val_loss: 12.6289 - val_mae: 1.4409
# Epoch 2497/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.3248 - mae: 1.4439 - val_loss: 12.6350 - val_mae: 1.4374
# Epoch 2498/2600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.3238 - mae: 1.4410 - val_loss: 12.6386 - val_mae: 1.4358
# Epoch 2499/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3234 - mae: 1.4397 - val_loss: 12.6413 - val_mae: 1.4350
# Epoch 2500/2600
# 4/4 [==============================] - 0s 28ms/step - loss: 12.3228 - mae: 1.4398 - val_loss: 12.6431 - val_mae: 1.4358
# Epoch 2501/2600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.3242 - mae: 1.4409 - val_loss: 12.6444 - val_mae: 1.4379
# Epoch 2502/2600
# 4/4 [==============================] - 0s 33ms/step - loss: 12.3245 - mae: 1.4433 - val_loss: 12.6374 - val_mae: 1.4404
# Epoch 2503/2600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.3242 - mae: 1.4451 - val_loss: 12.6412 - val_mae: 1.4405
# Epoch 2504/2600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.3312 - mae: 1.4419 - val_loss: 12.6633 - val_mae: 1.4344
# Epoch 2505/2600
# 4/4 [==============================] - 0s 33ms/step - loss: 12.3242 - mae: 1.4400 - val_loss: 12.6419 - val_mae: 1.4385
# Epoch 2506/2600
# 4/4 [==============================] - 0s 41ms/step - loss: 12.3236 - mae: 1.4421 - val_loss: 12.6427 - val_mae: 1.4374
# Epoch 2507/2600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.3231 - mae: 1.4417 - val_loss: 12.6385 - val_mae: 1.4384
# Epoch 2508/2600
# 4/4 [==============================] - 0s 28ms/step - loss: 12.3241 - mae: 1.4434 - val_loss: 12.6365 - val_mae: 1.4400
# Epoch 2509/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3251 - mae: 1.4428 - val_loss: 12.6440 - val_mae: 1.4369
# Epoch 2510/2600
# 4/4 [==============================] - 0s 28ms/step - loss: 12.3204 - mae: 1.4416 - val_loss: 12.6392 - val_mae: 1.4377
# Epoch 2511/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3230 - mae: 1.4434 - val_loss: 12.6300 - val_mae: 1.4403
# Epoch 2512/2600
# 4/4 [==============================] - 0s 32ms/step - loss: 12.3232 - mae: 1.4436 - val_loss: 12.6405 - val_mae: 1.4364
# Epoch 2513/2600
# 4/4 [==============================] - 0s 27ms/step - loss: 12.3209 - mae: 1.4408 - val_loss: 12.6437 - val_mae: 1.4360
# Epoch 2514/2600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.3198 - mae: 1.4407 - val_loss: 12.6408 - val_mae: 1.4372
# Epoch 2515/2600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.3192 - mae: 1.4415 - val_loss: 12.6415 - val_mae: 1.4374
# Epoch 2516/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3332 - mae: 1.4450 - val_loss: 12.6323 - val_mae: 1.4413
# Epoch 2517/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3200 - mae: 1.4426 - val_loss: 12.6581 - val_mae: 1.4342
# Epoch 2518/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.3331 - mae: 1.4367 - val_loss: 12.6787 - val_mae: 1.4308
# Epoch 2519/2600
# 4/4 [==============================] - 0s 29ms/step - loss: 12.3225 - mae: 1.4366 - val_loss: 12.6452 - val_mae: 1.4385
# Epoch 2520/2600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.3189 - mae: 1.4437 - val_loss: 12.6329 - val_mae: 1.4445
# Epoch 2521/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.3250 - mae: 1.4496 - val_loss: 12.6290 - val_mae: 1.4450
# Epoch 2522/2600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.3210 - mae: 1.4471 - val_loss: 12.6379 - val_mae: 1.4384
# Epoch 2523/2600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.3315 - mae: 1.4395 - val_loss: 12.6619 - val_mae: 1.4318
# Epoch 2524/2600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.3208 - mae: 1.4373 - val_loss: 12.6409 - val_mae: 1.4356
# Epoch 2525/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3382 - mae: 1.4445 - val_loss: 12.6186 - val_mae: 1.4453
# Epoch 2526/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3235 - mae: 1.4464 - val_loss: 12.6324 - val_mae: 1.4374
# Epoch 2527/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3182 - mae: 1.4392 - val_loss: 12.6496 - val_mae: 1.4325
# Epoch 2528/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3192 - mae: 1.4371 - val_loss: 12.6474 - val_mae: 1.4340
# Epoch 2529/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3171 - mae: 1.4388 - val_loss: 12.6421 - val_mae: 1.4372
# Epoch 2530/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3165 - mae: 1.4436 - val_loss: 12.6321 - val_mae: 1.4426
# Epoch 2531/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3183 - mae: 1.4459 - val_loss: 12.6342 - val_mae: 1.4412
# Epoch 2532/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3200 - mae: 1.4456 - val_loss: 12.6328 - val_mae: 1.4403
# Epoch 2533/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3147 - mae: 1.4436 - val_loss: 12.6429 - val_mae: 1.4361
# Epoch 2534/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3157 - mae: 1.4401 - val_loss: 12.6463 - val_mae: 1.4345
# Epoch 2535/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3163 - mae: 1.4379 - val_loss: 12.6514 - val_mae: 1.4336
# Epoch 2536/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3162 - mae: 1.4389 - val_loss: 12.6403 - val_mae: 1.4376
# Epoch 2537/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3144 - mae: 1.4429 - val_loss: 12.6341 - val_mae: 1.4409
# Epoch 2538/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3165 - mae: 1.4445 - val_loss: 12.6358 - val_mae: 1.4390
# Epoch 2539/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3465 - mae: 1.4400 - val_loss: 12.6624 - val_mae: 1.4335
# Epoch 2540/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3167 - mae: 1.4414 - val_loss: 12.6272 - val_mae: 1.4429
# Epoch 2541/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3192 - mae: 1.4461 - val_loss: 12.6257 - val_mae: 1.4413
# Epoch 2542/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.3172 - mae: 1.4432 - val_loss: 12.6344 - val_mae: 1.4368
# Epoch 2543/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.3149 - mae: 1.4408 - val_loss: 12.6384 - val_mae: 1.4356
# Epoch 2544/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3150 - mae: 1.4407 - val_loss: 12.6343 - val_mae: 1.4368
# Epoch 2545/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3121 - mae: 1.4420 - val_loss: 12.6307 - val_mae: 1.4386
# Epoch 2546/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3122 - mae: 1.4429 - val_loss: 12.6315 - val_mae: 1.4384
# Epoch 2547/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3135 - mae: 1.4424 - val_loss: 12.6364 - val_mae: 1.4372
# Epoch 2548/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3121 - mae: 1.4419 - val_loss: 12.6391 - val_mae: 1.4367
# Epoch 2549/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3142 - mae: 1.4413 - val_loss: 12.6446 - val_mae: 1.4359
# Epoch 2550/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.3164 - mae: 1.4388 - val_loss: 12.6507 - val_mae: 1.4344
# Epoch 2551/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3120 - mae: 1.4398 - val_loss: 12.6385 - val_mae: 1.4378
# Epoch 2552/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3184 - mae: 1.4440 - val_loss: 12.6261 - val_mae: 1.4408
# Epoch 2553/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.3135 - mae: 1.4448 - val_loss: 12.6265 - val_mae: 1.4393
# Epoch 2554/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3140 - mae: 1.4421 - val_loss: 12.6382 - val_mae: 1.4352
# Epoch 2555/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3120 - mae: 1.4389 - val_loss: 12.6389 - val_mae: 1.4347
# Epoch 2556/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3107 - mae: 1.4403 - val_loss: 12.6298 - val_mae: 1.4384
# Epoch 2557/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3119 - mae: 1.4416 - val_loss: 12.6346 - val_mae: 1.4375
# Epoch 2558/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3099 - mae: 1.4422 - val_loss: 12.6350 - val_mae: 1.4392
# Epoch 2559/2600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.3136 - mae: 1.4450 - val_loss: 12.6277 - val_mae: 1.4408
# Epoch 2560/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.3153 - mae: 1.4433 - val_loss: 12.6449 - val_mae: 1.4365
# Epoch 2561/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3111 - mae: 1.4421 - val_loss: 12.6331 - val_mae: 1.4386
# Epoch 2562/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3079 - mae: 1.4425 - val_loss: 12.6345 - val_mae: 1.4375
# Epoch 2563/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3176 - mae: 1.4436 - val_loss: 12.6256 - val_mae: 1.4391
# Epoch 2564/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3076 - mae: 1.4422 - val_loss: 12.6376 - val_mae: 1.4359
# Epoch 2565/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3107 - mae: 1.4391 - val_loss: 12.6514 - val_mae: 1.4337
# Epoch 2566/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3110 - mae: 1.4390 - val_loss: 12.6432 - val_mae: 1.4374
# Epoch 2567/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3098 - mae: 1.4438 - val_loss: 12.6278 - val_mae: 1.4416
# Epoch 2568/2600
# 4/4 [==============================] - 0s 15ms/step - loss: 12.3095 - mae: 1.4442 - val_loss: 12.6322 - val_mae: 1.4382
# Epoch 2569/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3147 - mae: 1.4436 - val_loss: 12.6253 - val_mae: 1.4388
# Epoch 2570/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3062 - mae: 1.4415 - val_loss: 12.6396 - val_mae: 1.4343
# Epoch 2571/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3095 - mae: 1.4380 - val_loss: 12.6522 - val_mae: 1.4332
# Epoch 2572/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3110 - mae: 1.4394 - val_loss: 12.6352 - val_mae: 1.4375
# Epoch 2573/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3108 - mae: 1.4407 - val_loss: 12.6357 - val_mae: 1.4376
# Epoch 2574/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.3095 - mae: 1.4412 - val_loss: 12.6371 - val_mae: 1.4379
# Epoch 2575/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3069 - mae: 1.4432 - val_loss: 12.6299 - val_mae: 1.4405
# Epoch 2576/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3111 - mae: 1.4434 - val_loss: 12.6384 - val_mae: 1.4380
# Epoch 2577/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3079 - mae: 1.4425 - val_loss: 12.6285 - val_mae: 1.4382
# Epoch 2578/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3062 - mae: 1.4421 - val_loss: 12.6323 - val_mae: 1.4373
# Epoch 2579/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3094 - mae: 1.4396 - val_loss: 12.6454 - val_mae: 1.4334
# Epoch 2580/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3062 - mae: 1.4380 - val_loss: 12.6396 - val_mae: 1.4355
# Epoch 2581/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3036 - mae: 1.4416 - val_loss: 12.6250 - val_mae: 1.4411
# Epoch 2582/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3121 - mae: 1.4465 - val_loss: 12.6219 - val_mae: 1.4420
# Epoch 2583/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3055 - mae: 1.4439 - val_loss: 12.6342 - val_mae: 1.4359
# Epoch 2584/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.3044 - mae: 1.4386 - val_loss: 12.6435 - val_mae: 1.4330
# Epoch 2585/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3096 - mae: 1.4392 - val_loss: 12.6317 - val_mae: 1.4376
# Epoch 2586/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3046 - mae: 1.4425 - val_loss: 12.6329 - val_mae: 1.4388
# Epoch 2587/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3037 - mae: 1.4434 - val_loss: 12.6319 - val_mae: 1.4385
# Epoch 2588/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3131 - mae: 1.4401 - val_loss: 12.6507 - val_mae: 1.4336
# Epoch 2589/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3095 - mae: 1.4400 - val_loss: 12.6228 - val_mae: 1.4390
# Epoch 2590/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3082 - mae: 1.4446 - val_loss: 12.6193 - val_mae: 1.4402
# Epoch 2591/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3040 - mae: 1.4436 - val_loss: 12.6323 - val_mae: 1.4364
# Epoch 2592/2600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.3176 - mae: 1.4375 - val_loss: 12.6603 - val_mae: 1.4307
# Epoch 2593/2600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.3105 - mae: 1.4354 - val_loss: 12.6445 - val_mae: 1.4355
# Epoch 2594/2600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.3028 - mae: 1.4429 - val_loss: 12.6254 - val_mae: 1.4440
# Epoch 2595/2600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.3064 - mae: 1.4480 - val_loss: 12.6270 - val_mae: 1.4433
# Epoch 2596/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3026 - mae: 1.4458 - val_loss: 12.6314 - val_mae: 1.4388
# Epoch 2597/2600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.3072 - mae: 1.4430 - val_loss: 12.6278 - val_mae: 1.4376
# Epoch 2598/2600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.3003 - mae: 1.4413 - val_loss: 12.6382 - val_mae: 1.4345
# Epoch 2599/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3089 - mae: 1.4368 - val_loss: 12.6534 - val_mae: 1.4312
# Epoch 2600/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.3063 - mae: 1.4380 - val_loss: 12.6248 - val_mae: 1.4389

# %%
# plot learning curves
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('MSE loss')
plt.plot((history_fine.history['loss']), label='train')
plt.plot((history_fine.history['val_loss']), label='test')
plt.legend()
plt.show()

# %% [markdown]
# Overfitting can be observed as the training loss continues to decrease with the Epochs, improving the accuracy, while the test loss shows a slower decrease. With more training epochs the test loss should reach an asymptotic value and not decrease anymore.

# %% [markdown]
# ### 7) Testing the trained model on the initial case study
#
# The trained model is now applied to a real case study, the GMI overpass of Medicane Ianos on 16/09/2020 seen before, and the reult will be compared with the surface precipitation estimates provided by the NASA Goddard Profiling Algorithm, the official GPM preciptiation product for the GMI radiometer. Some details on the GPROF algorithm can be found in <a href="https://gpm.nasa.gov/resources/documents/gpm-gprof-algorithm-theoretical-basis-document-atbd/">GPM GPROF Algorithm Theoretical Basis Document (ATBD)  </a>.

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap 
from mpl_toolkits.basemap import Basemap
import numpy as np
import h5py
import warnings

# defining the function to plot
def plot_rr_map(RR,lat,lon,colorAxisMin,colorAxisMax):
    # set the lat/lon borders of the map
    latborders=[34,40]
    lonborders=[14,22]
    m = Basemap(projection='merc',
        resolution='l',
        lat_ts=20,
        llcrnrlat=latborders[0],urcrnrlat=latborders[1],\
        llcrnrlon=lonborders[0],urcrnrlon=lonborders[1])

    
#E set min/max values of the colorbar
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        im1 = m.pcolor(lon[:],lat[:],RR[:],shading='nearest',cmap='turbo',latlon=True,vmin=colorAxisMin,vmax=colorAxisMax)
    m.drawcoastlines()
# set parallels and meridians

    dparal=2 #separation in deg between drawn parallels
    parallels = np.arange(latborders[0],latborders[1],dparal)
    dmerid=2 #separation in deg between drawn meridians
    meridians = np.arange(lonborders[0],lonborders[1],dmerid)
    m.drawparallels(parallels,labels=[1,0,0,0],fontsize=15)
    m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=15) 
# add colorbar.
    cbar = m.colorbar(location='right',pad="5%")
    cbar.set_label('Rainfall Rate [mm/h]')
    
gmi_file_path='./1C-R.GPM.GMI.XCAL2016-C.20200916-S130832-E144106.037225.V07A.HDF5'
hf=h5py.File(gmi_file_path,'r')
lat1=hf['S1/Latitude'][:]
lon1=hf['S1/Longitude'][:]
TB1=hf['S1/Tc'][:]
TB2=hf['S2/Tc'][:]
hf.close()

TB=np.concatenate((TB1,TB2,),axis=2)
TB=np.reshape(TB,(2963*221,13))
TB[np.any(TB<=0,axis=1),:]=np.NaN
TB = scaler.transform(TB)
predictions = model.predict(TB)
predictions = np.reshape(predictions,(2963,221))


gprof_file_path='./2A.GPM.GMI.GPROF2021v1.20200916-S130832-E144106.037225.V07A.HDF5'
hf=h5py.File(gprof_file_path,'r')
lat2=hf['S1/Latitude'][:]
lon2=hf['S1/Longitude'][:]
gprof_rr=hf['S1/surfacePrecipitation'][:]
hf.close()
# Out:
# 20464/20464 [==============================] - 28s 1ms/step

# %%
fig = plt.figure(figsize=(24,16))
ax = fig.add_subplot(121)
plot_rr_map(predictions,lat1,lon1,0,40)
plt.title('Exercise1 model',fontsize=12)
ax = fig.add_subplot(122)
plot_rr_map(gprof_rr,lat2,lon2,0,40)
plt.title('GPROF',fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-976f58a3e128> in <cell line: 3>()
#       1 fig = plt.figure(figsize=(24,16))
#       2 ax = fig.add_subplot(121)
# ----> 3 plot_rr_map(predictions,lat1,lon1,0,40)
#       4 plt.title('Exercise1 model',fontsize=12)
#       5 ax = fig.add_subplot(122)
#
# <ipython-input-13-0713104f2261> in plot_rr_map(RR, lat, lon, colorAxisMin, colorAxisMax)
#      32     m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=15)
#      33 # add colorbar.
# ---> 34     cbar = m.colorbar(location='right',pad="5%")
#      35     cbar.set_label('Rainfall Rate [mm/h]')
#      36
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/basemap/__init__.py in colorbar(self, mappable, location, size, pad, fig, ax, **kwargs)
#    4640         else:
#    4641             raise ValueError('location must be top,bottom,left or right')
# -> 4642         cax = divider.append_axes(location, size=size, pad=pad)
#    4643         # create colorbar.
#    4644         cb = fig.colorbar(mappable,orientation=orientation,cax=cax,**kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     382             # Early return in the simple, non-deprecated case (much faster than
#     383             # calling bind()).
# --> 384             return func(*inner_args, **inner_kwargs)
#     385         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     386         if is_varargs and arguments.get(name):
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axes_grid1/axes_divider.py in append_axes(self, position, size, pad, add_to_figure, axes_class, **kwargs)
#     523             "top": (self.new_vertical, False),
#     524         }, position=position)
# --> 525         ax = create_axes(
#     526             size, pad, pack_start=pack_start, axes_class=axes_class, **kwargs)
#     527         if add_to_figure:
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axes_grid1/axes_divider.py in new_horizontal(self, size, pad, pack_start, **kwargs)
#     457             locator = self.new_locator(
#     458                 nx=len(self._horizontal) - 1, ny=self._yrefindex)
# --> 459         ax = self._get_new_axes(**kwargs)
#     460         ax.set_axes_locator(locator)
#     461         return ax
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axes_grid1/axes_divider.py in _get_new_axes(self, axes_class, **kwargs)
#     423         if axes_class is None:
#     424             if isinstance(axes, SubplotBase):
# --> 425                 axes_class = axes._axes_class
#     426             else:
#     427                 axes_class = type(axes)
#
# AttributeError: 'Axes' object has no attribute '_axes_class'

# %% [markdown]
# The result obtained by our NN model seems quite acceptable, the rainfall patterns predicted by our model are quite similar to those of GPROF, which is based on a physically-based Bayesian approach and is a very complex algorithm. It is important to highlight that:
#  1. The GMI observation of Madicane Ianos is not included in the training dataset (training dataset is built from 10 orbits of March 2014, while Medicane Ianos occured on 16/09/2020).
#  2. The NN model precipitation rate estimates over land and coastal areas are not reliable, as the training dataset does not include measurements over land (the precipitation retrieval over land is much more complex than over ocean and it has not been address in this exercise).
#  3. The high rainfall rates are underestimated, probably due to the small size of the training dataset, since intense rainfall is rare and probably it is not well represented in our limited-size training dataset.
#  4. Very low precipitation rates are present also in areas where the GPROF algorithm does not predict any precipitation, since the training dataset includes only pixels with precipitation (rainfall rate > 0 mm/h), and it has not learned how to disciminate between rain and no-rain pixels (precipitation detection is often handled using a different ML approach).
#  5. Remember that the trainig dataset is very small (10 orbits over ocean only) and the NN model obtained with this exercise is not suitable for operational or scientific purposes.

# %% [markdown]
# # Addtional Exercises
#
# Using the following code try to train the model differently. In particular:
#
# 1. try to modify the learning rate and the epoch number (try learning rates 0.01, 0.002, 0.0005 0.0001)
# 2. modify the model architecture, varying the number of perceptrons in each hidden layer (40/10, 20/30)
# 3. try to remove one or more input GMI channels (e.g. the first two at 10 GHz which are more directly impacted by surface precipitation)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import optimizers
from tensorflow.keras import utils
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
import xarray as xr

import warnings
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# model hyperparameters
learning_rate1= 0.001  #the learning rate is the step size at each iteration while moving toward a minimum of a loss function
epochs = 1600          #An epoch in machine learning means one complete pass of the training dataset through the algorithm. 
batch_size = 8000      #the batch size is the number of training examples utilized in one iteration. A large batch size should make the training faster but may lead to memory saturation
num_percept_layer1=20  #number of perceptron 1st hidden layer
num_percept_layer2=10  #number of perceptron 2nd hidden layer



def load_dataset():
    warnings.filterwarnings("ignore")
    data_path = './dataset2_GMI_DPR_RR.nc'
    ds = xr.open_dataset(data_path)
    train_df = ds['tb'].to_dataframe().unstack()
    target = ds['rr'].to_dataframe()
    tensor_df = tf.convert_to_tensor(train_df, dtype=np.float)
    label_df = tf.convert_to_tensor(target, dtype=np.float)
    return tensor_df,label_df

def split_dataset(dataset, label_dataset):
    #split = round(test_split* len(tensor_df))
    choice=np.mod(range(0,len(tensor_df)),2)==0
    X_train = dataset[choice==0]
    X_test = dataset[choice]
    y_train = label_dataset[choice==0]
    y_test = label_dataset[choice]   
    
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = split_dataset(tensor_df, label_df)

# Scaling: Standardize features by removing the mean and scaling to unit variance.
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train) #mean and variance are calculated on the training dataset and applied to the training dataset
X_test_scaled = scaler.transform(X_test)       #mean and variance (previously calculated) are applied to the test dataset

# Set the input shape
input_shape = X_train.shape[1]


def train():
    # here the network achitecture is defined: here it is a feed forward neural network with 2 hidden layers, 
    # Sigmoids are used as transfer function in both hidden layers.
    model = Sequential()
    model.add(Dense(num_percept_layer1, input_dim=input_shape, kernel_initializer='normal', activation='sigmoid'))
    model.add(Dense(num_percept_layer2, kernel_initializer='normal', activation='sigmoid')) ###second hidden
    model.add(Dense(1, kernel_initializer='normal', activation='linear')) #output
    model.summary()
    #the optimizer is the algorithm used for the training. Adam is a standard choice, Scale conjugate gradient (SGD), is also very efficient.
    optimizer = optimizers.Adam(lr=learning_rate1)
    #optimizer = optimizers.experimental.SGD( learning_rate=learning_rate1)
    
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae']) # the loss function to be minimized during training is the mean squared error (MSE)
    history = model.fit(
        X_train_scaled,
        y_train,
        batch_size=batch_size,
        epochs=epochs,
    # We also carry out some validation to
    # monitor loss and metrics on the test dataset
    # at the end of each epoch
        validation_data=(X_test_scaled, y_test),)
        #validation_data=(X_test, np.log10(y_test)),)
    return model, history


verbose = 1
# training with the train dataset
model, history = train()

model.save('./exer2_model.h5')

# plot learning curves
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('MSE loss')
plt.plot((history.history['loss']), label='train')
plt.plot((history.history['val_loss']), label='test')
plt.legend()
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 20)                280
#
#  dense_4 (Dense)             (None, 10)                210
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/1600
# 4/4 [==============================] - 1s 51ms/step - loss: 32.1492 - mae: 2.4741 - val_loss: 33.1275 - val_mae: 2.4584
# Epoch 2/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 32.0108 - mae: 2.4462 - val_loss: 32.9911 - val_mae: 2.4307
# Epoch 3/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 31.8757 - mae: 2.4186 - val_loss: 32.8567 - val_mae: 2.4031
# Epoch 4/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 31.7413 - mae: 2.3910 - val_loss: 32.7234 - val_mae: 2.3755
# Epoch 5/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 31.6086 - mae: 2.3633 - val_loss: 32.5898 - val_mae: 2.3475
# Epoch 6/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 31.4749 - mae: 2.3352 - val_loss: 32.4551 - val_mae: 2.3193
# Epoch 7/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 31.3402 - mae: 2.3071 - val_loss: 32.3190 - val_mae: 2.2916
# Epoch 8/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 31.2032 - mae: 2.2796 - val_loss: 32.1812 - val_mae: 2.2647
# Epoch 9/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 31.0642 - mae: 2.2530 - val_loss: 32.0413 - val_mae: 2.2387
# Epoch 10/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 30.9238 - mae: 2.2270 - val_loss: 31.8988 - val_mae: 2.2134
# Epoch 11/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 30.7807 - mae: 2.2020 - val_loss: 31.7537 - val_mae: 2.1889
# Epoch 12/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 30.6350 - mae: 2.1779 - val_loss: 31.6059 - val_mae: 2.1655
# Epoch 13/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 30.4866 - mae: 2.1547 - val_loss: 31.4555 - val_mae: 2.1430
# Epoch 14/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 30.3361 - mae: 2.1325 - val_loss: 31.3024 - val_mae: 2.1216
# Epoch 15/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 30.1811 - mae: 2.1115 - val_loss: 31.1475 - val_mae: 2.1013
# Epoch 16/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 30.0268 - mae: 2.0915 - val_loss: 30.9904 - val_mae: 2.0821
# Epoch 17/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 29.8683 - mae: 2.0726 - val_loss: 30.8321 - val_mae: 2.0642
# Epoch 18/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 29.7111 - mae: 2.0549 - val_loss: 30.6722 - val_mae: 2.0474
# Epoch 19/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 29.5505 - mae: 2.0385 - val_loss: 30.5122 - val_mae: 2.0319
# Epoch 20/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 29.3902 - mae: 2.0234 - val_loss: 30.3523 - val_mae: 2.0176
# Epoch 21/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 29.2316 - mae: 2.0095 - val_loss: 30.1924 - val_mae: 2.0046
# Epoch 22/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 29.0716 - mae: 1.9970 - val_loss: 30.0337 - val_mae: 1.9929
# Epoch 23/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 28.9140 - mae: 1.9856 - val_loss: 29.8763 - val_mae: 1.9824
# Epoch 24/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 28.7573 - mae: 1.9755 - val_loss: 29.7209 - val_mae: 1.9733
# Epoch 25/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 28.6033 - mae: 1.9667 - val_loss: 29.5675 - val_mae: 1.9655
# Epoch 26/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 28.4506 - mae: 1.9593 - val_loss: 29.4170 - val_mae: 1.9589
# Epoch 27/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 28.3008 - mae: 1.9528 - val_loss: 29.2695 - val_mae: 1.9535
# Epoch 28/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 28.1554 - mae: 1.9478 - val_loss: 29.1249 - val_mae: 1.9493
# Epoch 29/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 28.0119 - mae: 1.9439 - val_loss: 28.9840 - val_mae: 1.9462
# Epoch 30/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 27.8738 - mae: 1.9410 - val_loss: 28.8466 - val_mae: 1.9441
# Epoch 31/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 27.7352 - mae: 1.9392 - val_loss: 28.7142 - val_mae: 1.9431
# Epoch 32/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 27.6069 - mae: 1.9387 - val_loss: 28.5848 - val_mae: 1.9431
# Epoch 33/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 27.4784 - mae: 1.9388 - val_loss: 28.4603 - val_mae: 1.9439
# Epoch 34/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 27.3572 - mae: 1.9400 - val_loss: 28.3396 - val_mae: 1.9456
# Epoch 35/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 27.2377 - mae: 1.9418 - val_loss: 28.2239 - val_mae: 1.9480
# Epoch 36/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 27.1241 - mae: 1.9444 - val_loss: 28.1126 - val_mae: 1.9510
# Epoch 37/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 27.0141 - mae: 1.9475 - val_loss: 28.0062 - val_mae: 1.9548
# Epoch 38/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 26.9092 - mae: 1.9514 - val_loss: 27.9043 - val_mae: 1.9590
# Epoch 39/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 26.8096 - mae: 1.9557 - val_loss: 27.8066 - val_mae: 1.9638
# Epoch 40/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 26.7149 - mae: 1.9606 - val_loss: 27.7129 - val_mae: 1.9691
# Epoch 41/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 26.6224 - mae: 1.9655 - val_loss: 27.6238 - val_mae: 1.9747
# Epoch 42/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 26.5348 - mae: 1.9709 - val_loss: 27.5389 - val_mae: 1.9805
# Epoch 43/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 26.4517 - mae: 1.9766 - val_loss: 27.4581 - val_mae: 1.9866
# Epoch 44/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 26.3720 - mae: 1.9825 - val_loss: 27.3812 - val_mae: 1.9928
# Epoch 45/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 26.2965 - mae: 1.9886 - val_loss: 27.3079 - val_mae: 1.9991
# Epoch 46/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 26.2254 - mae: 1.9949 - val_loss: 27.2378 - val_mae: 2.0056
# Epoch 47/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 26.1562 - mae: 2.0013 - val_loss: 27.1710 - val_mae: 2.0120
# Epoch 48/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 26.0907 - mae: 2.0077 - val_loss: 27.1074 - val_mae: 2.0185
# Epoch 49/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 26.0284 - mae: 2.0140 - val_loss: 27.0466 - val_mae: 2.0249
# Epoch 50/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.9681 - mae: 2.0203 - val_loss: 26.9887 - val_mae: 2.0312
# Epoch 51/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.9131 - mae: 2.0267 - val_loss: 26.9327 - val_mae: 2.0375
# Epoch 52/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 25.8573 - mae: 2.0328 - val_loss: 26.8796 - val_mae: 2.0436
# Epoch 53/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.8058 - mae: 2.0390 - val_loss: 26.8285 - val_mae: 2.0496
# Epoch 54/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 25.7550 - mae: 2.0449 - val_loss: 26.7798 - val_mae: 2.0553
# Epoch 55/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 25.7071 - mae: 2.0507 - val_loss: 26.7328 - val_mae: 2.0609
# Epoch 56/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 25.6609 - mae: 2.0564 - val_loss: 26.6877 - val_mae: 2.0663
# Epoch 57/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 25.6168 - mae: 2.0619 - val_loss: 26.6440 - val_mae: 2.0716
# Epoch 58/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.5737 - mae: 2.0673 - val_loss: 26.6020 - val_mae: 2.0767
# Epoch 59/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.5335 - mae: 2.0726 - val_loss: 26.5611 - val_mae: 2.0818
# Epoch 60/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.4929 - mae: 2.0777 - val_loss: 26.5218 - val_mae: 2.0866
# Epoch 61/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 25.4542 - mae: 2.0826 - val_loss: 26.4838 - val_mae: 2.0913
# Epoch 62/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 25.4168 - mae: 2.0873 - val_loss: 26.4470 - val_mae: 2.0959
# Epoch 63/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 25.3814 - mae: 2.0919 - val_loss: 26.4111 - val_mae: 2.1003
# Epoch 64/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.3455 - mae: 2.0963 - val_loss: 26.3766 - val_mae: 2.1045
# Epoch 65/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.3116 - mae: 2.1005 - val_loss: 26.3431 - val_mae: 2.1086
# Epoch 66/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 25.2782 - mae: 2.1046 - val_loss: 26.3107 - val_mae: 2.1124
# Epoch 67/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.2469 - mae: 2.1087 - val_loss: 26.2788 - val_mae: 2.1163
# Epoch 68/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.2159 - mae: 2.1125 - val_loss: 26.2477 - val_mae: 2.1200
# Epoch 69/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 25.1849 - mae: 2.1163 - val_loss: 26.2177 - val_mae: 2.1236
# Epoch 70/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 25.1560 - mae: 2.1200 - val_loss: 26.1882 - val_mae: 2.1271
# Epoch 71/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 25.1267 - mae: 2.1235 - val_loss: 26.1596 - val_mae: 2.1304
# Epoch 72/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.0992 - mae: 2.1269 - val_loss: 26.1314 - val_mae: 2.1338
# Epoch 73/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.0708 - mae: 2.1302 - val_loss: 26.1043 - val_mae: 2.1368
# Epoch 74/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 25.0446 - mae: 2.1334 - val_loss: 26.0776 - val_mae: 2.1399
# Epoch 75/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 25.0182 - mae: 2.1364 - val_loss: 26.0516 - val_mae: 2.1428
# Epoch 76/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 24.9928 - mae: 2.1395 - val_loss: 26.0260 - val_mae: 2.1457
# Epoch 77/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 24.9677 - mae: 2.1423 - val_loss: 26.0010 - val_mae: 2.1484
# Epoch 78/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 24.9435 - mae: 2.1452 - val_loss: 25.9766 - val_mae: 2.1511
# Epoch 79/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 24.9198 - mae: 2.1479 - val_loss: 25.9525 - val_mae: 2.1538
# Epoch 80/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.8957 - mae: 2.1505 - val_loss: 25.9292 - val_mae: 2.1562
# Epoch 81/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.8728 - mae: 2.1531 - val_loss: 25.9063 - val_mae: 2.1586
# Epoch 82/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.8505 - mae: 2.1555 - val_loss: 25.8838 - val_mae: 2.1609
# Epoch 83/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.8280 - mae: 2.1578 - val_loss: 25.8619 - val_mae: 2.1631
# Epoch 84/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.8068 - mae: 2.1601 - val_loss: 25.8402 - val_mae: 2.1653
# Epoch 85/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.7856 - mae: 2.1623 - val_loss: 25.8189 - val_mae: 2.1675
# Epoch 86/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.7650 - mae: 2.1646 - val_loss: 25.7978 - val_mae: 2.1696
# Epoch 87/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.7444 - mae: 2.1667 - val_loss: 25.7772 - val_mae: 2.1716
# Epoch 88/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.7237 - mae: 2.1688 - val_loss: 25.7571 - val_mae: 2.1735
# Epoch 89/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.7043 - mae: 2.1707 - val_loss: 25.7372 - val_mae: 2.1754
# Epoch 90/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.6844 - mae: 2.1726 - val_loss: 25.7177 - val_mae: 2.1771
# Epoch 91/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.6655 - mae: 2.1744 - val_loss: 25.6985 - val_mae: 2.1789
# Epoch 92/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.6466 - mae: 2.1762 - val_loss: 25.6796 - val_mae: 2.1806
# Epoch 93/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.6276 - mae: 2.1779 - val_loss: 25.6611 - val_mae: 2.1821
# Epoch 94/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.6102 - mae: 2.1797 - val_loss: 25.6425 - val_mae: 2.1838
# Epoch 95/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.5917 - mae: 2.1813 - val_loss: 25.6244 - val_mae: 2.1853
# Epoch 96/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.5743 - mae: 2.1830 - val_loss: 25.6064 - val_mae: 2.1869
# Epoch 97/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.5564 - mae: 2.1844 - val_loss: 25.5889 - val_mae: 2.1882
# Epoch 98/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.5394 - mae: 2.1860 - val_loss: 25.5715 - val_mae: 2.1897
# Epoch 99/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.5221 - mae: 2.1874 - val_loss: 25.5545 - val_mae: 2.1909
# Epoch 100/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.5055 - mae: 2.1887 - val_loss: 25.5376 - val_mae: 2.1922
# Epoch 101/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.4889 - mae: 2.1901 - val_loss: 25.5209 - val_mae: 2.1934
# Epoch 102/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.4729 - mae: 2.1915 - val_loss: 25.5043 - val_mae: 2.1948
# Epoch 103/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 24.4565 - mae: 2.1928 - val_loss: 25.4880 - val_mae: 2.1959
# Epoch 104/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.4403 - mae: 2.1939 - val_loss: 25.4720 - val_mae: 2.1970
# Epoch 105/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.4249 - mae: 2.1951 - val_loss: 25.4561 - val_mae: 2.1981
# Epoch 106/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.4095 - mae: 2.1962 - val_loss: 25.4403 - val_mae: 2.1992
# Epoch 107/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.3936 - mae: 2.1973 - val_loss: 25.4249 - val_mae: 2.2001
# Epoch 108/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.3786 - mae: 2.1982 - val_loss: 25.4095 - val_mae: 2.2011
# Epoch 109/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 24.3634 - mae: 2.1992 - val_loss: 25.3944 - val_mae: 2.2019
# Epoch 110/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.3489 - mae: 2.2001 - val_loss: 25.3793 - val_mae: 2.2028
# Epoch 111/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.3337 - mae: 2.2009 - val_loss: 25.3645 - val_mae: 2.2036
# Epoch 112/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.3194 - mae: 2.2018 - val_loss: 25.3497 - val_mae: 2.2045
# Epoch 113/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.3050 - mae: 2.2027 - val_loss: 25.3350 - val_mae: 2.2053
# Epoch 114/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.2904 - mae: 2.2035 - val_loss: 25.3206 - val_mae: 2.2060
# Epoch 115/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.2765 - mae: 2.2043 - val_loss: 25.3062 - val_mae: 2.2068
# Epoch 116/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.2624 - mae: 2.2051 - val_loss: 25.2919 - val_mae: 2.2075
# Epoch 117/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.2485 - mae: 2.2058 - val_loss: 25.2777 - val_mae: 2.2082
# Epoch 118/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 24.2342 - mae: 2.2064 - val_loss: 25.2639 - val_mae: 2.2087
# Epoch 119/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.2208 - mae: 2.2070 - val_loss: 25.2500 - val_mae: 2.2093
# Epoch 120/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 24.2074 - mae: 2.2076 - val_loss: 25.2361 - val_mae: 2.2099
# Epoch 121/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 24.1937 - mae: 2.2082 - val_loss: 25.2225 - val_mae: 2.2104
# Epoch 122/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.1805 - mae: 2.2087 - val_loss: 25.2088 - val_mae: 2.2109
# Epoch 123/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.1671 - mae: 2.2093 - val_loss: 25.1953 - val_mae: 2.2113
# Epoch 124/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.1539 - mae: 2.2097 - val_loss: 25.1819 - val_mae: 2.2118
# Epoch 125/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.1406 - mae: 2.2101 - val_loss: 25.1687 - val_mae: 2.2121
# Epoch 126/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.1277 - mae: 2.2105 - val_loss: 25.1554 - val_mae: 2.2125
# Epoch 127/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 24.1146 - mae: 2.2108 - val_loss: 25.1423 - val_mae: 2.2127
# Epoch 128/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 24.1016 - mae: 2.2111 - val_loss: 25.1293 - val_mae: 2.2129
# Epoch 129/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 24.0890 - mae: 2.2113 - val_loss: 25.1163 - val_mae: 2.2132
# Epoch 130/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.0763 - mae: 2.2116 - val_loss: 25.1033 - val_mae: 2.2134
# Epoch 131/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 24.0634 - mae: 2.2118 - val_loss: 25.0904 - val_mae: 2.2136
# Epoch 132/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 24.0508 - mae: 2.2120 - val_loss: 25.0776 - val_mae: 2.2137
# Epoch 133/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.0382 - mae: 2.2121 - val_loss: 25.0649 - val_mae: 2.2138
# Epoch 134/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.0258 - mae: 2.2122 - val_loss: 25.0521 - val_mae: 2.2139
# Epoch 135/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 24.0134 - mae: 2.2124 - val_loss: 25.0394 - val_mae: 2.2141
# Epoch 136/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 24.0007 - mae: 2.2125 - val_loss: 25.0268 - val_mae: 2.2141
# Epoch 137/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.9884 - mae: 2.2125 - val_loss: 25.0142 - val_mae: 2.2141
# Epoch 138/1600
# 4/4 [==============================] - 0s 13ms/step - loss: 23.9759 - mae: 2.2125 - val_loss: 25.0016 - val_mae: 2.2141
# Epoch 139/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.9635 - mae: 2.2125 - val_loss: 24.9891 - val_mae: 2.2140
# Epoch 140/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.9510 - mae: 2.2124 - val_loss: 24.9766 - val_mae: 2.2139
# Epoch 141/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.9390 - mae: 2.2123 - val_loss: 24.9641 - val_mae: 2.2139
# Epoch 142/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.9265 - mae: 2.2123 - val_loss: 24.9516 - val_mae: 2.2138
# Epoch 143/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.9143 - mae: 2.2122 - val_loss: 24.9391 - val_mae: 2.2137
# Epoch 144/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.9019 - mae: 2.2121 - val_loss: 24.9266 - val_mae: 2.2135
# Epoch 145/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.8897 - mae: 2.2119 - val_loss: 24.9141 - val_mae: 2.2134
# Epoch 146/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.8772 - mae: 2.2117 - val_loss: 24.9017 - val_mae: 2.2131
# Epoch 147/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.8650 - mae: 2.2115 - val_loss: 24.8892 - val_mae: 2.2129
# Epoch 148/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.8525 - mae: 2.2112 - val_loss: 24.8768 - val_mae: 2.2125
# Epoch 149/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.8404 - mae: 2.2109 - val_loss: 24.8642 - val_mae: 2.2123
# Epoch 150/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.8283 - mae: 2.2108 - val_loss: 24.8516 - val_mae: 2.2122
# Epoch 151/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 23.8156 - mae: 2.2106 - val_loss: 24.8390 - val_mae: 2.2119
# Epoch 152/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.8031 - mae: 2.2103 - val_loss: 24.8265 - val_mae: 2.2115
# Epoch 153/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.7907 - mae: 2.2098 - val_loss: 24.8140 - val_mae: 2.2110
# Epoch 154/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.7783 - mae: 2.2093 - val_loss: 24.8014 - val_mae: 2.2106
# Epoch 155/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.7658 - mae: 2.2089 - val_loss: 24.7887 - val_mae: 2.2101
# Epoch 156/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.7533 - mae: 2.2084 - val_loss: 24.7761 - val_mae: 2.2096
# Epoch 157/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.7406 - mae: 2.2079 - val_loss: 24.7634 - val_mae: 2.2091
# Epoch 158/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.7282 - mae: 2.2074 - val_loss: 24.7505 - val_mae: 2.2086
# Epoch 159/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.7154 - mae: 2.2069 - val_loss: 24.7377 - val_mae: 2.2081
# Epoch 160/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.7027 - mae: 2.2064 - val_loss: 24.7248 - val_mae: 2.2075
# Epoch 161/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.6899 - mae: 2.2058 - val_loss: 24.7118 - val_mae: 2.2069
# Epoch 162/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.6770 - mae: 2.2052 - val_loss: 24.6988 - val_mae: 2.2064
# Epoch 163/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.6638 - mae: 2.2045 - val_loss: 24.6858 - val_mae: 2.2056
# Epoch 164/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.6512 - mae: 2.2039 - val_loss: 24.6726 - val_mae: 2.2051
# Epoch 165/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.6377 - mae: 2.2032 - val_loss: 24.6594 - val_mae: 2.2043
# Epoch 166/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.6248 - mae: 2.2025 - val_loss: 24.6461 - val_mae: 2.2037
# Epoch 167/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.6114 - mae: 2.2019 - val_loss: 24.6327 - val_mae: 2.2029
# Epoch 168/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.5979 - mae: 2.2010 - val_loss: 24.6193 - val_mae: 2.2020
# Epoch 169/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.5847 - mae: 2.2003 - val_loss: 24.6057 - val_mae: 2.2014
# Epoch 170/1600
# 4/4 [==============================] - 0s 33ms/step - loss: 23.5709 - mae: 2.1995 - val_loss: 24.5920 - val_mae: 2.2005
# Epoch 171/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.5574 - mae: 2.1987 - val_loss: 24.5782 - val_mae: 2.1997
# Epoch 172/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.5436 - mae: 2.1979 - val_loss: 24.5644 - val_mae: 2.1989
# Epoch 173/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.5299 - mae: 2.1971 - val_loss: 24.5503 - val_mae: 2.1982
# Epoch 174/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.5157 - mae: 2.1963 - val_loss: 24.5363 - val_mae: 2.1973
# Epoch 175/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.5017 - mae: 2.1954 - val_loss: 24.5221 - val_mae: 2.1964
# Epoch 176/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.4876 - mae: 2.1945 - val_loss: 24.5078 - val_mae: 2.1955
# Epoch 177/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.4731 - mae: 2.1935 - val_loss: 24.4935 - val_mae: 2.1945
# Epoch 178/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.4589 - mae: 2.1926 - val_loss: 24.4790 - val_mae: 2.1936
# Epoch 179/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.4444 - mae: 2.1916 - val_loss: 24.4644 - val_mae: 2.1925
# Epoch 180/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 23.4296 - mae: 2.1905 - val_loss: 24.4498 - val_mae: 2.1914
# Epoch 181/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.4149 - mae: 2.1894 - val_loss: 24.4350 - val_mae: 2.1903
# Epoch 182/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.4001 - mae: 2.1883 - val_loss: 24.4201 - val_mae: 2.1893
# Epoch 183/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.3849 - mae: 2.1872 - val_loss: 24.4052 - val_mae: 2.1881
# Epoch 184/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.3702 - mae: 2.1861 - val_loss: 24.3900 - val_mae: 2.1871
# Epoch 185/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.3546 - mae: 2.1850 - val_loss: 24.3748 - val_mae: 2.1858
# Epoch 186/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.3393 - mae: 2.1837 - val_loss: 24.3595 - val_mae: 2.1847
# Epoch 187/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.3240 - mae: 2.1826 - val_loss: 24.3441 - val_mae: 2.1836
# Epoch 188/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.3083 - mae: 2.1814 - val_loss: 24.3286 - val_mae: 2.1824
# Epoch 189/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.2927 - mae: 2.1802 - val_loss: 24.3130 - val_mae: 2.1812
# Epoch 190/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.2769 - mae: 2.1790 - val_loss: 24.2972 - val_mae: 2.1801
# Epoch 191/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 23.2609 - mae: 2.1778 - val_loss: 24.2814 - val_mae: 2.1789
# Epoch 192/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.2449 - mae: 2.1766 - val_loss: 24.2655 - val_mae: 2.1777
# Epoch 193/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 23.2290 - mae: 2.1755 - val_loss: 24.2494 - val_mae: 2.1767
# Epoch 194/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.2125 - mae: 2.1743 - val_loss: 24.2333 - val_mae: 2.1754
# Epoch 195/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.1965 - mae: 2.1732 - val_loss: 24.2170 - val_mae: 2.1743
# Epoch 196/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.1800 - mae: 2.1719 - val_loss: 24.2007 - val_mae: 2.1731
# Epoch 197/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.1633 - mae: 2.1706 - val_loss: 24.1844 - val_mae: 2.1717
# Epoch 198/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 23.1471 - mae: 2.1694 - val_loss: 24.1678 - val_mae: 2.1707
# Epoch 199/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 23.1302 - mae: 2.1683 - val_loss: 24.1513 - val_mae: 2.1694
# Epoch 200/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 23.1134 - mae: 2.1668 - val_loss: 24.1348 - val_mae: 2.1681
# Epoch 201/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 23.0970 - mae: 2.1656 - val_loss: 24.1180 - val_mae: 2.1670
# Epoch 202/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 23.0799 - mae: 2.1643 - val_loss: 24.1014 - val_mae: 2.1655
# Epoch 203/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 23.0631 - mae: 2.1630 - val_loss: 24.0846 - val_mae: 2.1643
# Epoch 204/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 23.0462 - mae: 2.1617 - val_loss: 24.0677 - val_mae: 2.1630
# Epoch 205/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 23.0290 - mae: 2.1603 - val_loss: 24.0510 - val_mae: 2.1616
# Epoch 206/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 23.0123 - mae: 2.1590 - val_loss: 24.0340 - val_mae: 2.1605
# Epoch 207/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 22.9951 - mae: 2.1578 - val_loss: 24.0170 - val_mae: 2.1592
# Epoch 208/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 22.9779 - mae: 2.1563 - val_loss: 24.0001 - val_mae: 2.1578
# Epoch 209/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.9612 - mae: 2.1551 - val_loss: 23.9830 - val_mae: 2.1567
# Epoch 210/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.9438 - mae: 2.1538 - val_loss: 23.9660 - val_mae: 2.1554
# Epoch 211/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.9268 - mae: 2.1526 - val_loss: 23.9490 - val_mae: 2.1542
# Epoch 212/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.9094 - mae: 2.1512 - val_loss: 23.9321 - val_mae: 2.1527
# Epoch 213/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 22.8921 - mae: 2.1496 - val_loss: 23.9151 - val_mae: 2.1513
# Epoch 214/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.8752 - mae: 2.1483 - val_loss: 23.8981 - val_mae: 2.1500
# Epoch 215/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.8581 - mae: 2.1469 - val_loss: 23.8810 - val_mae: 2.1487
# Epoch 216/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.8408 - mae: 2.1456 - val_loss: 23.8640 - val_mae: 2.1474
# Epoch 217/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.8238 - mae: 2.1444 - val_loss: 23.8469 - val_mae: 2.1463
# Epoch 218/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.8066 - mae: 2.1431 - val_loss: 23.8298 - val_mae: 2.1452
# Epoch 219/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.7893 - mae: 2.1419 - val_loss: 23.8128 - val_mae: 2.1439
# Epoch 220/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 22.7720 - mae: 2.1406 - val_loss: 23.7958 - val_mae: 2.1426
# Epoch 221/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.7547 - mae: 2.1391 - val_loss: 23.7789 - val_mae: 2.1412
# Epoch 222/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.7378 - mae: 2.1377 - val_loss: 23.7619 - val_mae: 2.1398
# Epoch 223/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.7209 - mae: 2.1364 - val_loss: 23.7448 - val_mae: 2.1387
# Epoch 224/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 22.7034 - mae: 2.1352 - val_loss: 23.7279 - val_mae: 2.1374
# Epoch 225/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.6866 - mae: 2.1339 - val_loss: 23.7109 - val_mae: 2.1363
# Epoch 226/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.6694 - mae: 2.1326 - val_loss: 23.6939 - val_mae: 2.1349
# Epoch 227/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.6521 - mae: 2.1312 - val_loss: 23.6771 - val_mae: 2.1336
# Epoch 228/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.6353 - mae: 2.1298 - val_loss: 23.6601 - val_mae: 2.1323
# Epoch 229/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.6179 - mae: 2.1283 - val_loss: 23.6433 - val_mae: 2.1308
# Epoch 230/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.6011 - mae: 2.1267 - val_loss: 23.6264 - val_mae: 2.1294
# Epoch 231/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 22.5844 - mae: 2.1255 - val_loss: 23.6094 - val_mae: 2.1284
# Epoch 232/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.5674 - mae: 2.1244 - val_loss: 23.5925 - val_mae: 2.1273
# Epoch 233/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 22.5500 - mae: 2.1229 - val_loss: 23.5757 - val_mae: 2.1257
# Epoch 234/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 22.5333 - mae: 2.1215 - val_loss: 23.5588 - val_mae: 2.1244
# Epoch 235/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 22.5164 - mae: 2.1200 - val_loss: 23.5419 - val_mae: 2.1230
# Epoch 236/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.4995 - mae: 2.1187 - val_loss: 23.5250 - val_mae: 2.1219
# Epoch 237/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.4825 - mae: 2.1173 - val_loss: 23.5081 - val_mae: 2.1205
# Epoch 238/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.4655 - mae: 2.1158 - val_loss: 23.4913 - val_mae: 2.1190
# Epoch 239/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.4486 - mae: 2.1144 - val_loss: 23.4744 - val_mae: 2.1177
# Epoch 240/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.4316 - mae: 2.1129 - val_loss: 23.4575 - val_mae: 2.1162
# Epoch 241/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.4146 - mae: 2.1113 - val_loss: 23.4407 - val_mae: 2.1146
# Epoch 242/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.3979 - mae: 2.1098 - val_loss: 23.4237 - val_mae: 2.1133
# Epoch 243/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.3809 - mae: 2.1083 - val_loss: 23.4069 - val_mae: 2.1118
# Epoch 244/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.3642 - mae: 2.1069 - val_loss: 23.3898 - val_mae: 2.1107
# Epoch 245/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.3470 - mae: 2.1055 - val_loss: 23.3728 - val_mae: 2.1091
# Epoch 246/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.3302 - mae: 2.1040 - val_loss: 23.3558 - val_mae: 2.1080
# Epoch 247/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.3129 - mae: 2.1027 - val_loss: 23.3389 - val_mae: 2.1065
# Epoch 248/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.2963 - mae: 2.1013 - val_loss: 23.3218 - val_mae: 2.1052
# Epoch 249/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 22.2791 - mae: 2.0998 - val_loss: 23.3048 - val_mae: 2.1037
# Epoch 250/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.2622 - mae: 2.0982 - val_loss: 23.2877 - val_mae: 2.1021
# Epoch 251/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 22.2449 - mae: 2.0965 - val_loss: 23.2707 - val_mae: 2.1004
# Epoch 252/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.2281 - mae: 2.0949 - val_loss: 23.2536 - val_mae: 2.0991
# Epoch 253/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.2109 - mae: 2.0933 - val_loss: 23.2366 - val_mae: 2.0975
# Epoch 254/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.1942 - mae: 2.0920 - val_loss: 23.2194 - val_mae: 2.0964
# Epoch 255/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.1770 - mae: 2.0907 - val_loss: 23.2021 - val_mae: 2.0950
# Epoch 256/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.1600 - mae: 2.0893 - val_loss: 23.1849 - val_mae: 2.0938
# Epoch 257/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.1423 - mae: 2.0877 - val_loss: 23.1677 - val_mae: 2.0921
# Epoch 258/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.1254 - mae: 2.0861 - val_loss: 23.1505 - val_mae: 2.0906
# Epoch 259/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 22.1082 - mae: 2.0845 - val_loss: 23.1333 - val_mae: 2.0892
# Epoch 260/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 22.0912 - mae: 2.0831 - val_loss: 23.1160 - val_mae: 2.0879
# Epoch 261/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 22.0738 - mae: 2.0817 - val_loss: 23.0986 - val_mae: 2.0865
# Epoch 262/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.0565 - mae: 2.0801 - val_loss: 23.0812 - val_mae: 2.0849
# Epoch 263/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 22.0388 - mae: 2.0784 - val_loss: 23.0640 - val_mae: 2.0832
# Epoch 264/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 22.0216 - mae: 2.0766 - val_loss: 23.0466 - val_mae: 2.0816
# Epoch 265/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 22.0047 - mae: 2.0753 - val_loss: 23.0290 - val_mae: 2.0806
# Epoch 266/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.9868 - mae: 2.0739 - val_loss: 23.0116 - val_mae: 2.0792
# Epoch 267/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 21.9696 - mae: 2.0725 - val_loss: 22.9940 - val_mae: 2.0778
# Epoch 268/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 21.9522 - mae: 2.0711 - val_loss: 22.9763 - val_mae: 2.0765
# Epoch 269/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.9344 - mae: 2.0696 - val_loss: 22.9586 - val_mae: 2.0748
# Epoch 270/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 21.9167 - mae: 2.0677 - val_loss: 22.9411 - val_mae: 2.0730
# Epoch 271/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 21.8994 - mae: 2.0661 - val_loss: 22.9233 - val_mae: 2.0718
# Epoch 272/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.8816 - mae: 2.0647 - val_loss: 22.9056 - val_mae: 2.0701
# Epoch 273/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.8638 - mae: 2.0629 - val_loss: 22.8879 - val_mae: 2.0686
# Epoch 274/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.8461 - mae: 2.0613 - val_loss: 22.8700 - val_mae: 2.0671
# Epoch 275/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.8284 - mae: 2.0598 - val_loss: 22.8521 - val_mae: 2.0656
# Epoch 276/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.8109 - mae: 2.0585 - val_loss: 22.8341 - val_mae: 2.0645
# Epoch 277/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.7925 - mae: 2.0570 - val_loss: 22.8162 - val_mae: 2.0629
# Epoch 278/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.7748 - mae: 2.0553 - val_loss: 22.7982 - val_mae: 2.0613
# Epoch 279/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.7564 - mae: 2.0534 - val_loss: 22.7803 - val_mae: 2.0595
# Epoch 280/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.7387 - mae: 2.0518 - val_loss: 22.7622 - val_mae: 2.0581
# Epoch 281/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.7206 - mae: 2.0501 - val_loss: 22.7441 - val_mae: 2.0564
# Epoch 282/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.7027 - mae: 2.0487 - val_loss: 22.7258 - val_mae: 2.0553
# Epoch 283/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 21.6844 - mae: 2.0474 - val_loss: 22.7075 - val_mae: 2.0539
# Epoch 284/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 21.6658 - mae: 2.0457 - val_loss: 22.6892 - val_mae: 2.0522
# Epoch 285/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.6478 - mae: 2.0441 - val_loss: 22.6707 - val_mae: 2.0509
# Epoch 286/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 21.6292 - mae: 2.0425 - val_loss: 22.6523 - val_mae: 2.0493
# Epoch 287/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.6112 - mae: 2.0409 - val_loss: 22.6337 - val_mae: 2.0479
# Epoch 288/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 21.5925 - mae: 2.0395 - val_loss: 22.6152 - val_mae: 2.0463
# Epoch 289/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 21.5743 - mae: 2.0380 - val_loss: 22.5965 - val_mae: 2.0451
# Epoch 290/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 21.5554 - mae: 2.0363 - val_loss: 22.5780 - val_mae: 2.0432
# Epoch 291/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 21.5368 - mae: 2.0345 - val_loss: 22.5593 - val_mae: 2.0418
# Epoch 292/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.5176 - mae: 2.0328 - val_loss: 22.5407 - val_mae: 2.0400
# Epoch 293/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 21.4998 - mae: 2.0312 - val_loss: 22.5217 - val_mae: 2.0388
# Epoch 294/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.4806 - mae: 2.0298 - val_loss: 22.5028 - val_mae: 2.0373
# Epoch 295/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.4619 - mae: 2.0283 - val_loss: 22.4838 - val_mae: 2.0358
# Epoch 296/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 21.4430 - mae: 2.0268 - val_loss: 22.4648 - val_mae: 2.0344
# Epoch 297/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.4239 - mae: 2.0253 - val_loss: 22.4458 - val_mae: 2.0329
# Epoch 298/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.4049 - mae: 2.0235 - val_loss: 22.4267 - val_mae: 2.0311
# Epoch 299/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 21.3861 - mae: 2.0220 - val_loss: 22.4073 - val_mae: 2.0298
# Epoch 300/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.3667 - mae: 2.0203 - val_loss: 22.3881 - val_mae: 2.0281
# Epoch 301/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.3476 - mae: 2.0187 - val_loss: 22.3688 - val_mae: 2.0265
# Epoch 302/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.3284 - mae: 2.0169 - val_loss: 22.3496 - val_mae: 2.0247
# Epoch 303/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 21.3089 - mae: 2.0150 - val_loss: 22.3303 - val_mae: 2.0231
# Epoch 304/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 21.2896 - mae: 2.0136 - val_loss: 22.3109 - val_mae: 2.0217
# Epoch 305/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.2703 - mae: 2.0120 - val_loss: 22.2914 - val_mae: 2.0201
# Epoch 306/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.2507 - mae: 2.0102 - val_loss: 22.2717 - val_mae: 2.0183
# Epoch 307/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.2312 - mae: 2.0084 - val_loss: 22.2522 - val_mae: 2.0169
# Epoch 308/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.2121 - mae: 2.0071 - val_loss: 22.2322 - val_mae: 2.0157
# Epoch 309/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 21.1916 - mae: 2.0054 - val_loss: 22.2126 - val_mae: 2.0136
# Epoch 310/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.1722 - mae: 2.0034 - val_loss: 22.1928 - val_mae: 2.0119
# Epoch 311/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.1525 - mae: 2.0019 - val_loss: 22.1728 - val_mae: 2.0107
# Epoch 312/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.1328 - mae: 2.0007 - val_loss: 22.1528 - val_mae: 2.0095
# Epoch 313/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 21.1129 - mae: 1.9993 - val_loss: 22.1327 - val_mae: 2.0080
# Epoch 314/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 21.0926 - mae: 1.9976 - val_loss: 22.1127 - val_mae: 2.0064
# Epoch 315/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 21.0725 - mae: 1.9955 - val_loss: 22.0926 - val_mae: 2.0040
# Epoch 316/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 21.0526 - mae: 1.9934 - val_loss: 22.0723 - val_mae: 2.0023
# Epoch 317/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.0326 - mae: 1.9919 - val_loss: 22.0520 - val_mae: 2.0012
# Epoch 318/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 21.0120 - mae: 1.9905 - val_loss: 22.0319 - val_mae: 1.9996
# Epoch 319/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.9920 - mae: 1.9889 - val_loss: 22.0115 - val_mae: 1.9982
# Epoch 320/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.9715 - mae: 1.9872 - val_loss: 21.9911 - val_mae: 1.9966
# Epoch 321/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.9509 - mae: 1.9855 - val_loss: 21.9707 - val_mae: 1.9948
# Epoch 322/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.9307 - mae: 1.9839 - val_loss: 21.9502 - val_mae: 1.9936
# Epoch 323/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.9103 - mae: 1.9824 - val_loss: 21.9294 - val_mae: 1.9920
# Epoch 324/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.8893 - mae: 1.9807 - val_loss: 21.9086 - val_mae: 1.9904
# Epoch 325/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.8692 - mae: 1.9792 - val_loss: 21.8876 - val_mae: 1.9890
# Epoch 326/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.8478 - mae: 1.9774 - val_loss: 21.8668 - val_mae: 1.9871
# Epoch 327/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 20.8276 - mae: 1.9759 - val_loss: 21.8458 - val_mae: 1.9860
# Epoch 328/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.8065 - mae: 1.9743 - val_loss: 21.8251 - val_mae: 1.9841
# Epoch 329/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 20.7855 - mae: 1.9725 - val_loss: 21.8040 - val_mae: 1.9826
# Epoch 330/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 20.7656 - mae: 1.9713 - val_loss: 21.7827 - val_mae: 1.9818
# Epoch 331/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 20.7435 - mae: 1.9697 - val_loss: 21.7617 - val_mae: 1.9797
# Epoch 332/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.7223 - mae: 1.9675 - val_loss: 21.7407 - val_mae: 1.9776
# Epoch 333/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.7017 - mae: 1.9654 - val_loss: 21.7194 - val_mae: 1.9757
# Epoch 334/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 20.6805 - mae: 1.9637 - val_loss: 21.6979 - val_mae: 1.9743
# Epoch 335/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.6594 - mae: 1.9622 - val_loss: 21.6765 - val_mae: 1.9727
# Epoch 336/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.6378 - mae: 1.9602 - val_loss: 21.6553 - val_mae: 1.9705
# Epoch 337/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 20.6170 - mae: 1.9585 - val_loss: 21.6337 - val_mae: 1.9694
# Epoch 338/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.5951 - mae: 1.9568 - val_loss: 21.6124 - val_mae: 1.9675
# Epoch 339/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 20.5740 - mae: 1.9551 - val_loss: 21.5908 - val_mae: 1.9659
# Epoch 340/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.5526 - mae: 1.9535 - val_loss: 21.5693 - val_mae: 1.9647
# Epoch 341/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 20.5313 - mae: 1.9521 - val_loss: 21.5475 - val_mae: 1.9632
# Epoch 342/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 20.5096 - mae: 1.9506 - val_loss: 21.5257 - val_mae: 1.9618
# Epoch 343/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 20.4879 - mae: 1.9491 - val_loss: 21.5038 - val_mae: 1.9602
# Epoch 344/1600
# 4/4 [==============================] - 0s 14ms/step - loss: 20.4662 - mae: 1.9470 - val_loss: 21.4820 - val_mae: 1.9580
# Epoch 345/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.4445 - mae: 1.9451 - val_loss: 21.4603 - val_mae: 1.9564
# Epoch 346/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.4231 - mae: 1.9432 - val_loss: 21.4384 - val_mae: 1.9545
# Epoch 347/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 20.4010 - mae: 1.9414 - val_loss: 21.4166 - val_mae: 1.9531
# Epoch 348/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 20.3791 - mae: 1.9396 - val_loss: 21.3948 - val_mae: 1.9510
# Epoch 349/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 20.3580 - mae: 1.9380 - val_loss: 21.3726 - val_mae: 1.9499
# Epoch 350/1600
# ...
# Epoch 1484/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 13.0417 - mae: 1.4585 - val_loss: 13.4296 - val_mae: 1.4601
# Epoch 1485/1600
# 4/4 [==============================] - 0s 30ms/step - loss: 13.0384 - mae: 1.4572 - val_loss: 13.4289 - val_mae: 1.4605
# Epoch 1486/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 13.0384 - mae: 1.4572 - val_loss: 13.4286 - val_mae: 1.4603
# Epoch 1487/1600
# 4/4 [==============================] - 0s 33ms/step - loss: 13.0368 - mae: 1.4559 - val_loss: 13.4285 - val_mae: 1.4587
# Epoch 1488/1600
# 4/4 [==============================] - 0s 27ms/step - loss: 13.0354 - mae: 1.4563 - val_loss: 13.4229 - val_mae: 1.4608
# Epoch 1489/1600
# 4/4 [==============================] - 0s 41ms/step - loss: 13.0345 - mae: 1.4569 - val_loss: 13.4235 - val_mae: 1.4600
# Epoch 1490/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 13.0353 - mae: 1.4600 - val_loss: 13.4188 - val_mae: 1.4651
# Epoch 1491/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 13.0312 - mae: 1.4598 - val_loss: 13.4172 - val_mae: 1.4604
# Epoch 1492/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 13.0296 - mae: 1.4578 - val_loss: 13.4141 - val_mae: 1.4613
# Epoch 1493/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 13.0256 - mae: 1.4572 - val_loss: 13.4143 - val_mae: 1.4593
# Epoch 1494/1600
# 4/4 [==============================] - 0s 36ms/step - loss: 13.0248 - mae: 1.4553 - val_loss: 13.4140 - val_mae: 1.4578
# Epoch 1495/1600
# 4/4 [==============================] - 0s 33ms/step - loss: 13.0264 - mae: 1.4540 - val_loss: 13.4144 - val_mae: 1.4571
# Epoch 1496/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 13.0232 - mae: 1.4536 - val_loss: 13.4122 - val_mae: 1.4598
# Epoch 1497/1600
# 4/4 [==============================] - 0s 32ms/step - loss: 13.0219 - mae: 1.4582 - val_loss: 13.4111 - val_mae: 1.4640
# Epoch 1498/1600
# 4/4 [==============================] - 0s 33ms/step - loss: 13.0213 - mae: 1.4605 - val_loss: 13.4104 - val_mae: 1.4637
# Epoch 1499/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 13.0180 - mae: 1.4592 - val_loss: 13.4061 - val_mae: 1.4603
# Epoch 1500/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 13.0161 - mae: 1.4556 - val_loss: 13.4072 - val_mae: 1.4576
# Epoch 1501/1600
# 4/4 [==============================] - 0s 29ms/step - loss: 13.0187 - mae: 1.4544 - val_loss: 13.4053 - val_mae: 1.4571
# Epoch 1502/1600
# 4/4 [==============================] - 0s 36ms/step - loss: 13.0116 - mae: 1.4553 - val_loss: 13.3999 - val_mae: 1.4617
# Epoch 1503/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 13.0133 - mae: 1.4592 - val_loss: 13.3973 - val_mae: 1.4642
# Epoch 1504/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 13.0119 - mae: 1.4595 - val_loss: 13.3968 - val_mae: 1.4616
# Epoch 1505/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 13.0169 - mae: 1.4607 - val_loss: 13.3967 - val_mae: 1.4629
# Epoch 1506/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 13.0071 - mae: 1.4563 - val_loss: 13.4024 - val_mae: 1.4542
# Epoch 1507/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0085 - mae: 1.4513 - val_loss: 13.3990 - val_mae: 1.4543
# Epoch 1508/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 13.0058 - mae: 1.4536 - val_loss: 13.3917 - val_mae: 1.4600
# Epoch 1509/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0030 - mae: 1.4579 - val_loss: 13.3895 - val_mae: 1.4624
# Epoch 1510/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0062 - mae: 1.4567 - val_loss: 13.3905 - val_mae: 1.4577
# Epoch 1511/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.9993 - mae: 1.4548 - val_loss: 13.3880 - val_mae: 1.4593
# Epoch 1512/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 13.0019 - mae: 1.4580 - val_loss: 13.3850 - val_mae: 1.4624
# Epoch 1513/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9995 - mae: 1.4566 - val_loss: 13.3843 - val_mae: 1.4577
# Epoch 1514/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.9959 - mae: 1.4552 - val_loss: 13.3801 - val_mae: 1.4581
# Epoch 1515/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.9936 - mae: 1.4552 - val_loss: 13.3797 - val_mae: 1.4579
# Epoch 1516/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9940 - mae: 1.4549 - val_loss: 13.3795 - val_mae: 1.4568
# Epoch 1517/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 13.0019 - mae: 1.4530 - val_loss: 13.3809 - val_mae: 1.4556
# Epoch 1518/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9935 - mae: 1.4568 - val_loss: 13.3744 - val_mae: 1.4652
# Epoch 1519/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9916 - mae: 1.4613 - val_loss: 13.3733 - val_mae: 1.4638
# Epoch 1520/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9876 - mae: 1.4595 - val_loss: 13.3704 - val_mae: 1.4595
# Epoch 1521/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9866 - mae: 1.4533 - val_loss: 13.3767 - val_mae: 1.4527
# Epoch 1522/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9882 - mae: 1.4505 - val_loss: 13.3740 - val_mae: 1.4546
# Epoch 1523/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9903 - mae: 1.4562 - val_loss: 13.3679 - val_mae: 1.4642
# Epoch 1524/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9843 - mae: 1.4590 - val_loss: 13.3675 - val_mae: 1.4594
# Epoch 1525/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9819 - mae: 1.4542 - val_loss: 13.3686 - val_mae: 1.4561
# Epoch 1526/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9801 - mae: 1.4548 - val_loss: 13.3634 - val_mae: 1.4603
# Epoch 1527/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9789 - mae: 1.4557 - val_loss: 13.3608 - val_mae: 1.4585
# Epoch 1528/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9824 - mae: 1.4582 - val_loss: 13.3584 - val_mae: 1.4623
# Epoch 1529/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9774 - mae: 1.4562 - val_loss: 13.3606 - val_mae: 1.4560
# Epoch 1530/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9746 - mae: 1.4519 - val_loss: 13.3605 - val_mae: 1.4537
# Epoch 1531/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9751 - mae: 1.4513 - val_loss: 13.3540 - val_mae: 1.4578
# Epoch 1532/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9696 - mae: 1.4550 - val_loss: 13.3546 - val_mae: 1.4605
# Epoch 1533/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9720 - mae: 1.4583 - val_loss: 13.3537 - val_mae: 1.4609
# Epoch 1534/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9685 - mae: 1.4580 - val_loss: 13.3498 - val_mae: 1.4597
# Epoch 1535/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9680 - mae: 1.4534 - val_loss: 13.3544 - val_mae: 1.4539
# Epoch 1536/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.9663 - mae: 1.4510 - val_loss: 13.3497 - val_mae: 1.4556
# Epoch 1537/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9634 - mae: 1.4549 - val_loss: 13.3431 - val_mae: 1.4618
# Epoch 1538/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9658 - mae: 1.4605 - val_loss: 13.3424 - val_mae: 1.4644
# Epoch 1539/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.9616 - mae: 1.4574 - val_loss: 13.3441 - val_mae: 1.4558
# Epoch 1540/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9609 - mae: 1.4528 - val_loss: 13.3430 - val_mae: 1.4552
# Epoch 1541/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.9580 - mae: 1.4524 - val_loss: 13.3415 - val_mae: 1.4550
# Epoch 1542/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9576 - mae: 1.4511 - val_loss: 13.3432 - val_mae: 1.4546
# Epoch 1543/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9575 - mae: 1.4516 - val_loss: 13.3415 - val_mae: 1.4580
# Epoch 1544/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9526 - mae: 1.4551 - val_loss: 13.3389 - val_mae: 1.4606
# Epoch 1545/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9609 - mae: 1.4607 - val_loss: 13.3382 - val_mae: 1.4655
# Epoch 1546/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9617 - mae: 1.4573 - val_loss: 13.3354 - val_mae: 1.4549
# Epoch 1547/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9533 - mae: 1.4507 - val_loss: 13.3342 - val_mae: 1.4543
# Epoch 1548/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.9486 - mae: 1.4535 - val_loss: 13.3285 - val_mae: 1.4590
# Epoch 1549/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9466 - mae: 1.4561 - val_loss: 13.3273 - val_mae: 1.4590
# Epoch 1550/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9459 - mae: 1.4554 - val_loss: 13.3257 - val_mae: 1.4579
# Epoch 1551/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9431 - mae: 1.4534 - val_loss: 13.3277 - val_mae: 1.4552
# Epoch 1552/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9456 - mae: 1.4532 - val_loss: 13.3263 - val_mae: 1.4561
# Epoch 1553/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9418 - mae: 1.4532 - val_loss: 13.3270 - val_mae: 1.4549
# Epoch 1554/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9465 - mae: 1.4498 - val_loss: 13.3315 - val_mae: 1.4525
# Epoch 1555/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9422 - mae: 1.4527 - val_loss: 13.3224 - val_mae: 1.4611
# Epoch 1556/1600
# 4/4 [==============================] - 0s 24ms/step - loss: 12.9398 - mae: 1.4583 - val_loss: 13.3217 - val_mae: 1.4613
# Epoch 1557/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9398 - mae: 1.4551 - val_loss: 13.3229 - val_mae: 1.4547
# Epoch 1558/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9367 - mae: 1.4525 - val_loss: 13.3157 - val_mae: 1.4571
# Epoch 1559/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9338 - mae: 1.4535 - val_loss: 13.3163 - val_mae: 1.4566
# Epoch 1560/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9350 - mae: 1.4525 - val_loss: 13.3159 - val_mae: 1.4558
# Epoch 1561/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9350 - mae: 1.4559 - val_loss: 13.3114 - val_mae: 1.4624
# Epoch 1562/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9335 - mae: 1.4578 - val_loss: 13.3127 - val_mae: 1.4573
# Epoch 1563/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9272 - mae: 1.4527 - val_loss: 13.3137 - val_mae: 1.4542
# Epoch 1564/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9324 - mae: 1.4527 - val_loss: 13.3115 - val_mae: 1.4566
# Epoch 1565/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9276 - mae: 1.4515 - val_loss: 13.3112 - val_mae: 1.4530
# Epoch 1566/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9240 - mae: 1.4512 - val_loss: 13.3064 - val_mae: 1.4563
# Epoch 1567/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9314 - mae: 1.4564 - val_loss: 13.3038 - val_mae: 1.4623
# Epoch 1568/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9230 - mae: 1.4578 - val_loss: 13.3015 - val_mae: 1.4580
# Epoch 1569/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9201 - mae: 1.4527 - val_loss: 13.3074 - val_mae: 1.4526
# Epoch 1570/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9214 - mae: 1.4503 - val_loss: 13.3068 - val_mae: 1.4527
# Epoch 1571/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9198 - mae: 1.4491 - val_loss: 13.3082 - val_mae: 1.4528
# Epoch 1572/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9213 - mae: 1.4526 - val_loss: 13.2986 - val_mae: 1.4593
# Epoch 1573/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.9173 - mae: 1.4544 - val_loss: 13.2984 - val_mae: 1.4559
# Epoch 1574/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9131 - mae: 1.4532 - val_loss: 13.2960 - val_mae: 1.4571
# Epoch 1575/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9162 - mae: 1.4524 - val_loss: 13.2957 - val_mae: 1.4549
# Epoch 1576/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.9093 - mae: 1.4533 - val_loss: 13.2917 - val_mae: 1.4594
# Epoch 1577/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9121 - mae: 1.4575 - val_loss: 13.2909 - val_mae: 1.4607
# Epoch 1578/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9087 - mae: 1.4561 - val_loss: 13.2881 - val_mae: 1.4563
# Epoch 1579/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.9067 - mae: 1.4531 - val_loss: 13.2889 - val_mae: 1.4548
# Epoch 1580/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.9062 - mae: 1.4519 - val_loss: 13.2873 - val_mae: 1.4535
# Epoch 1581/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9046 - mae: 1.4496 - val_loss: 13.2883 - val_mae: 1.4520
# Epoch 1582/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 12.9041 - mae: 1.4500 - val_loss: 13.2863 - val_mae: 1.4548
# Epoch 1583/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 12.9026 - mae: 1.4534 - val_loss: 13.2811 - val_mae: 1.4581
# Epoch 1584/1600
# 4/4 [==============================] - 0s 26ms/step - loss: 12.9029 - mae: 1.4558 - val_loss: 13.2807 - val_mae: 1.4579
# Epoch 1585/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.8999 - mae: 1.4536 - val_loss: 13.2822 - val_mae: 1.4544
# Epoch 1586/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 12.8997 - mae: 1.4524 - val_loss: 13.2806 - val_mae: 1.4562
# Epoch 1587/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.8965 - mae: 1.4527 - val_loss: 13.2800 - val_mae: 1.4556
# Epoch 1588/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 12.8979 - mae: 1.4537 - val_loss: 13.2779 - val_mae: 1.4575
# Epoch 1589/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.8939 - mae: 1.4532 - val_loss: 13.2777 - val_mae: 1.4537
# Epoch 1590/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.9070 - mae: 1.4479 - val_loss: 13.2818 - val_mae: 1.4511
# Epoch 1591/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.8898 - mae: 1.4508 - val_loss: 13.2729 - val_mae: 1.4590
# Epoch 1592/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.8920 - mae: 1.4576 - val_loss: 13.2717 - val_mae: 1.4626
# Epoch 1593/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 12.8921 - mae: 1.4571 - val_loss: 13.2682 - val_mae: 1.4572
# Epoch 1594/1600
# 4/4 [==============================] - 0s 35ms/step - loss: 12.8878 - mae: 1.4520 - val_loss: 13.2737 - val_mae: 1.4520
# Epoch 1595/1600
# 4/4 [==============================] - 0s 22ms/step - loss: 12.8877 - mae: 1.4489 - val_loss: 13.2709 - val_mae: 1.4522
# Epoch 1596/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.8889 - mae: 1.4493 - val_loss: 13.2657 - val_mae: 1.4537
# Epoch 1597/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.8987 - mae: 1.4556 - val_loss: 13.2622 - val_mae: 1.4622
# Epoch 1598/1600
# 4/4 [==============================] - 0s 21ms/step - loss: 12.8835 - mae: 1.4568 - val_loss: 13.2635 - val_mae: 1.4547
# Epoch 1599/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.8908 - mae: 1.4479 - val_loss: 13.2759 - val_mae: 1.4481
# Epoch 1600/1600
# 4/4 [==============================] - 0s 23ms/step - loss: 12.8835 - mae: 1.4469 - val_loss: 13.2653 - val_mae: 1.4544
