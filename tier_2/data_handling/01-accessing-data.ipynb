# %% [markdown]
# # Accessing data with CliMetLab
#
# Here are a few examples on how to get data into python using CliMetLab.
#
# More examples can be found in the CliMetLab documentation (https://climetlab.readthedocs.io/en/latest/examples.html).

# %% [markdown]
# ## How to run this exercise
#
# This exercise is in the form of a [Jupyter notebook](https://jupyter.org/). It can be "run" in a number of free cloud based environments (see two options below). These require no installation. When you click on one of the links below ([`Open in Colab`](https://colab.research.google.com/github/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/data_handling/01-accessing-data.ipynb) or [`Launch in Deepnote`](https://deepnote.com/launch?url=https://github.com/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/data_handling/01-accessing-data.ipynb)) you will be prompted to create a free account, after which you will see the same page you see here. You can run each block of code by selecting shift+control repeatedly, or by selecting the "play" icon.
#
# Advanced users may wish to run this exercise on their own computers by first installing [Python](https://www.python.org/downloads/), [Jupyter](https://jupyter.org/install) and [CliMetLab](https://climetlab.readthedocs.io/en/latest/installing.html).

# %% [markdown]
# <style>
# td, th {
#    border: 1px solid white;
#    border-collapse: collapse;
# }
# </style>
# <table align="left">
#   <tr>
#     <th>Run the tutorial via free cloud platforms: </th>
#     <th><a href="https://colab.research.google.com/github/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/data_handling/01-accessing-data.ipynb">
#         <img src = "https://colab.research.google.com/assets/colab-badge.svg" alt = "Colab"></th>
#     <th><a href="https://deepnote.com/launch?url=https://github.com/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/data_handling/01-accessing-data.ipynb">
#         <img src = "https://deepnote.com/buttons/launch-in-deepnote-small.svg" alt = "Kaggle"></th>
#   </tr>
# </table>

# %% [markdown]
# ## Loading various sources
#
# Now let's begin exploring data with CliMetLab. We will start by loading various "sources". A source is "something providing data". It needs some parameters to define the actual location of the data. For instance, a source can be a URL, a remote or local server, a database, or a file, etc.
#
# Below are a few examples of using ``cml.load_source()``.
#
# Notice how:
# - The API to retrieve the data is similar.
# - Credentials are requested if needed with appropriate help message, then saved locally.
# - Data is provided as pandas.Dataframe or xarray.Dataset.

# %% [markdown]
# Let's download some files for the examples:

# %%
# !test -f test.grib || wget https://github.com/ecmwf/climetlab/raw/main/docs/examples/test.grib
# !test -f test.nc || wget https://github.com/ecmwf/climetlab/raw/main/docs/examples/test.nc
# !test -f temp.bufr || wget http://download.ecmwf.int/test-data/metview/gallery/temp.bufr
# Out:
# --2023-04-28 11:59:38--  https://github.com/ecmwf/climetlab/raw/main/docs/examples/test.grib
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ecmwf/climetlab/main/docs/examples/test.grib [following]
# --2023-04-28 11:59:38--  https://raw.githubusercontent.com/ecmwf/climetlab/main/docs/examples/test.grib
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1052 (1.0K) [application/octet-stream]
# Saving to: ‘test.grib’
#
# test.grib           100%[===================>]   1.03K  --.-KB/s    in 0s
#
# 2023-04-28 11:59:38 (34.7 MB/s) - ‘test.grib’ saved [1052/1052]
#
# --2023-04-28 11:59:38--  https://github.com/ecmwf/climetlab/raw/main/docs/examples/test.nc
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ecmwf/climetlab/main/docs/examples/test.nc [following]
# --2023-04-28 11:59:39--  https://raw.githubusercontent.com/ecmwf/climetlab/main/docs/examples/test.nc
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6504 (6.4K) [application/octet-stream]
# Saving to: ‘test.nc’
#
# test.nc             100%[===================>]   6.35K  --.-KB/s    in 0s
#
# 2023-04-28 11:59:39 (30.0 MB/s) - ‘test.nc’ saved [6504/6504]
#
# --2023-04-28 11:59:39--  http://download.ecmwf.int/test-data/metview/gallery/temp.bufr
# Resolving download.ecmwf.int (download.ecmwf.int)... 136.156.180.69
# Connecting to download.ecmwf.int (download.ecmwf.int)|136.156.180.69|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 497568 (486K) [application/octet-stream]
# Saving to: ‘temp.bufr’
#
# temp.bufr           100%[===================>] 485.91K   363KB/s    in 1.3s
#
# 2023-04-28 11:59:41 (363 KB/s) - ‘temp.bufr’ saved [497568/497568]

# %% [markdown]
# ## Install and import CliMetLab

# %%
# !pip install climetlab
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting climetlab
#   Downloading climetlab-0.14.23.tar.gz (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.5/177.5 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from climetlab) (0.12.0)
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (from climetlab) (2022.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from climetlab) (3.12.0)
# Collecting cfgrib>=0.9.10.1
#   Downloading cfgrib-0.9.10.3.tar.gz (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 67.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from climetlab) (2.3.0)
# Collecting ecmwf-opendata>=0.1.2
#   Downloading ecmwf-opendata-0.2.0.tar.gz (23 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xarray>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from climetlab) (2022.12.0)
# Collecting numpngw
#   Downloading numpngw-0.1.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from climetlab) (4.65.0)
# Collecting netcdf4
#   Downloading netCDF4-1.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 69.2 MB/s eta 0:00:00
# Collecting cdsapi
#   Downloading cdsapi-0.6.1.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting multiurl>=0.1.0
#   Downloading multiurl-0.2.1.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from climetlab) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from climetlab) (2.27.1)
# Requirement already satisfied: branca in /usr/local/lib/python3.10/dist-packages (from climetlab) (0.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from climetlab) (1.5.3)
# Collecting ecmwf-api-client>=1.6.1
#   Downloading ecmwf-api-client-1.6.3.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from climetlab) (0.4)
# Collecting pyodc
#   Downloading pyodc-1.1.4.tar.gz (26 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting eccodes>=1.3.0
#   Downloading eccodes-1.5.2.tar.gz (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 50.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from climetlab) (6.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from climetlab) (2.25.1)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from climetlab) (3.4.3)
# Collecting pdbufr
#   Downloading pdbufr-0.10.1.tar.gz (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 63.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting magics>=1.5.6
#   Downloading Magics-1.5.8.tar.gz (22 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ecmwflibs
#   Downloading ecmwflibs-0.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (76.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 MB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2 in /usr/local/lib/python3.10/dist-packages (from cfgrib>=0.9.10.1->climetlab) (23.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from cfgrib>=0.9.10.1->climetlab) (8.1.3)
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from eccodes>=1.3.0->climetlab) (1.15.1)
# Collecting findlibs
#   Downloading findlibs-0.0.5.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from multiurl>=0.1.0->climetlab) (2022.7.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from multiurl>=0.1.0->climetlab) (2.8.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray>=0.19.0->climetlab) (23.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from branca->climetlab) (3.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->climetlab) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->climetlab) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->climetlab) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->climetlab) (1.26.15)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask->climetlab) (2.2.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask->climetlab) (2023.4.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask->climetlab) (1.4.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio->climetlab) (8.4.0)
# Collecting cftime
#   Downloading cftime-1.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.3 MB/s eta 0:00:00
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask->climetlab) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->multiurl>=0.1.0->climetlab) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->eccodes>=1.3.0->climetlab) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->branca->climetlab) (2.1.2)
# Building wheels for collected packages: climetlab, cfgrib, eccodes, ecmwf-api-client, ecmwf-opendata, magics, multiurl, cdsapi, pdbufr, pyodc, findlibs
#   Building wheel for climetlab (pyproject.toml) ... done
#   Created wheel for climetlab: filename=climetlab-0.14.23-py3-none-any.whl size=291327 sha256=402897b7c1a2d1a0bc0e1121acfe8f6c4bb6c29afe5dcdb65ec9cdcd42111544
#   Stored in directory: /root/.cache/pip/wheels/76/d6/cc/340cd3128907c746ff7b4bb1b20bae39f07fa389a6c068fa7b
#   Building wheel for cfgrib (pyproject.toml) ... done
#   Created wheel for cfgrib: filename=cfgrib-0.9.10.3-py3-none-any.whl size=46719 sha256=0c40257afbf824c4a2f9d0cfbdb54b99cd3e4e5ce0c3c31988b9bb8a0036a296
#   Stored in directory: /root/.cache/pip/wheels/64/d8/f6/7caecd8a01d42f7db5a764d8c06dbb2dced1a2aa9d9c1920d5
#   Building wheel for eccodes (setup.py) ... done
#   Created wheel for eccodes: filename=eccodes-1.5.2-py3-none-any.whl size=40562 sha256=52c9ac8cc16d39d874e54bec2207b082b8772849bfc8d36f8a51243a7feee318
#   Stored in directory: /root/.cache/pip/wheels/30/a8/9b/b80ae7683c2187d95eab008b4c57a5a57c50836aef413262a5
#   Building wheel for ecmwf-api-client (setup.py) ... done
#   Created wheel for ecmwf-api-client: filename=ecmwf_api_client-1.6.3-py3-none-any.whl size=13530 sha256=a7d44759e812c1554fa4778feb689132c328b83be70a40eee9658d61fa974f23
#   Stored in directory: /root/.cache/pip/wheels/16/64/8f/f0038cd123b884423739feea02cd13466b01ec8b08e5d1de93
#   Building wheel for ecmwf-opendata (setup.py) ... done
#   Created wheel for ecmwf-opendata: filename=ecmwf_opendata-0.2.0-py3-none-any.whl size=19620 sha256=c8aa89d9d0e90750c1c4fefdb0bc476c09cb32eb2473922c0084cd2a21f71e10
#   Stored in directory: /root/.cache/pip/wheels/8a/23/f4/eed8e507e7ae509e28001a57989df930cf34ede73065edce75
#   Building wheel for magics (setup.py) ... done
#   Created wheel for magics: filename=Magics-1.5.8-py2.py3-none-any.whl size=24868 sha256=f347429b0a1e3a805ef1d66e2f0fb269be86f029fe0bcc9a4303e90c32077942
#   Stored in directory: /root/.cache/pip/wheels/fe/d6/fb/7cd27dba96cf9fe081152512dce8cbc1a32faeeb6615de62af
#   Building wheel for multiurl (setup.py) ... done
#   Created wheel for multiurl: filename=multiurl-0.2.1-py3-none-any.whl size=21097 sha256=972747cb25597e9f41d86c79cd885d5cfc4bc9ed0621aed6cc993cf7c8cccbd0
#   Stored in directory: /root/.cache/pip/wheels/01/01/39/e2518f9172b2ae75ea8d8dead504f7c9a70454f9622a8ad5d7
#   Building wheel for cdsapi (setup.py) ... done
#   Created wheel for cdsapi: filename=cdsapi-0.6.1-py2.py3-none-any.whl size=12021 sha256=cf29f780d0b0258ff9032db0eeb6f9177ee5329b61a77c769fb6da25bf8b6eed
#   Stored in directory: /root/.cache/pip/wheels/7c/63/08/45461d6f6636c1aba7846828d8c787a064073945048f76d44a
#   Building wheel for pdbufr (pyproject.toml) ... done
#   Created wheel for pdbufr: filename=pdbufr-0.10.1-py3-none-any.whl size=21785 sha256=ef73f2231e078652e05ac85e6b325ee49b76ed3592ede2f132e9e0a6604ac4c6
#   Stored in directory: /root/.cache/pip/wheels/b0/05/11/10fd29d5c2d65e5291e4801153f18246d153a49d780035bcd7
#   Building wheel for pyodc (pyproject.toml) ... done
#   Created wheel for pyodc: filename=pyodc-1.1.4-py3-none-any.whl size=28061 sha256=cb1169f5c6c640ad84f7a52da0871c9501652cb0706a6bbd12a3b68aa9678bba
#   Stored in directory: /root/.cache/pip/wheels/3b/f2/e5/18b1508f043a3188c75a8bf4f094ef58164b31faf229999ba3
#   Building wheel for findlibs (setup.py) ... done
#   Created wheel for findlibs: filename=findlibs-0.0.5-py3-none-any.whl size=6954 sha256=a9bdd27ab7faf679e5d4b9792bbd0eb50a0e374cd60d4f4cc314cf8269dcc384
#   Stored in directory: /root/.cache/pip/wheels/2e/67/14/22fa5b9fd9c41be520b37e908597d6a262803c0fcf2ba7c2c3
# Successfully built climetlab cfgrib eccodes ecmwf-api-client ecmwf-opendata magics multiurl cdsapi pdbufr pyodc findlibs
# Installing collected packages: findlibs, ecmwf-api-client, numpngw, magics, ecmwflibs, cftime, netcdf4, multiurl, eccodes, cdsapi, pyodc, pdbufr, ecmwf-opendata, cfgrib, climetlab
# Successfully installed cdsapi-0.6.1 cfgrib-0.9.10.3 cftime-1.6.2 climetlab-0.14.23 eccodes-1.5.2 ecmwf-api-client-1.6.3 ecmwf-opendata-0.2.0 ecmwflibs-0.5.3 findlibs-0.0.5 magics-1.5.8 multiurl-0.2.1 netcdf4-1.6.3 numpngw-0.1.2 pdbufr-0.10.1 pyodc-1.1.4

# %%
import climetlab as cml

# %% [markdown]
# ## Read data

# %% [markdown]
# How to read data from a GRIB file:

# %%
ds = cml.load_source('file', 'test.grib')
for field in ds:
	cml.plot_map(field)
ds.to_xarray()
# Out:
# <xarray.Dataset>
# Dimensions:     (number: 1, time: 1, step: 1, surface: 1, latitude: 11,
#                  longitude: 19)
# Coordinates:
#   * number      (number) int64 0
#   * time        (time) datetime64[ns] 2020-05-13T12:00:00
#   * step        (step) timedelta64[ns] 00:00:00
#   * surface     (surface) float64 0.0
#   * latitude    (latitude) float64 73.0 69.0 65.0 61.0 ... 45.0 41.0 37.0 33.0
#   * longitude   (longitude) float64 -27.0 -23.0 -19.0 -15.0 ... 37.0 41.0 45.0
#     valid_time  (time, step) datetime64[ns] ...
# Data variables:
#     t2m         (number, time, step, surface, latitude, longitude) float32 ...
#     msl         (number, time, step, surface, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2023-02-17T11:34 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# How to read data from a netCDF file:

# %%
ds = cml.load_source('file', 'test.nc')
for field in ds:
	cml.plot_map(field)
ds.to_xarray()
# Out:
# <xarray.Dataset>
# Dimensions:     (longitude: 19, latitude: 11)
# Coordinates:
#   * longitude   (longitude) float64 -27.0 -23.0 -19.0 -15.0 ... 37.0 41.0 45.0
#   * latitude    (latitude) float64 73.0 69.0 65.0 61.0 ... 45.0 41.0 37.0 33.0
#     number      int32 ...
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     surface     int32 ...
#     valid_time  datetime64[ns] ...
# Data variables:
#     t2m         (latitude, longitude) float32 dask.array<chunksize=(11, 19), meta=np.ndarray>
#     msl         (latitude, longitude) float32 dask.array<chunksize=(11, 19), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 GRIB to CDM+CF via cfgrib-0.9.5/ecCodes-2.17.0 w...

# %% [markdown]
# How to read data from a BUFR file:

# %%
ds = cml.load_source('file', 'temp.bufr')
df = ds.to_pandas(
    columns=(
        "stationNumber",
        "latitude",
        "longitude",
        "data_datetime",
        "pressure",
        "airTemperature",
    ),
    filters={},
)
cml.plot_map(df, projection="global")
df
# Out:
#        stationNumber  latitude  longitude  pressure  airTemperature  \
# 0                907     58.47     -78.08  100300.0           258.3
# 1                907     58.47     -78.08  100000.0           259.7
# 2                907     58.47     -78.08   99800.0           261.1
# 3                907     58.47     -78.08   99100.0           261.7
# 4                907     58.47     -78.08   92500.0           258.1
# ...              ...       ...        ...       ...             ...
# 26000            968     25.03     121.52   10000.0           197.9
# 26001            968     25.03     121.52    9520.0           196.3
# 26002            968     25.03     121.52    7000.0           201.5
# 26003            968     25.03     121.52    5000.0           209.1
# 26004            968     25.03     121.52    3000.0           217.3
#
#             data_datetime
# 0     2008-12-08 12:00:00
# 1     2008-12-08 12:00:00
# 2     2008-12-08 12:00:00
# 3     2008-12-08 12:00:00
# 4     2008-12-08 12:00:00
# ...                   ...
# 26000 2008-12-08 12:00:00
# 26001 2008-12-08 12:00:00
# 26002 2008-12-08 12:00:00
# 26003 2008-12-08 12:00:00
# 26004 2008-12-08 12:00:00
#
# [26005 rows x 6 columns]

# %% [markdown]
# The purpose of the "file" source is to open **any** file, CliMetLab guesses what type of file is provided.

# %% [markdown]
# ## Reading from a URL `cml.load_source("url", URL)`

# %% [markdown]
# How to read data from a GRIB URL (using the climetlab source "url")

# %%
ds = cml.load_source('url', 'https://github.com/ecmwf/climetlab/raw/main/docs/examples/test.grib')
for field in ds:
	cml.plot_map(field)
ds.to_xarray()
# Out:
# test.grib:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# <xarray.Dataset>
# Dimensions:     (number: 1, time: 1, step: 1, surface: 1, latitude: 11,
#                  longitude: 19)
# Coordinates:
#   * number      (number) int64 0
#   * time        (time) datetime64[ns] 2020-05-13T12:00:00
#   * step        (step) timedelta64[ns] 00:00:00
#   * surface     (surface) float64 0.0
#   * latitude    (latitude) float64 73.0 69.0 65.0 61.0 ... 45.0 41.0 37.0 33.0
#   * longitude   (longitude) float64 -27.0 -23.0 -19.0 -15.0 ... 37.0 41.0 45.0
#     valid_time  (time, step) datetime64[ns] ...
# Data variables:
#     t2m         (number, time, step, surface, latitude, longitude) float32 ...
#     msl         (number, time, step, surface, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2023-04-28T12:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
cml.load_source('url', 'https://github.com/ecmwf/climetlab/raw/main/docs/examples/test.nc')
cml.load_source('url', 'http://download.ecmwf.int/test-data/metview/gallery/temp.bufr')
# Out:
# test.nc:   0%|          | 0.00/6.35k [00:00<?, ?B/s]
# temp.bufr:   0%|          | 0.00/486k [00:00<?, ?B/s]
# Url(http://download.ecmwf.int/test-data/metview/gallery/temp.bufr)

# %%
# Downloading 32M of data.
URL = "https://www.ncei.noaa.gov/data/international-best-track-archive-for-climate-stewardship-ibtracs/v04r00/access/csv/ibtracs.SP.list.v04r00.csv"
data = cml.load_source("url", URL)
pd = data.to_pandas()
# Out:
# ibtracs.SP.list.v04r00.csv:   0%|          | 0.00/33.2M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/climetlab/readers/csv.py:146: DtypeWarning: Columns (1,2,8,9,14,161,162) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pandas.read_csv(self.path, **pandas_read_csv_kwargs)

# %%
uma = pd[pd.NAME == "UMA:VELI"]
cml.plot_map(uma, style="cyclone-track")

# %% [markdown]
# As shown below, data can be read from different sources, the API is similar: "load_source" with keywords to specify the data requested.

# %%
source = cml.load_source(
    "ecmwf-open-data",
    param=["2t", "msl"],
)
for s in source:
    cml.plot_map(s, title=True)
source.to_xarray()
# Out:
# <multiple>:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# <xarray.Dataset>
# Dimensions:            (time: 1, step: 1, heightAboveGround: 1, latitude: 451,
#                         longitude: 900, meanSea: 1)
# Coordinates:
#   * time               (time) datetime64[ns] 2023-04-28
#   * step               (step) timedelta64[ns] 00:00:00
#   * heightAboveGround  (heightAboveGround) float64 2.0
#   * latitude           (latitude) float64 90.0 89.6 89.2 ... -89.2 -89.6 -90.0
#   * longitude          (longitude) float64 -180.0 -179.6 -179.2 ... 179.2 179.6
#     valid_time         (time, step) datetime64[ns] ...
#   * meanSea            (meanSea) float64 0.0
# Data variables:
#     t2m                (time, step, heightAboveGround, latitude, longitude) float32 ...
#     msl                (time, step, meanSea, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2023-04-28T12:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# In order to run the following cell you need to register to the Climate Data Store (free) and enter your API key. When running the next cell, CliMetLab asks for two pieces of information: the API url (leave blank to use the default) and API key. Below is an example of the prompt generated by CliMetLab to requests your input. You only have to enter them once.
#
# **No registration to the CDS or MARS is required to follow the MOOC:** While interactive learning proved to be better than simply reading, you do not need to run the cells using the "cds" or "mars" to complete this MOOC.

# %% [markdown]
# <img src="https://github.com/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/data_handling/screenshot-cds-api.png?raw=1" alt="CDSAPI prompts" />

# %%
source = cml.load_source(
    "cds",
    "reanalysis-era5-single-levels",
    variable=["2t", "msl"],
    product_type="reanalysis",
    area=[50, -50, 20, 50],
    date="2011-12-02", # ["2011-12-02", "2011-12-03"] for several dates
    time="12:00",
)
for s in source:
    cml.plot_map(s)
# Out:
# <div style='border: 1px solid orange; color: black;
#      background-color: rgb(255, 214, 0);
#      margin: 0.5em; padding: 0.5em; font-weight: bold;'>
# <p>An API key is needed to access this dataset. Please visit
# <a href="https://cds.climate.copernicus.eu/">https://cds.climate.copernicus.eu/</a> to register or sign-in
# then visit <a href="https://cds.climate.copernicus.eu/api-how-to">https://cds.climate.copernicus.eu/api-how-to</a> to retrieve you API key.</p>
# </div>
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API url</span> or leave empty for the default value <span style='color: red;'>https://cds.climate.copernicus.eu/api/v2</span>, then press <em>ENTER</em></p>
# </div>
# API url:
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API key</span>, then press <em>ENTER</em> The value should look like  <span style='color: red;'>123:abcdef01-0000-1111-2222-0123456789ab</span></p>
# </div>
# API key: ··········
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-5ede8477f04f> in <cell line: 1>()
# ----> 1 source = cml.load_source(
#       2     "cds",
#       3     "reanalysis-era5-single-levels",
#       4     variable=["2t", "msl"],
#       5     product_type="reanalysis",
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in load_source(name, lazily, *args, **kwargs)
#     176
#     177     prev = None
# --> 178     src = get_source(name, *args, **kwargs)
#     179     while src is not prev:
#     180         prev = src
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in __call__(self, name, *args, **kwargs)
#     157             klass = SourceMockup
#     158
# --> 159         source = klass(*args, **kwargs)
#     160
#     161         if getattr(source, "name", None) is None:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/__init__.py in __call__(cls, *args, **kwargs)
#      23         obj = cls.__new__(cls, *args, **kwargs)
#      24         args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 25         obj.__init__(*args, **kwargs)
#      26         return obj
#      27
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/cds.py in __init__(self, dataset, *args, **kwargs)
#      82         requests = self.requests(**kwargs)
#      83
# ---> 84         client()  # Trigger password prompt before thraeding
#      85
#      86         nthreads = min(self.settings("number-of-download-threads"), len(requests))
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/cds.py in client()
#      47 def client():
#      48     prompt = CDSAPIKeyPrompt()
# ---> 49     prompt.check()
#      50
#      51     try:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in check(self, load)
#     126         rcfile = os.path.expanduser(self.rcfile)
#     127         if not os.path.exists(rcfile):
# --> 128             self.ask_user_and_save()
#     129
#     130         if load:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user_and_save(self)
#     141
#     142     def ask_user_and_save(self):
# --> 143         input = self.ask_user()
#     144
#     145         rcfile = os.path.expanduser(self.rcfile)
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#     138             prompt = Text(self)
#     139
# --> 140         return self.validate(prompt.ask_user())
#     141
#     142     def ask_user_and_save(self):
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#      74                     validate = RegexValidate(validate)
#      75
# ---> 76                 value = validate(value)
#      77
#      78             result[p["name"]] = value
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in __call__(self, value)
#      51
#      52     def __call__(self, value):
# ---> 53         assert re.fullmatch(self.pattern, value), (self.pattern, value)
#      54         return value
#      55
#
# AssertionError: ('\\d+:[\\-0-9a-f]+', '')

# %%
source = cml.load_source(
    "mars",
    param=["2t", "msl"],
    levtype="sfc",
    area=[50, -50, 20, 50],
    grid=[1, 1],
    date="2011-12-02",
    
)
for s in source:
    cml.plot_map(s)
source.to_xarray()
# Out:
# <div style='border: 1px solid orange; color: black;
#      background-color: rgb(255, 214, 0);
#      margin: 0.5em; padding: 0.5em; font-weight: bold;'>
# <p>An API key is needed to access this dataset. Please visit
# <a href="https://www.ecmwf.int/user/login/sso">https://www.ecmwf.int/user/login/sso</a> to register or sign-in
# then visit <a href="https://api.ecmwf.int/v1/key/">https://api.ecmwf.int/v1/key/</a> to retrieve you API key.</p>
# </div>
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API url</span> or leave empty for the default value <span style='color: red;'>https://api.ecmwf.int/v1</span>, then press <em>ENTER</em></p>
# </div>
# API url:
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API key</span>, then press <em>ENTER</em> The value should look like  <span style='color: red;'>b295aad8af30332fad2fa8c963ab7900</span></p>
# </div>
# API key: ··········
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-f8b0a934347e> in <cell line: 1>()
# ----> 1 source = cml.load_source(
#       2     "mars",
#       3     param=["2t", "msl"],
#       4     levtype="sfc",
#       5     area=[50, -50, 20, 50],
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in load_source(name, lazily, *args, **kwargs)
#     176
#     177     prev = None
# --> 178     src = get_source(name, *args, **kwargs)
#     179     while src is not prev:
#     180         prev = src
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in __call__(self, name, *args, **kwargs)
#     157             klass = SourceMockup
#     158
# --> 159         source = klass(*args, **kwargs)
#     160
#     161         if getattr(source, "name", None) is None:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/__init__.py in __call__(cls, *args, **kwargs)
#      23         obj = cls.__new__(cls, *args, **kwargs)
#      24         args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 25         obj.__init__(*args, **kwargs)
#      26         return obj
#      27
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/ecmwf_api.py in __init__(self, *args, **kwargs)
#      58         requests = self.requests(**request)
#      59
# ---> 60         self.service()  # Trigger password prompt before threading
#      61
#      62         nthreads = min(self.settings("number-of-download-threads"), len(requests))
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/mars.py in service(self)
#      54
#      55         prompt = MARSAPIKeyPrompt()
# ---> 56         prompt.check()
#      57
#      58         try:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in check(self, load)
#     126         rcfile = os.path.expanduser(self.rcfile)
#     127         if not os.path.exists(rcfile):
# --> 128             self.ask_user_and_save()
#     129
#     130         if load:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user_and_save(self)
#     141
#     142     def ask_user_and_save(self):
# --> 143         input = self.ask_user()
#     144
#     145         rcfile = os.path.expanduser(self.rcfile)
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#     138             prompt = Text(self)
#     139
# --> 140         return self.validate(prompt.ask_user())
#     141
#     142     def ask_user_and_save(self):
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#      74                     validate = RegexValidate(validate)
#      75
# ---> 76                 value = validate(value)
#      77
#      78             result[p["name"]] = value
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in __call__(self, value)
#      51
#      52     def __call__(self, value):
# ---> 53         assert re.fullmatch(self.pattern, value), (self.pattern, value)
#      54         return value
#      55
#
# AssertionError: ('[0-9a-z]{32}', '')

# %%
import climetlab as cml
source = cml.load_source(
    "mars",
    type="ofb",
    obsgroup="conv",
    time="12",
    format="odb",
    reportype=16001,
    date="2020-05-18",
)
pd = source.to_pandas()
# Out:
# <div style='border: 1px solid orange; color: black;
#      background-color: rgb(255, 214, 0);
#      margin: 0.5em; padding: 0.5em; font-weight: bold;'>
# <p>An API key is needed to access this dataset. Please visit
# <a href="https://www.ecmwf.int/user/login/sso">https://www.ecmwf.int/user/login/sso</a> to register or sign-in
# then visit <a href="https://api.ecmwf.int/v1/key/">https://api.ecmwf.int/v1/key/</a> to retrieve you API key.</p>
# </div>
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API url</span> or leave empty for the default value <span style='color: red;'>https://api.ecmwf.int/v1</span>, then press <em>ENTER</em></p>
# </div>
# API url:
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API key</span>, then press <em>ENTER</em> The value should look like  <span style='color: red;'>b295aad8af30332fad2fa8c963ab7900</span></p>
# </div>
# API key: ··········
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-6a29c7937f86> in <cell line: 2>()
#       1 import climetlab as cml
# ----> 2 source = cml.load_source(
#       3     "mars",
#       4     type="ofb",
#       5     obsgroup="conv",
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in load_source(name, lazily, *args, **kwargs)
#     176
#     177     prev = None
# --> 178     src = get_source(name, *args, **kwargs)
#     179     while src is not prev:
#     180         prev = src
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in __call__(self, name, *args, **kwargs)
#     157             klass = SourceMockup
#     158
# --> 159         source = klass(*args, **kwargs)
#     160
#     161         if getattr(source, "name", None) is None:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/__init__.py in __call__(cls, *args, **kwargs)
#      23         obj = cls.__new__(cls, *args, **kwargs)
#      24         args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 25         obj.__init__(*args, **kwargs)
#      26         return obj
#      27
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/ecmwf_api.py in __init__(self, *args, **kwargs)
#      58         requests = self.requests(**request)
#      59
# ---> 60         self.service()  # Trigger password prompt before threading
#      61
#      62         nthreads = min(self.settings("number-of-download-threads"), len(requests))
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/mars.py in service(self)
#      54
#      55         prompt = MARSAPIKeyPrompt()
# ---> 56         prompt.check()
#      57
#      58         try:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in check(self, load)
#     126         rcfile = os.path.expanduser(self.rcfile)
#     127         if not os.path.exists(rcfile):
# --> 128             self.ask_user_and_save()
#     129
#     130         if load:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user_and_save(self)
#     141
#     142     def ask_user_and_save(self):
# --> 143         input = self.ask_user()
#     144
#     145         rcfile = os.path.expanduser(self.rcfile)
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#     138             prompt = Text(self)
#     139
# --> 140         return self.validate(prompt.ask_user())
#     141
#     142     def ask_user_and_save(self):
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#      74                     validate = RegexValidate(validate)
#      75
# ---> 76                 value = validate(value)
#      77
#      78             result[p["name"]] = value
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in __call__(self, value)
#      51
#      52     def __call__(self, value):
# ---> 53         assert re.fullmatch(self.pattern, value), (self.pattern, value)
#      54         return value
#      55
#
# AssertionError: ('[0-9a-z]{32}', '')

# %% [markdown]
# ## Dataset
#
# A dataset is a clearly identified set of data. It has a name, can be cited, has documentation and, hopefully, somebody is maintaining it.
#
# A dataset is an object created using cml.load_dataset(name, arg1, arg2=..., ...)
#
# - The name is a string that uniquely identifies the dataset.
# - The argument(s) arg1 and keyword argument(s) arg2 can be used to specify a subset of the dataset.
# - The data can be accessed using methods such as to_xarray() or to_pandas() or other.
# - Relevant metadata are attached directly to the dataset to provide additional information such as a URL, a citation, licence, etc.

# %% [markdown]
# ### Example dataset: hurricane database

# %%
atlantic = cml.load_dataset("hurricane-database", bassin="atlantic")
df = atlantic.to_pandas()
# Out:
# hurdat2.txt: 0.00B [00:00, ?B/s]

# %% [markdown]
# ### Example dataset: part of ERA5

# %%
import climetlab as cml
ds = cml.load_dataset("era5-temperature", 
#    period=(1979, 1999), # This can be long to run.
    period=(1979, 1981),
    domain="France",
    time=12,
 )
# Out:
# <div style='border: 1px solid orange; color: black;
#      background-color: rgb(255, 214, 0);
#      margin: 0.5em; padding: 0.5em; font-weight: bold;'>
# <p>An API key is needed to access this dataset. Please visit
# <a href="https://cds.climate.copernicus.eu/">https://cds.climate.copernicus.eu/</a> to register or sign-in
# then visit <a href="https://cds.climate.copernicus.eu/api-how-to">https://cds.climate.copernicus.eu/api-how-to</a> to retrieve you API key.</p>
# </div>
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API url</span> or leave empty for the default value <span style='color: red;'>https://cds.climate.copernicus.eu/api/v2</span>, then press <em>ENTER</em></p>
# </div>
# API url:
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API key</span>, then press <em>ENTER</em> The value should look like  <span style='color: red;'>123:abcdef01-0000-1111-2222-0123456789ab</span></p>
# </div>
# API key: ··········
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-20ee4ddf8b63> in <cell line: 2>()
#       1 import climetlab as cml
# ----> 2 ds = cml.load_dataset("era5-temperature",
#       3 #    period=(1979, 1999), # This can be long to run.
#       4     period=(1979, 1981),
#       5     domain="France",
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/__init__.py in load_dataset(name, *args, **kwargs)
#     278         TERMS_OF_USE_SHOWN.add(name)
#     279
# --> 280     ds = klass(*args, **kwargs).mutate()
#     281     if getattr(ds, "name", None) is None:
#     282         ds.name = name
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/__init__.py in __call__(cls, *args, **kwargs)
#      23         obj = cls.__new__(cls, *args, **kwargs)
#      24         args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 25         obj.__init__(*args, **kwargs)
#      26         return obj
#      27
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/era5_temperature.py in __init__(self, *args, **kwargs)
#      13 class Era5Temperature(Era5SingleLevels):
#      14     def __init__(self, *args, **kwargs):
# ---> 15         super().__init__("2t", *args, **kwargs)
#      16
#      17
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/era5_single_levels.py in __init__(self, variable, period, domain, time, grid)
#      48             request["year"] = year
#      49             sources.append(
# ---> 50                 load_source("cds", "reanalysis-era5-single-levels", **request)
#      51             )
#      52
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in load_source(name, lazily, *args, **kwargs)
#     176
#     177     prev = None
# --> 178     src = get_source(name, *args, **kwargs)
#     179     while src is not prev:
#     180         prev = src
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in __call__(self, name, *args, **kwargs)
#     157             klass = SourceMockup
#     158
# --> 159         source = klass(*args, **kwargs)
#     160
#     161         if getattr(source, "name", None) is None:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/__init__.py in __call__(cls, *args, **kwargs)
#      23         obj = cls.__new__(cls, *args, **kwargs)
#      24         args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 25         obj.__init__(*args, **kwargs)
#      26         return obj
#      27
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/cds.py in __init__(self, dataset, *args, **kwargs)
#      82         requests = self.requests(**kwargs)
#      83
# ---> 84         client()  # Trigger password prompt before thraeding
#      85
#      86         nthreads = min(self.settings("number-of-download-threads"), len(requests))
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/cds.py in client()
#      47 def client():
#      48     prompt = CDSAPIKeyPrompt()
# ---> 49     prompt.check()
#      50
#      51     try:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in check(self, load)
#     126         rcfile = os.path.expanduser(self.rcfile)
#     127         if not os.path.exists(rcfile):
# --> 128             self.ask_user_and_save()
#     129
#     130         if load:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user_and_save(self)
#     141
#     142     def ask_user_and_save(self):
# --> 143         input = self.ask_user()
#     144
#     145         rcfile = os.path.expanduser(self.rcfile)
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#     138             prompt = Text(self)
#     139
# --> 140         return self.validate(prompt.ask_user())
#     141
#     142     def ask_user_and_save(self):
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#      74                     validate = RegexValidate(validate)
#      75
# ---> 76                 value = validate(value)
#      77
#      78             result[p["name"]] = value
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in __call__(self, value)
#      51
#      52     def __call__(self, value):
# ---> 53         assert re.fullmatch(self.pattern, value), (self.pattern, value)
#      54         return value
#      55
#
# AssertionError: ('\\d+:[\\-0-9a-f]+', '')

# %%
ds.to_xarray()

# %% [markdown]
# Once the data has been downloaded, it is cached locally. The following will not download any additional data.

# %%
import climetlab as cml
ds = cml.load_dataset("era5-temperature", 
    period=1980,
    domain="France",
    time=12,
 )
# Out:
# <div style='border: 1px solid orange; color: black;
#      background-color: rgb(255, 214, 0);
#      margin: 0.5em; padding: 0.5em; font-weight: bold;'>
# <p>An API key is needed to access this dataset. Please visit
# <a href="https://cds.climate.copernicus.eu/">https://cds.climate.copernicus.eu/</a> to register or sign-in
# then visit <a href="https://cds.climate.copernicus.eu/api-how-to">https://cds.climate.copernicus.eu/api-how-to</a> to retrieve you API key.</p>
# </div>
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API url</span> or leave empty for the default value <span style='color: red;'>https://cds.climate.copernicus.eu/api/v2</span>, then press <em>ENTER</em></p>
# </div>
# API url:
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API key</span>, then press <em>ENTER</em> The value should look like  <span style='color: red;'>123:abcdef01-0000-1111-2222-0123456789ab</span></p>
# </div>
# API key: ··········
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-61b2fe391612> in <cell line: 2>()
#       1 import climetlab as cml
# ----> 2 ds = cml.load_dataset("era5-temperature",
#       3     period=1980,
#       4     domain="France",
#       5     time=12,
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/__init__.py in load_dataset(name, *args, **kwargs)
#     278         TERMS_OF_USE_SHOWN.add(name)
#     279
# --> 280     ds = klass(*args, **kwargs).mutate()
#     281     if getattr(ds, "name", None) is None:
#     282         ds.name = name
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/__init__.py in __call__(cls, *args, **kwargs)
#      23         obj = cls.__new__(cls, *args, **kwargs)
#      24         args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 25         obj.__init__(*args, **kwargs)
#      26         return obj
#      27
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/era5_temperature.py in __init__(self, *args, **kwargs)
#      13 class Era5Temperature(Era5SingleLevels):
#      14     def __init__(self, *args, **kwargs):
# ---> 15         super().__init__("2t", *args, **kwargs)
#      16
#      17
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/era5_single_levels.py in __init__(self, variable, period, domain, time, grid)
#      48             request["year"] = year
#      49             sources.append(
# ---> 50                 load_source("cds", "reanalysis-era5-single-levels", **request)
#      51             )
#      52
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in load_source(name, lazily, *args, **kwargs)
#     176
#     177     prev = None
# --> 178     src = get_source(name, *args, **kwargs)
#     179     while src is not prev:
#     180         prev = src
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in __call__(self, name, *args, **kwargs)
#     157             klass = SourceMockup
#     158
# --> 159         source = klass(*args, **kwargs)
#     160
#     161         if getattr(source, "name", None) is None:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/__init__.py in __call__(cls, *args, **kwargs)
#      23         obj = cls.__new__(cls, *args, **kwargs)
#      24         args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 25         obj.__init__(*args, **kwargs)
#      26         return obj
#      27
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/cds.py in __init__(self, dataset, *args, **kwargs)
#      82         requests = self.requests(**kwargs)
#      83
# ---> 84         client()  # Trigger password prompt before thraeding
#      85
#      86         nthreads = min(self.settings("number-of-download-threads"), len(requests))
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/cds.py in client()
#      47 def client():
#      48     prompt = CDSAPIKeyPrompt()
# ---> 49     prompt.check()
#      50
#      51     try:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in check(self, load)
#     126         rcfile = os.path.expanduser(self.rcfile)
#     127         if not os.path.exists(rcfile):
# --> 128             self.ask_user_and_save()
#     129
#     130         if load:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user_and_save(self)
#     141
#     142     def ask_user_and_save(self):
# --> 143         input = self.ask_user()
#     144
#     145         rcfile = os.path.expanduser(self.rcfile)
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#     138             prompt = Text(self)
#     139
# --> 140         return self.validate(prompt.ask_user())
#     141
#     142     def ask_user_and_save(self):
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#      74                     validate = RegexValidate(validate)
#      75
# ---> 76                 value = validate(value)
#      77
#      78             result[p["name"]] = value
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in __call__(self, value)
#      51
#      52     def __call__(self, value):
# ---> 53         assert re.fullmatch(self.pattern, value), (self.pattern, value)
#      54         return value
#      55
#
# AssertionError: ('\\d+:[\\-0-9a-f]+', '')

# %% [markdown]
# If the dataset is not found, CliMetLab provides the list of available datasets:

# %%
import climetlab as cml
cml.load_dataset('hurican-database-with-typo') # Asking for an unknown dataset with a typo
# For Github actions: skip
# Out:
# hurican-database-with-typo.yaml: 0.00B [00:00, ?B/s]
# WARNING:climetlab.core.plugins:Cannot find dataset 'hurican-database-with-typo', did you mean 'hurricane-database'?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-584b1b432620> in <cell line: 2>()
#       1 import climetlab as cml
# ----> 2 cml.load_dataset('hurican-database-with-typo') # Asking for an unknown dataset with a typo
#       3 # For Github actions: skip
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/__init__.py in load_dataset(name, *args, **kwargs)
#     271         The loaded dataset.
#     272     """
# --> 273     klass = get_dataset.lookup(name)
#     274
#     275     if name not in TERMS_OF_USE_SHOWN:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/__init__.py in lookup(self, name)
#     239     def lookup(self, name):
#     240         loader = DatasetLoader()
# --> 241         klass = find_plugin(os.path.dirname(__file__), name, loader)
#     242
#     243         return klass
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/plugins.py in find_plugin(directories, name, loader, refreshed)
#     136         LOG.debug("Cannot find {loader.kind} 'name'. Refreshing plugin list.")
#     137         refresh(loader.kind)
# --> 138         return find_plugin(directories, name, loader, refreshed=True)
#     139
#     140     module = loader.load_remote(name)
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/plugins.py in find_plugin(directories, name, loader, refreshed)
#     154     candidates = ", ".join(sorted(c for c in candidates if "-" in c))
#     155
# --> 156     raise NameError(f"Cannot find {loader.kind} '{name}' (values are: {candidates})")
#     157
#     158
#
# NameError: Cannot find dataset 'hurican-database-with-typo' (values are: era5-precipitations, era5-single-levels, era5-temperature, example-dataset, high-low, hurricane-database, meteonet-radar-rainfall, meteonet-samples-ground-stations, meteonet-samples-masks, meteonet-samples-radar, meteonet-samples-weather-models, sample-bufr-data, sample-grib-data, weather-bench)

# %% [markdown]
# Additional datasets are defined with python plugins (via pip install), more details on this process in the "Dataset plugins" notebook.
#
# More  examples can be found at (https://climetlab.readthedocs.io/en/latest/examples.html).

# %% [markdown]
# ## Exercises
# Find the mean temperature (2m temperature) in Italy in 1980, at 6am.

# %% [markdown]
# **Solutions:**

# %%
import climetlab as cml
data = cml.load_dataset("era5-temperature", 
    period=1980,
    domain="Italy",
    time=6,
)
ds = data.to_xarray()
float(ds.mean().t2m)
# Out:
# <div style='border: 1px solid orange; color: black;
#      background-color: rgb(255, 214, 0);
#      margin: 0.5em; padding: 0.5em; font-weight: bold;'>
# <p>An API key is needed to access this dataset. Please visit
# <a href="https://cds.climate.copernicus.eu/">https://cds.climate.copernicus.eu/</a> to register or sign-in
# then visit <a href="https://cds.climate.copernicus.eu/api-how-to">https://cds.climate.copernicus.eu/api-how-to</a> to retrieve you API key.</p>
# </div>
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API url</span> or leave empty for the default value <span style='color: red;'>https://cds.climate.copernicus.eu/api/v2</span>, then press <em>ENTER</em></p>
# </div>
# API url:
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API key</span>, then press <em>ENTER</em> The value should look like  <span style='color: red;'>123:abcdef01-0000-1111-2222-0123456789ab</span></p>
# </div>
# API key: ··········
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-18-c7bcad375011> in <cell line: 2>()
#       1 import climetlab as cml
# ----> 2 data = cml.load_dataset("era5-temperature",
#       3     period=1980,
#       4     domain="Italy",
#       5     time=6,
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/__init__.py in load_dataset(name, *args, **kwargs)
#     278         TERMS_OF_USE_SHOWN.add(name)
#     279
# --> 280     ds = klass(*args, **kwargs).mutate()
#     281     if getattr(ds, "name", None) is None:
#     282         ds.name = name
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/__init__.py in __call__(cls, *args, **kwargs)
#      23         obj = cls.__new__(cls, *args, **kwargs)
#      24         args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 25         obj.__init__(*args, **kwargs)
#      26         return obj
#      27
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/era5_temperature.py in __init__(self, *args, **kwargs)
#      13 class Era5Temperature(Era5SingleLevels):
#      14     def __init__(self, *args, **kwargs):
# ---> 15         super().__init__("2t", *args, **kwargs)
#      16
#      17
#
# /usr/local/lib/python3.10/dist-packages/climetlab/datasets/era5_single_levels.py in __init__(self, variable, period, domain, time, grid)
#      48             request["year"] = year
#      49             sources.append(
# ---> 50                 load_source("cds", "reanalysis-era5-single-levels", **request)
#      51             )
#      52
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in load_source(name, lazily, *args, **kwargs)
#     176
#     177     prev = None
# --> 178     src = get_source(name, *args, **kwargs)
#     179     while src is not prev:
#     180         prev = src
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/__init__.py in __call__(self, name, *args, **kwargs)
#     157             klass = SourceMockup
#     158
# --> 159         source = klass(*args, **kwargs)
#     160
#     161         if getattr(source, "name", None) is None:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/core/__init__.py in __call__(cls, *args, **kwargs)
#      23         obj = cls.__new__(cls, *args, **kwargs)
#      24         args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 25         obj.__init__(*args, **kwargs)
#      26         return obj
#      27
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/cds.py in __init__(self, dataset, *args, **kwargs)
#      82         requests = self.requests(**kwargs)
#      83
# ---> 84         client()  # Trigger password prompt before thraeding
#      85
#      86         nthreads = min(self.settings("number-of-download-threads"), len(requests))
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/cds.py in client()
#      47 def client():
#      48     prompt = CDSAPIKeyPrompt()
# ---> 49     prompt.check()
#      50
#      51     try:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in check(self, load)
#     126         rcfile = os.path.expanduser(self.rcfile)
#     127         if not os.path.exists(rcfile):
# --> 128             self.ask_user_and_save()
#     129
#     130         if load:
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user_and_save(self)
#     141
#     142     def ask_user_and_save(self):
# --> 143         input = self.ask_user()
#     144
#     145         rcfile = os.path.expanduser(self.rcfile)
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#     138             prompt = Text(self)
#     139
# --> 140         return self.validate(prompt.ask_user())
#     141
#     142     def ask_user_and_save(self):
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in ask_user(self)
#      74                     validate = RegexValidate(validate)
#      75
# ---> 76                 value = validate(value)
#      77
#      78             result[p["name"]] = value
#
# /usr/local/lib/python3.10/dist-packages/climetlab/sources/prompt.py in __call__(self, value)
#      51
#      52     def __call__(self, value):
# ---> 53         assert re.fullmatch(self.pattern, value), (self.pattern, value)
#      54         return value
#      55
#
# AssertionError: ('\\d+:[\\-0-9a-f]+', '')
